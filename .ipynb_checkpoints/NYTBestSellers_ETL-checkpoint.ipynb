# %% [markdown]
# In this ETL project, we build a collection of NYT fiction best sellers from 2008 to 2018. We put together and save to MongoDB a dataset combining a kaggle dataset and additional data scraped from Amazon.com.
# This collection can then be potentially used to build an app to help book fans select great books by various keywords, or identify current good deals for buying NYT best sellers, or analyze best seller list trends, among other potential uses.
#
# The team members in this project are Joyce Jiang and Sandrine Poissonnet.

# %% [markdown]
# # EXTRACT

# %% [markdown]
# ### STEP 1: Extract data from kaggle's file 'nyt2.json'
#
# Our first challenge started with the data file 'nyt2.json' we downloaded from kaggle (https://www.kaggle.com/cmenca/new-york-times-hardcover-fiction-best-sellers). We expected a traditional json file (a list of dictionaries or a dictionary of dictionaries), but it is, instead, a compilation of json files, one per line. We wrote the code below to transform it into a true json file, which we named 'output.json'.

# %%
# Import dependencies needed

import json
import pandas as pd
from pprint import pprint

# %%
# Load 'nyt2.json' file into dataframe:

raw_nyt = pd.read_json('Resources/nyt2.json', lines=True, orient='columns')
raw_nyt.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b4aa4ead3089013507db18b'}
# 1  {'$oid': '5b4aa4ead3089013507db18c'}
# 2  {'$oid': '5b4aa4ead3089013507db18d'}
# 3  {'$oid': '5b4aa4ead3089013507db18e'}
# 4  {'$oid': '5b4aa4ead3089013507db18f'}
#
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 3  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
#
#                               bestsellers_date  \
# 0  {'$date': {'$numberLong': '1211587200000'}}
# 1  {'$date': {'$numberLong': '1211587200000'}}
# 2  {'$date': {'$numberLong': '1211587200000'}}
# 3  {'$date': {'$numberLong': '1211587200000'}}
# 4  {'$date': {'$numberLong': '1211587200000'}}
#
#                                          description  \
# 0  Odd Thomas, who can communicate with the dead,...
# 1  Aliens have taken control of the minds and bod...
# 2  A woman's happy marriage is shaken when she en...
# 3  A Massachusetts state investigator and his tea...
# 4  An aging porn queens aims to cap her career by...
#
#                         price                               published_date  \
# 0        {'$numberInt': '27'}  {'$date': {'$numberLong': '1212883200000'}}
# 1  {'$numberDouble': '25.99'}  {'$date': {'$numberLong': '1212883200000'}}
# 2  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 3  {'$numberDouble': '22.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 4  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
#
#        publisher                 rank       rank_last_week  \
# 0         Bantam  {'$numberInt': '1'}  {'$numberInt': '0'}
# 1  Little, Brown  {'$numberInt': '2'}  {'$numberInt': '1'}
# 2   St. Martin's  {'$numberInt': '3'}  {'$numberInt': '2'}
# 3         Putnam  {'$numberInt': '4'}  {'$numberInt': '0'}
# 4      Doubleday  {'$numberInt': '5'}  {'$numberInt': '0'}
#
#                       title        weeks_on_list
# 0                 ODD HOURS  {'$numberInt': '1'}
# 1                  THE HOST  {'$numberInt': '3'}
# 2  LOVE THE ONE YOU'RE WITH  {'$numberInt': '2'}
# 3                 THE FRONT  {'$numberInt': '1'}
# 4                     SNUFF  {'$numberInt': '1'}

# %%
# Save DataFrame 'raw_nyt' into a json file ('output.json') and load it as 'data' we can now work with:

raw_nyt.to_json(path_or_buf='Output/output.json', orient = "records")
with open('Output/output.json') as file:
    data = json.load(file)
#pprint(data)

# %%
# Set up lists to hold reponse info:

nyt_ids = []
urls = []
authors = []
bestsellers_dates = []
descriptions = []
prices = []
published_dates = []
publishers = []
ranks = []
ranks_last_week = []
titles = []
weeks_on_lists = []

# Populate the lists:

for item in data:
    nyt_ids.append(item['_id']['$oid'])
    urls.append(item['amazon_product_url'])
    authors.append(item['author'])
    bestsellers_dates.append(item['bestsellers_date']['$date']['$numberLong'])
    descriptions.append(item['description'])
    published_dates.append(item['published_date']['$date']['$numberLong'])
    publishers.append(item['publisher'])
    ranks.append(item['rank']['$numberInt'])
    ranks_last_week.append(item['rank_last_week']['$numberInt'])
    titles.append(item['title'])
    weeks_on_lists.append(item['weeks_on_list']['$numberInt'])
# Here we have to check for the correct keyname before we can extract the price string:
    price_key, = item['price'].keys()
    if price_key == '$numberInt' or price_key == '$numberDouble':
        prices.append(item['price'][price_key])# Populate the lists:

# %%
# Create a DataFrame from the lists

bestsellers_dict = {
    "nyt_id": nyt_ids,
    "title": titles,
    "author": authors,
    "url": urls,
    "publisher": publishers,
    "description": descriptions,
    "list_price": prices,
    "published_date": published_dates,
    "bestseller_date": bestsellers_dates,
    "rank": ranks,
    "rank_last_week": ranks_last_week,
    "weeks_on_list": weeks_on_lists
}
bestsellers_data = pd.DataFrame(bestsellers_dict)
bestsellers_data.head()
# Out:
#                      nyt_id                     title             author  \
# 0  5b4aa4ead3089013507db18b                 ODD HOURS      Dean R Koontz
# 1  5b4aa4ead3089013507db18c                  THE HOST    Stephenie Meyer
# 2  5b4aa4ead3089013507db18d  LOVE THE ONE YOU'RE WITH       Emily Giffin
# 3  5b4aa4ead3089013507db18e                 THE FRONT  Patricia Cornwell
# 4  5b4aa4ead3089013507db18f                     SNUFF    Chuck Palahniuk
#
#                                                  url      publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...         Bantam
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...  Little, Brown
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...   St. Martin's
# 3  http://www.amazon.com/The-Front-Garano-Patrici...         Putnam
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...      Doubleday
#
#                                          description list_price  \
# 0  Odd Thomas, who can communicate with the dead,...         27
# 1  Aliens have taken control of the minds and bod...      25.99
# 2  A woman's happy marriage is shaken when she en...      24.95
# 3  A Massachusetts state investigator and his tea...      22.95
# 4  An aging porn queens aims to cap her career by...      24.95
#
#   published_date bestseller_date rank rank_last_week weeks_on_list
# 0  1212883200000   1211587200000    1              0             1
# 1  1212883200000   1211587200000    2              1             3
# 2  1212883200000   1211587200000    3              2             2
# 3  1212883200000   1211587200000    4              0             1
# 4  1212883200000   1211587200000    5              0             1

# %%
bestsellers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 12 columns):
# nyt_id             10195 non-null object
# title              10195 non-null object
# author             10195 non-null object
# url                10195 non-null object
# publisher          10195 non-null object
# description        10195 non-null object
# list_price         10195 non-null object
# published_date     10195 non-null object
# bestseller_date    10195 non-null object
# rank               10195 non-null object
# rank_last_week     10195 non-null object
# weeks_on_list      10195 non-null object
# dtypes: object(12)
# memory usage: 955.9+ KB

# %% [markdown]
# ### STEP 2: Scrape info from amazon.com
#
# In this step, we identify the list of 2329 unique Amazon URLs from our bestsellers_data DataFrame, and we visit each of those URLs to scrape the Amazon price offer, number of customer reviews, average 5-star rating, and thumbnail book picture.
# We encountered our second challenge here, as we had to iterate multiple times through our list of Amazon URLs and repetitively request the info we were seeking. We each scraped Amazon for the info sought, and then combined our respective results together (see TRANSFORM, Step 2, further below). Please see files
# 'Web_Scraping_Amazon.py' and 'More_Scraping_Amazon.ipynb' to examine the code used for this scraping.
#
# We believe we had trouble scraping all info from Amazon in part because the site identified us as robots, and in part because the Amazon page has lots of javascript that takes time to load. We later learnt that the requests library cannot process javascript and it might have been preferable to use Splinter to deal with the javascript problem, but we felt we already had an interesting dataset for the purpose of this project.

# %%
# Import dependencies needed

from bs4 import BeautifulSoup
import requests
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
# Get list of unique amazon urls

amazon_urls = list(dict.fromkeys(urls))
len(amazon_urls)
# Out:
# 2329

# %% [markdown]
# #### Please see file 'Web_Scraping_Amazon.py' to examine the code one team member developed for scraping the Amazon pages.
#
# #### Please see jupyter notebook 'More_Scraping_Amazon.ipynb' to examine the code used by the other team member for scraping the Amazon pages.

# %% [markdown]
# # TRANSFORM

# %% [markdown]
# ### STEP 1: Transform data from 'bestsellers_data' DataFrame
#
# In this step we group our data by URL and convert some columns to their appropriate data type (integer, float, or date types where needed).

# %%
# Import dependencies needed
import numpy as np
from datetime import datetime

# %%
# Group bestsellers_data by url

grouped = bestsellers_data.groupby('url')
bestsellers_grouped = grouped['url', 'title', 'author', 'publisher', 'description', 'list_price', 'weeks_on_list'].max()

# Calculate additional columns

bestsellers_grouped['first_date_listed'] = grouped[['published_date']].min()
bestsellers_grouped['last_date_listed'] = grouped[['published_date']].max()
bestsellers_grouped['worst_rank'] = grouped[['rank']].max()
bestsellers_grouped['best_rank'] = grouped[['rank']].min()
bestsellers_grouped['times_listed'] = grouped[['url']].count()
bestsellers_grouped.count()
# Out:
# url                  2329
# title                2329
# author               2329
# publisher            2329
# description          2329
# list_price           2329
# weeks_on_list        2329
# first_date_listed    2329
# last_date_listed     2329
# worst_rank           2329
# best_rank            2329
# times_listed         2329
# dtype: int64

# %%
bestsellers_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2329 entries, http://www.amazon.com/10th-Anniversary-Womens-Murder-Club/dp/1455511463?tag=NYTBS-20 to https://www.amazon.com/You-Will-Pay-Lisa-Jackson/dp/1617734667?tag=NYTBS-20
# Data columns (total 12 columns):
# url                  2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# list_price           2329 non-null object
# weeks_on_list        2329 non-null object
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null object
# best_rank            2329 non-null object
# times_listed         2329 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 236.5+ KB

# %%
# Convert 'list_price' to float:
bestsellers_grouped['list_price'] = bestsellers_grouped['list_price'].apply(lambda x : float(x))

# Convert date columns from unix time stamp to date format:
bestsellers_grouped['first_date_listed'] = bestsellers_grouped['first_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))
bestsellers_grouped['last_date_listed'] = bestsellers_grouped['last_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))

# Convert 'weeks_on_list', 'worst_rank' and 'best_rank' to integer:
bestsellers_grouped['weeks_on_list'] = bestsellers_grouped['weeks_on_list'].apply(lambda x : int(x))
bestsellers_grouped['worst_rank'] = bestsellers_grouped['worst_rank'].apply(lambda x : int(x))
bestsellers_grouped['best_rank'] = bestsellers_grouped['best_rank'].apply(lambda x : int(x))

# %%
bestsellers_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2329 entries, http://www.amazon.com/10th-Anniversary-Womens-Murder-Club/dp/1455511463?tag=NYTBS-20 to https://www.amazon.com/You-Will-Pay-Lisa-Jackson/dp/1617734667?tag=NYTBS-20
# Data columns (total 12 columns):
# url                  2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# list_price           2329 non-null float64
# weeks_on_list        2329 non-null int64
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null int64
# best_rank            2329 non-null int64
# times_listed         2329 non-null int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 236.5+ KB

# %%
bestsellers_grouped.head()
# Out:
#                                                                                                   url  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...  http://www.amazon.com/10th-Anniversary-Womens-...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  http://www.amazon.com/11th-Hour-Womens-Murder-...
# http://www.amazon.com/1225-Christmas-Tree-Lane-...  http://www.amazon.com/1225-Christmas-Tree-Lane...
# http://www.amazon.com/12th-Never-Womens-Murder-...  http://www.amazon.com/12th-Never-Womens-Murder...
#
#                                                                        title  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...          10TH ANNIVERSARY
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                  11/22/63
# http://www.amazon.com/11th-Hour-Womens-Murder-C...                 11TH HOUR
# http://www.amazon.com/1225-Christmas-Tree-Lane-...  1225 CHRISTMAS TREE LANE
# http://www.amazon.com/12th-Never-Womens-Murder-...             12TH OF NEVER
#
#                                                                                author  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...  James Patterson and Maxine Paetro
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                       Stephen King
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  James Patterson and Maxine Paetro
# http://www.amazon.com/1225-Christmas-Tree-Lane-...                    Debbie Macomber
# http://www.amazon.com/12th-Never-Womens-Murder-...  James Patterson and Maxine Paetro
#
#                                                         publisher  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Little, Brown
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       Scribner
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  Little, Brown
# http://www.amazon.com/1225-Christmas-Tree-Lane-...           Mira
# http://www.amazon.com/12th-Never-Womens-Murder-...  Little, Brown
#
#                                                                                           description  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Detective Lindsay Boxer’s long-awaited wedding...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  An English teacher travels back to 1958 by way...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  When a millionaire is gunned down, Detective L...
# http://www.amazon.com/1225-Christmas-Tree-Lane-...  Puppies that need good homes and an ex-husband...
# http://www.amazon.com/12th-Never-Womens-Murder-...  One week after the birth of her baby, Detectiv...
#
#                                                     list_price  weeks_on_list  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...       27.99              8
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       35.00              9
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       27.99              8
# http://www.amazon.com/1225-Christmas-Tree-Lane-...       16.95              4
# http://www.amazon.com/12th-Never-Womens-Murder-...        0.00              6
#
#                                                    first_date_listed  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...        2011-05-22
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...        2011-11-27
# http://www.amazon.com/11th-Hour-Womens-Murder-C...        2012-05-27
# http://www.amazon.com/1225-Christmas-Tree-Lane-...        2011-10-16
# http://www.amazon.com/12th-Never-Womens-Murder-...        2013-05-19
#
#                                                    last_date_listed  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...       2011-07-24
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       2012-05-13
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       2012-07-29
# http://www.amazon.com/1225-Christmas-Tree-Lane-...       2011-11-27
# http://www.amazon.com/12th-Never-Womens-Murder-...       2013-06-30
#
#                                                     worst_rank  best_rank  \
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...           9         16
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...           6          1
# http://www.amazon.com/11th-Hour-Womens-Murder-C...           6          1
# http://www.amazon.com/1225-Christmas-Tree-Lane-...           8         10
# http://www.amazon.com/12th-Never-Womens-Murder-...           8          1
#
#                                                     times_listed
# url
# http://www.amazon.com/10th-Anniversary-Womens-M...            10
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...            23
# http://www.amazon.com/11th-Hour-Womens-Murder-C...            10
# http://www.amazon.com/1225-Christmas-Tree-Lane-...             7
# http://www.amazon.com/12th-Never-Womens-Murder-...             7

# %% [markdown]
# ### STEP 2: Combine output files of Amazon data
#
# In this step we merge our scraped data together. Some of the output results are duplicated, so we cleaned them through merge and drop_duplicates. We end up with a dataframe of 2194 unique urls.

# %%
file1=pd.read_csv("Output/output.csv")
file2=pd.read_csv("Output/output1.csv")
file3=pd.read_csv("Output/output2.csv")
file4=pd.read_csv("Output/output3.csv")
file5=pd.read_csv("Output/output4.csv")
file6=pd.read_csv("Output/more_scraped_data.csv")

# %%
file6=file6.rename(columns={"nb_reviews":"reviews","nb_stars":"rating","amazon_price":"price"})
file6['reviews']=file6['reviews'].apply(str)
file6['rating']=file6['rating'].apply(str)

# %%
join1=pd.merge(file1,file2,on=['url','reviews','rating','price'],how='outer')
join2=pd.merge(join1,file3,on=['url','reviews','rating','price'],how='outer')
join3=pd.merge(join2,file4,on=['url','reviews','rating','price'],how='outer')
join4=pd.merge(join3,file5,on=['url','reviews','rating','price'],how='outer')
join5=pd.merge(join4,file6,on=['url','reviews','rating','price'],how='outer')

# %%
clean_data=join5.drop_duplicates(subset='url', keep='first', inplace=False)
clean_data.head()
# Out:
#      Unnamed: 0_x                                                url  \
# 0             0.0  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 20            1.0  http://www.amazon.com/The-Whole-Truth-David-Ba...
# 24            2.0  http://www.amazon.com/Story-Edgar-Sawtelle-Dav...
# 288           3.0  http://www.amazon.com/The-Quilters-Kitchen-Qui...
# 289           4.0  http://www.amazon.com/Testimony-A-Novel-Anita-...
#
#                     reviews              rating    price  Unnamed: 0_y  \
# 0      237 customer reviews  3.5 out of 5 stars   $9.99            4.0
# 20   1,064 customer reviews  4.4 out of 5 stars   $9.99            9.0
# 24   2,573 customer reviews  3.8 out of 5 stars   $8.99           65.0
# 288    218 customer reviews  3.6 out of 5 stars  $10.99            NaN
# 289    408 customer reviews  3.9 out of 5 stars   $7.99            NaN
#
#      Unnamed: 0_x  Unnamed: 0_y  Unnamed: 0_x  Unnamed: 0_y img_url
# 0             4.0           NaN           NaN           NaN     NaN
# 20            9.0           NaN           NaN           NaN     NaN
# 24           73.0          13.0           1.0           NaN     NaN
# 288           NaN           NaN           NaN           NaN     NaN
# 289           NaN           NaN          28.0           NaN     NaN

# %%
final_data=clean_data[['url','reviews','rating','price']]
final_data.head()
# Out:
#                                                    url  \
# 0    http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 20   http://www.amazon.com/The-Whole-Truth-David-Ba...
# 24   http://www.amazon.com/Story-Edgar-Sawtelle-Dav...
# 288  http://www.amazon.com/The-Quilters-Kitchen-Qui...
# 289  http://www.amazon.com/Testimony-A-Novel-Anita-...
#
#                     reviews              rating    price
# 0      237 customer reviews  3.5 out of 5 stars   $9.99
# 20   1,064 customer reviews  4.4 out of 5 stars   $9.99
# 24   2,573 customer reviews  3.8 out of 5 stars   $8.99
# 288    218 customer reviews  3.6 out of 5 stars  $10.99
# 289    408 customer reviews  3.9 out of 5 stars   $7.99

# %%
final_data.count()
# Out:
# url        2194
# reviews    2194
# rating     2194
# price      1809
# dtype: int64

# %%
final_data.to_csv('Output/join_data.csv')

# %% [markdown]
# ### STEP 3: Merge Amazon and NYT data
# In this step, we merge our combined scraped Amazon data with our NYT dataset. We do some additional data type conversions and other clean-up.

# %%
# Load our combined scraped Amazon data ('join_data.csv')

Amazon_data = pd.read_csv("Output/join_data.csv")
Amazon_data.count()
# Out:
# Unnamed: 0    2194
# url           2194
# reviews       1990
# rating        1975
# price         1809
# dtype: int64

# %%
# Merge Amazon dataframe with NYT dataframe

df = pd.merge(bestsellers_grouped, Amazon_data, on='url',how='left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 16 columns):
# url                  2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# list_price           2329 non-null float64
# weeks_on_list        2329 non-null int64
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null int64
# best_rank            2329 non-null int64
# times_listed         2329 non-null int64
# Unnamed: 0           2194 non-null float64
# reviews              1990 non-null object
# rating               1975 non-null object
# price                1809 non-null object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 309.3+ KB
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2961: FutureWarning: 'url' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Drop columns 'Unnamed: 0'
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Rename some columns
df = df.rename(columns={"list_price":"NYT_price", "price":"Amazon_price", 'url':'Amazon_url', 'reviews': 'Amazon_reviews', 'rating': 'Amazon_rating'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 15 columns):
# Amazon_url           2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# NYT_price            2329 non-null float64
# weeks_on_list        2329 non-null int64
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null int64
# best_rank            2329 non-null int64
# times_listed         2329 non-null int64
# Amazon_reviews       1990 non-null object
# Amazon_rating        1975 non-null object
# Amazon_price         1809 non-null object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 291.1+ KB

# %%
# Convert data types where appropriate

df['Amazon_price']=df['Amazon_price'].replace('[\$,]', '', regex=True).astype(float)
df['Amazon_reviews']=df['Amazon_reviews'].str.replace('customer reviews', '')
df['Amazon_rating']=df['Amazon_rating'].str.replace('out of 5 stars', '')
df["Amazon_price_as%_NYT_price"]=(df["Amazon_price"]/df["NYT_price"]*100).round(2)

df['Amazon_reviews']=df['Amazon_reviews'].str.replace(',', '')
df['Amazon_reviews']=pd.to_numeric(df['Amazon_reviews'], errors='coerce')
df['Amazon_rating']=pd.to_numeric(df['Amazon_rating'], errors='coerce')

df.dtypes
# Out:
# Amazon_url                     object
# title                          object
# author                         object
# publisher                      object
# description                    object
# NYT_price                     float64
# weeks_on_list                   int64
# first_date_listed              object
# last_date_listed               object
# worst_rank                      int64
# best_rank                       int64
# times_listed                    int64
# Amazon_reviews                float64
# Amazon_rating                 float64
# Amazon_price                  float64
# Amazon_price_as%_NYT_price    float64
# dtype: object

# %%
output_table = df[['title','author','publisher','description','Amazon_url','times_listed','first_date_listed','last_date_listed','weeks_on_list','worst_rank','best_rank','Amazon_reviews','Amazon_rating','NYT_price','Amazon_price','Amazon_price_as%_NYT_price']].reset_index(drop=True)
output_table.head()
# Out:
#                       title                             author      publisher  \
# 0          10TH ANNIVERSARY  James Patterson and Maxine Paetro  Little, Brown
# 1                  11/22/63                       Stephen King       Scribner
# 2                 11TH HOUR  James Patterson and Maxine Paetro  Little, Brown
# 3  1225 CHRISTMAS TREE LANE                    Debbie Macomber           Mira
# 4             12TH OF NEVER  James Patterson and Maxine Paetro  Little, Brown
#
#                                          description  \
# 0  Detective Lindsay Boxer’s long-awaited wedding...
# 1  An English teacher travels back to 1958 by way...
# 2  When a millionaire is gunned down, Detective L...
# 3  Puppies that need good homes and an ex-husband...
# 4  One week after the birth of her baby, Detectiv...
#
#                                           Amazon_url  times_listed  \
# 0  http://www.amazon.com/10th-Anniversary-Womens-...            10
# 1  http://www.amazon.com/11-22-63-A-Novel/dp/1451...            23
# 2  http://www.amazon.com/11th-Hour-Womens-Murder-...            10
# 3  http://www.amazon.com/1225-Christmas-Tree-Lane...             7
# 4  http://www.amazon.com/12th-Never-Womens-Murder...             7
#
#   first_date_listed last_date_listed  weeks_on_list  worst_rank  best_rank  \
# 0        2011-05-22       2011-07-24              8           9         16
# 1        2011-11-27       2012-05-13              9           6          1
# 2        2012-05-27       2012-07-29              8           6          1
# 3        2011-10-16       2011-11-27              4           8         10
# 4        2013-05-19       2013-06-30              6           8          1
#
#    Amazon_reviews  Amazon_rating  NYT_price  Amazon_price  \
# 0          1365.0            4.6      27.99          9.99
# 1         26427.0            4.5      35.00         10.99
# 2          1858.0            4.6      27.99          9.99
# 3           741.0            NaN      16.95          5.98
# 4          3789.0            4.5       0.00          9.99
#
#    Amazon_price_as%_NYT_price
# 0                   35.690000
# 1                   31.400000
# 2                   35.690000
# 3                   35.280000
# 4                         inf

# %%
output_table.count()
# Out:
# title                         2329
# author                        2329
# publisher                     2329
# description                   2329
# Amazon_url                    2329
# times_listed                  2329
# first_date_listed             2329
# last_date_listed              2329
# weeks_on_list                 2329
# worst_rank                    2329
# best_rank                     2329
# Amazon_reviews                1989
# Amazon_rating                 1975
# NYT_price                     2329
# Amazon_price                  1809
# Amazon_price_as%_NYT_price    1808
# dtype: int64

# %%
output_table.to_csv('Output/output_table_final_version.csv')

# %% [markdown]
# # LOAD into MongoDB

# %% [markdown]
# ### Why MongoDB?
#
# The original kaggle dataset contains over 2300 datapoints, yet we could not scrape all of the info sought in amazon for each of the unique urls contained in the dataset. Each team member scraped on her end with different using requests, but iterating in different ways (see jupyter notebook X and Y). We then merged our scraped data together and ended up with a dataframe of with a number of NaN values on certain fields. Since we wanted to keep all info for future app developpement, and one field is a long string (book description), we thought MongoDB would offer the best flexibility to store our data.

# %%
# Import dependencies needed
import pymongo

# %%
# Initialize PyMongo to work with MongoDB

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Check if database exists already and drop it if so

dblist = client.list_database_names()
if "nyt_bestsellers" in dblist:
    client.drop_database("nyt_bestsellers")

# %%
# Define database and collection

db = client.nyt_bestsellers
collection = db.bestsellers

# %%
bestsellers_df = pd.read_csv("Output/output_table_final_version.csv")
bestsellers_df.head()
# Out:
#    Unnamed: 0                     title                             author  \
# 0           0          10TH ANNIVERSARY  James Patterson and Maxine Paetro
# 1           1                  11/22/63                       Stephen King
# 2           2                 11TH HOUR  James Patterson and Maxine Paetro
# 3           3  1225 CHRISTMAS TREE LANE                    Debbie Macomber
# 4           4             12TH OF NEVER  James Patterson and Maxine Paetro
#
#        publisher                                        description  \
# 0  Little, Brown  Detective Lindsay Boxer’s long-awaited wedding...
# 1       Scribner  An English teacher travels back to 1958 by way...
# 2  Little, Brown  When a millionaire is gunned down, Detective L...
# 3           Mira  Puppies that need good homes and an ex-husband...
# 4  Little, Brown  One week after the birth of her baby, Detectiv...
#
#                                           Amazon_url  times_listed  \
# 0  http://www.amazon.com/10th-Anniversary-Womens-...            10
# 1  http://www.amazon.com/11-22-63-A-Novel/dp/1451...            23
# 2  http://www.amazon.com/11th-Hour-Womens-Murder-...            10
# 3  http://www.amazon.com/1225-Christmas-Tree-Lane...             7
# 4  http://www.amazon.com/12th-Never-Womens-Murder...             7
#
#   first_date_listed last_date_listed  weeks_on_list  worst_rank  best_rank  \
# 0        2011-05-22       2011-07-24              8           9         16
# 1        2011-11-27       2012-05-13              9           6          1
# 2        2012-05-27       2012-07-29              8           6          1
# 3        2011-10-16       2011-11-27              4           8         10
# 4        2013-05-19       2013-06-30              6           8          1
#
#    Amazon_reviews  Amazon_rating  NYT_price  Amazon_price  \
# 0          1365.0            4.6      27.99          9.99
# 1         26427.0            4.5      35.00         10.99
# 2          1858.0            4.6      27.99          9.99
# 3           741.0            NaN      16.95          5.98
# 4          3789.0            4.5       0.00          9.99
#
#    Amazon_price_as%_NYT_price
# 0                   35.690000
# 1                   31.400000
# 2                   35.690000
# 3                   35.280000
# 4                         inf

# %%
# Create a list of dictionaries that hold the mongoDB documents to be inserted

post = bestsellers_df.to_dict(orient='records')
print(f"Posting {len(post)} documents into collection of bestsellers inside nyt_bestsellers mongo database...")

# Insert the list of documents into the database

collection.insert_many(post)
# Out:
# Posting 2329 documents into collection of bestsellers inside nyt_bestsellers mongo database...

# %%
# Verify results

results = collection.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5c85a280bd7b6a02852b8e6e'), 'Unnamed: 0': 0, 'title': '10TH ANNIVERSARY', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'Detective Lindsay Boxer’s long-awaited wedding celebration becomes a distant memory when the Women’s Murder Club is called in to find a missing baby.', 'Amazon_url': 'http://www.amazon.com/10th-Anniversary-Womens-Murder-Club/dp/1455511463?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2011-05-22', 'last_date_listed': '2011-07-24', 'weeks_on_list': 8, 'worst_rank': 9, 'best_rank': 16, 'Amazon_reviews': 1365.0, 'Amazon_rating': 4.6, 'NYT_price': 27.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 35.69}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e6f'), 'Unnamed: 0': 1, 'title': '11/22/63', 'author': 'Stephen King', 'publisher': 'Scribner', 'description': 'An English teacher travels back to 1958 by way of a time portal in a Maine diner. His assignment: Stop Lee Harvey Oswald.', 'Amazon_url': 'http://www.amazon.com/11-22-63-A-Novel/dp/1451627297?tag=NYTBS-20', 'times_listed': 23, 'first_date_listed': '2011-11-27', 'last_date_listed': '2012-05-13', 'weeks_on_list': 9, 'worst_rank': 6, 'best_rank': 1, 'Amazon_reviews': 26427.0, 'Amazon_rating': 4.5, 'NYT_price': 35.0, 'Amazon_price': 10.99, 'Amazon_price_as%_NYT_price': 31.4}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e70'), 'Unnamed: 0': 2, 'title': '11TH HOUR', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': "When a millionaire is gunned down, Detective Lindsay Boxer and the Women's Murder Club discover that the murder weapon is linked to the deaths of four of San Francisco's most untouchable criminals.", 'Amazon_url': 'http://www.amazon.com/11th-Hour-Womens-Murder-Club/dp/0446571830?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2012-05-27', 'last_date_listed': '2012-07-29', 'weeks_on_list': 8, 'worst_rank': 6, 'best_rank': 1, 'Amazon_reviews': 1858.0, 'Amazon_rating': 4.6, 'NYT_price': 27.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 35.69}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e71'), 'Unnamed: 0': 3, 'title': '1225 CHRISTMAS TREE LANE', 'author': 'Debbie Macomber', 'publisher': 'Mira', 'description': 'Puppies that need good homes and an ex-husband loom large in the last installment of the Cedar Cove series.', 'Amazon_url': 'http://www.amazon.com/1225-Christmas-Tree-Lane-Cedar/dp/0778312690?tag=NYTBS-20', 'times_listed': 7, 'first_date_listed': '2011-10-16', 'last_date_listed': '2011-11-27', 'weeks_on_list': 4, 'worst_rank': 8, 'best_rank': 10, 'Amazon_reviews': 741.0, 'Amazon_rating': nan, 'NYT_price': 16.95, 'Amazon_price': 5.98, 'Amazon_price_as%_NYT_price': 35.28}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e72'), 'Unnamed: 0': 4, 'title': '12TH OF NEVER', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'One week after the birth of her baby, Detective Lindsay Boxer must return to work to investigate a string of grisly murders; a Women’s Murder Club novel.\xa0', 'Amazon_url': 'http://www.amazon.com/12th-Never-Womens-Murder-Club/dp/1455515795?tag=NYTBS-20', 'times_listed': 7, 'first_date_listed': '2013-05-19', 'last_date_listed': '2013-06-30', 'weeks_on_list': 6, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 3789.0, 'Amazon_rating': 4.5, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e73'), 'Unnamed: 0': 5, 'title': '1356', 'author': 'Bernard Cornwell', 'publisher': 'Harper/HarperCollins', 'description': 'In the fourth book of the Grail Quest series, the English and French face off at the Battle of Poitiers.', 'Amazon_url': 'http://www.amazon.com/1356-A-Novel-Bernard-Cornwell/dp/0061969672?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2013-01-27', 'last_date_listed': '2013-02-03', 'weeks_on_list': 1, 'worst_rank': 20, 'best_rank': 11, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 28.99, 'Amazon_price': 24.17, 'Amazon_price_as%_NYT_price': 83.37}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e74'), 'Unnamed: 0': 6, 'title': '14TH DEADLY SIN', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'Detective Lindsay Boxer and her friends must risk their lives to save the city and one another when a rash of murders grips San Francisco.', 'Amazon_url': 'http://www.amazon.com/14th-Deadly-Womens-Murder-Club/dp/031640702X?tag=NYTBS-20', 'times_listed': 8, 'first_date_listed': '2015-05-24', 'last_date_listed': '2015-07-12', 'weeks_on_list': 7, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 4140.0, 'Amazon_rating': 4.3, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e75'), 'Unnamed: 0': 7, 'title': '15 SECONDS', 'author': 'Andrew Gross', 'publisher': 'Morrow', 'description': nan, 'Amazon_url': 'http://www.amazon.com/15-Seconds-Andrew-Gross/dp/006165597X?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2012-07-29', 'last_date_listed': '2012-07-29', 'weeks_on_list': 0, 'worst_rank': 18, 'best_rank': 18, 'Amazon_reviews': 390.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 10.0, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e76'), 'Unnamed: 0': 8, 'title': '15TH AFFAIR', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': "When a brutal murder threatens the domestic happiness of the San Francisco police detective Lindsay Boxer, she turns for help to the Women's Murder Club.", 'Amazon_url': 'http://www.amazon.com/15th-Affair-Womens-Murder-Club/dp/0316407070?tag=NYTBS-20', 'times_listed': 8, 'first_date_listed': '2016-05-22', 'last_date_listed': '2016-07-10', 'weeks_on_list': 7, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 2913.0, 'Amazon_rating': 4.5, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e77'), 'Unnamed: 0': 9, 'title': '1Q84', 'author': 'Haruki Murakami', 'publisher': 'Knopf', 'description': 'In 1980s Tokyo, a woman who punishes perpetrators of domestic violence has ties to an aspiring novelist with an unusual project.', 'Amazon_url': 'http://www.amazon.com/1Q84-Haruki-Murakami-ebook/dp/B004LROUW2?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2011-11-13', 'last_date_listed': '2012-01-15', 'weeks_on_list': 9, 'worst_rank': 6, 'best_rank': 10, 'Amazon_reviews': 1892.0, 'Amazon_rating': 4.0, 'NYT_price': 30.5, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': 42.59}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e78'), 'Unnamed: 0': 10, 'title': '2030', 'author': 'Albert Brooks', 'publisher': "St. Martin's", 'description': 'In 2030, the young resent the elderly for draining the weakening economy, and a devastating earthquake in Los Angeles tests the administration of the country’s first Jewish president.', 'Amazon_url': 'http://www.amazon.com/2030-Real-Story-Happens-America-ebook/dp/B004OA62WC?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2011-05-29', 'last_date_listed': '2011-06-19', 'weeks_on_list': 3, 'worst_rank': 19, 'best_rank': 14, 'Amazon_reviews': 493.0, 'Amazon_rating': 3.7, 'NYT_price': 25.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 38.44}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e79'), 'Unnamed: 0': 11, 'title': '206 BONES', 'author': 'Kathy Reichs', 'publisher': 'Scribner', 'description': 'Temperance Brennan is accused of mishandling an autopsy.', 'Amazon_url': 'http://www.amazon.com/206-Bones-Novel-Temperance-Brennan-ebook/dp/B001NLL7K2?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2009-09-13', 'last_date_listed': '2009-10-04', 'weeks_on_list': 4, 'worst_rank': 8, 'best_rank': 12, 'Amazon_reviews': 329.0, 'Amazon_rating': 4.4, 'NYT_price': 26.99, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7a'), 'Unnamed: 0': 12, 'title': '2312', 'author': 'Kim Stanley Robinson', 'publisher': 'Orbit', 'description': nan, 'Amazon_url': 'http://www.amazon.com/2312-Kim-Stanley-Robinson/dp/0316098124?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2012-06-10', 'last_date_listed': '2012-06-10', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 20, 'Amazon_reviews': 564.0, 'Amazon_rating': 3.4, 'NYT_price': 0.0, 'Amazon_price': 25.0, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7b'), 'Unnamed: 0': 13, 'title': '44 CHARLES STREET', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': 'The owner of a Greenwich Village town house takes in boarders and bonds with her tenants.', 'Amazon_url': 'http://www.amazon.com/44-Charles-Street-A-Novel/dp/0440245176?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2011-04-24', 'last_date_listed': '2011-05-22', 'weeks_on_list': 5, 'worst_rank': 5, 'best_rank': 11, 'Amazon_reviews': 433.0, 'Amazon_rating': 4.2, 'NYT_price': 28.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': 28.54}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7c'), 'Unnamed: 0': 14, 'title': '61 HOURS', 'author': 'Lee Child', 'publisher': 'Delacorte', 'description': 'Jack Reacher helps the police in a small South Dakota town protect a witness in a drug trial.', 'Amazon_url': 'http://www.amazon.com/61-Hours-Jack-Reacher-Novel/dp/0440243696?tag=NYTBS-20', 'times_listed': 7, 'first_date_listed': '2010-06-06', 'last_date_listed': '2010-07-25', 'weeks_on_list': 6, 'worst_rank': 7, 'best_rank': 1, 'Amazon_reviews': 2403.0, 'Amazon_rating': 4.3, 'NYT_price': 28.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 35.68}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7d'), 'Unnamed: 0': 15, 'title': 'A CHANGE IN ALTITUDE', 'author': 'Anita Shreve', 'publisher': 'Little, Brown', 'description': 'A young woman’s life is transformed by a mountain-climbing accident in Kenya.', 'Amazon_url': 'http://www.amazon.com/A-Change-Altitude-Novel/dp/0316020710?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2009-10-11', 'last_date_listed': '2009-10-18', 'weeks_on_list': 1, 'worst_rank': 17, 'best_rank': 11, 'Amazon_reviews': 238.0, 'Amazon_rating': 3.4, 'NYT_price': 26.99, 'Amazon_price': 5.99, 'Amazon_price_as%_NYT_price': 22.19}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7e'), 'Unnamed: 0': 16, 'title': 'A CROWN IMPERILED', 'author': 'Raymond E Feist', 'publisher': 'Harper Voyager', 'description': nan, 'Amazon_url': 'http://www.amazon.com/A-Crown-Imperiled-Chaoswar-Saga/dp/006146841X?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2012-04-01', 'last_date_listed': '2012-04-01', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 20, 'Amazon_reviews': 824.0, 'Amazon_rating': 4.4, 'NYT_price': 0.0, 'Amazon_price': 4.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e7f'), 'Unnamed: 0': 17, 'title': 'A DARK MATTER', 'author': 'Peter Straub', 'publisher': 'Doubleday', 'description': 'A writer investigates what happened to his wife and others who fell under the spell of a charismatic campus guru in the 1960s.', 'Amazon_url': 'http://www.amazon.com/A-Dark-Matter-Peter-Straub/dp/1400096723?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2010-02-28', 'last_date_listed': '2010-02-28', 'weeks_on_list': 0, 'worst_rank': 17, 'best_rank': 17, 'Amazon_reviews': 194.0, 'Amazon_rating': 2.6, 'NYT_price': 0.0, 'Amazon_price': 7.29, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e80'), 'Unnamed: 0': 18, 'title': 'A DARKER PLACE', 'author': 'Jack Higgins', 'publisher': 'Putnam', 'description': 'A Russian defector becomes a counterspy.', 'Amazon_url': 'http://www.amazon.com/A-Darker-Place-Jack-Higgins/dp/0399155503?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2009-02-15', 'last_date_listed': '2009-03-01', 'weeks_on_list': 3, 'worst_rank': 14, 'best_rank': 10, 'Amazon_reviews': 91.0, 'Amazon_rating': 4.1, 'NYT_price': 26.95, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 37.07}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e81'), 'Unnamed: 0': 19, 'title': 'A DEVIL IS WAITING', 'author': 'Jack Higgins', 'publisher': 'Putnam', 'description': 'Sean Dillon helps to foil a plot to assassinate the president in London.', 'Amazon_url': 'http://www.amazon.com/A-Devil-Waiting-Jack-Higgins/dp/0425250571?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2012-01-22', 'last_date_listed': '2012-01-22', 'weeks_on_list': 1, 'worst_rank': 15, 'best_rank': 15, 'Amazon_reviews': 178.0, 'Amazon_rating': 4.1, 'NYT_price': 26.95, 'Amazon_price': 8.99, 'Amazon_price_as%_NYT_price': 33.36}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e82'), 'Unnamed: 0': 20, 'title': 'A DOG’S JOURNEY', 'author': 'W Bruce Cameron', 'publisher': 'Tom Doherty/Forge', 'description': 'In a sequel to “A Dog’s Purpose,” Buddy the dog embraces a new destiny.', 'Amazon_url': 'http://www.amazon.com/A-Dogs-Journey-Novel/dp/0765330539?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2012-05-27', 'last_date_listed': '2012-06-03', 'weeks_on_list': 1, 'worst_rank': 18, 'best_rank': 14, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 24.99, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e83'), 'Unnamed: 0': 21, 'title': "A DOUBTER'S ALMANAC", 'author': 'Ethan Canin', 'publisher': 'Random House', 'description': nan, 'Amazon_url': 'http://www.amazon.com/A-Doubters-Almanac-Novel/dp/1400068266?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2016-03-06', 'last_date_listed': '2016-03-13', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 20, 'Amazon_reviews': 226.0, 'Amazon_rating': 4.0, 'NYT_price': 0.0, 'Amazon_price': 10.47, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e84'), 'Unnamed: 0': 22, 'title': 'A GATHERING OF SHADOWS', 'author': 'V E Schwab', 'publisher': 'Tor/Tom Doherty', 'description': 'A magicians’ competition is about to be held in one of the linked alternative realities of London in this fantasy.', 'Amazon_url': 'http://www.amazon.com/A-Gathering-Shadows-Novel/dp/0765376474?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2016-03-13', 'last_date_listed': '2016-03-13', 'weeks_on_list': 1, 'worst_rank': 15, 'best_rank': 15, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e85'), 'Unnamed: 0': 23, 'title': 'A GOD IN RUINS', 'author': 'Kate Atkinson', 'publisher': 'Little, Brown', 'description': 'Postwar Britain as seen through the members of a well-to-do family.', 'Amazon_url': 'http://www.amazon.com/A-God-Ruins-Novel-ebook/dp/B00NERQQXG?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2015-05-24', 'last_date_listed': '2015-06-07', 'weeks_on_list': 2, 'worst_rank': 7, 'best_rank': 16, 'Amazon_reviews': 940.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 11.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e86'), 'Unnamed: 0': 24, 'title': 'A GOOD WOMAN', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': 'An American society girl who made a new life as a doctor in World War I France returns to New York.', 'Amazon_url': 'http://www.amazon.com/A-Good-Woman-Novel/dp/0440243300?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2008-11-16', 'last_date_listed': '2009-01-11', 'weeks_on_list': 2, 'worst_rank': 5, 'best_rank': 10, 'Amazon_reviews': 381.0, 'Amazon_rating': 4.5, 'NYT_price': 27.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': 29.59}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e87'), 'Unnamed: 0': 25, 'title': 'A HEARTBEAT AWAY', 'author': 'Michael Palmer', 'publisher': 'St. Martin’s', 'description': 'A terrorist group unleashes a deadly virus in the Capitol on the night of the State of the Union address.', 'Amazon_url': 'http://www.amazon.com/A-Heartbeat-Away-Michael-Palmer-ebook/dp/B00457X86M?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2011-03-06', 'last_date_listed': '2011-03-13', 'weeks_on_list': 2, 'worst_rank': 15, 'best_rank': 10, 'Amazon_reviews': 183.0, 'Amazon_rating': 3.9, 'NYT_price': 27.99, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': 28.55}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e88'), 'Unnamed: 0': 26, 'title': 'A HOLOGRAM FOR THE KING', 'author': 'Dave Eggers', 'publisher': "McSweeney's", 'description': 'In a rising Saudi Arabian city, a struggling American businessman pursues a last-ditch attempt to stave off foreclosure, pay his daughter’s college tuition, and finally do something great.', 'Amazon_url': 'http://www.amazon.com/A-Hologram-King-Dave-Eggers/dp/193636574X?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2012-07-08', 'last_date_listed': '2012-08-12', 'weeks_on_list': 1, 'worst_rank': 16, 'best_rank': 16, 'Amazon_reviews': 424.0, 'Amazon_rating': 3.3, 'NYT_price': 25.0, 'Amazon_price': 9.98, 'Amazon_price_as%_NYT_price': 39.92}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e89'), 'Unnamed: 0': 27, 'title': 'A LITTLE LIFE', 'author': 'Hanya Yanagihara', 'publisher': 'Doubleday', 'description': 'Four college friends, one with a traumatic past, move to New York seeking fame and fortune.', 'Amazon_url': 'http://www.amazon.com/A-Little-Life-Hanya-Yanagihara/dp/0804172706?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2016-01-17', 'last_date_listed': '2016-01-24', 'weeks_on_list': 0, 'worst_rank': 19, 'best_rank': 19, 'Amazon_reviews': 3436.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8a'), 'Unnamed: 0': 28, 'title': 'A MEMORY OF LIGHT', 'author': 'Robert Jordan and Brandon Sanderson', 'publisher': 'Tor/Tom Doherty', 'description': 'The 14th and final novel in the Wheel of Time fantasy series.', 'Amazon_url': 'http://www.amazon.com/A-Memory-Light-Wheel-Time-ebook/dp/B00BMKDTNC?tag=NYTBS-20', 'times_listed': 13, 'first_date_listed': '2013-01-27', 'last_date_listed': '2013-05-05', 'weeks_on_list': 9, 'worst_rank': 7, 'best_rank': 1, 'Amazon_reviews': 4293.0, 'Amazon_rating': 4.6, 'NYT_price': 34.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 28.55}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8b'), 'Unnamed: 0': 29, 'title': 'A MERCY', 'author': 'Toni Morrison', 'publisher': 'Knopf', 'description': 'In 17th-\xadcentury America, a slave mother urges a Northern farmer to buy her daughter so that she can have a better life; from the Nobel Prize-winning author of “Beloved.”', 'Amazon_url': 'http://www.amazon.com/A-Mercy-Toni-Morrison/dp/0307276767?tag=NYTBS-20', 'times_listed': 11, 'first_date_listed': '2008-11-30', 'last_date_listed': '2009-02-08', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 10, 'Amazon_reviews': 294.0, 'Amazon_rating': 3.9, 'NYT_price': 23.95, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 41.71}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8c'), 'Unnamed: 0': 30, 'title': 'A PERFECT LIFE', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': "A television anchor's on-air poise belies her unsettled life.", 'Amazon_url': 'http://www.amazon.com/A-Perfect-Life-Novel-ebook/dp/B00HXYKYDE?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2014-08-10', 'last_date_listed': '2014-09-07', 'weeks_on_list': 4, 'worst_rank': 7, 'best_rank': 11, 'Amazon_reviews': 1648.0, 'Amazon_rating': 4.4, 'NYT_price': 0.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8d'), 'Unnamed: 0': 31, 'title': 'A PLAGUE OF SECRETS', 'author': 'John Lescroart', 'publisher': 'Dutton', 'description': 'The San Francisco defense attorney Dismas Hardy must protect the secrets of his client.', 'Amazon_url': 'http://www.amazon.com/A-Plague-Secrets-John-Lescroart/dp/0451228324?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2009-07-19', 'last_date_listed': '2009-07-26', 'weeks_on_list': 1, 'worst_rank': 18, 'best_rank': 12, 'Amazon_reviews': 142.0, 'Amazon_rating': 4.3, 'NYT_price': 26.95, 'Amazon_price': 9.05, 'Amazon_price_as%_NYT_price': 33.58}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8e'), 'Unnamed: 0': 32, 'title': 'A PRINCESS OF LANDOVER', 'author': 'Terry Brooks', 'publisher': 'Ballantine', 'description': 'The king of Landover wants his princesss daughter to learn responsibility, but she runs away to learn sorcery.', 'Amazon_url': 'http://www.amazon.com/A-Princess-Landover-Terry-Brooks-ebook/dp/B002LA0ACK?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2009-09-06', 'last_date_listed': '2009-09-06', 'weeks_on_list': 1, 'worst_rank': 15, 'best_rank': 15, 'Amazon_reviews': 143.0, 'Amazon_rating': 4.2, 'NYT_price': 26.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e8f'), 'Unnamed: 0': 33, 'title': 'A RELIABLE WIFE', 'author': 'Robert Goolrick', 'publisher': 'Algonquin', 'description': 'Complications ensue when a wealthy Wisconsin widower in 1907 advertises for a spouse.', 'Amazon_url': 'http://www.amazon.com/A-Reliable-Wife-Robert-Goolrick/dp/1565125967?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2009-05-10', 'last_date_listed': '2009-05-10', 'weeks_on_list': 0, 'worst_rank': 17, 'best_rank': 17, 'Amazon_reviews': 1399.0, 'Amazon_rating': 3.3, 'NYT_price': 0.0, 'Amazon_price': 9.58, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e90'), 'Unnamed: 0': 34, 'title': 'A RISING THUNDER', 'author': 'David Weber', 'publisher': 'Baen', 'description': 'Honor Harrington defends the Star Empire of Manticore in a new and terrible war.', 'Amazon_url': 'http://www.amazon.com/A-Rising-Thunder-Honor-Harrington/dp/145163806X?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2012-03-25', 'last_date_listed': '2012-04-01', 'weeks_on_list': 2, 'worst_rank': 3, 'best_rank': 15, 'Amazon_reviews': 476.0, 'Amazon_rating': 3.8, 'NYT_price': 26.0, 'Amazon_price': 18.27, 'Amazon_price_as%_NYT_price': 70.27}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e91'), 'Unnamed: 0': 35, 'title': 'A SECRET KEPT', 'author': 'Tatiana de Rosnay', 'publisher': 'St. Martin’s', 'description': 'A family revelation upsets the life of a Parisian architect.', 'Amazon_url': 'http://www.amazon.com/A-Secret-Kept-Tatiana-Rosnay/dp/0312553498?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2010-10-03', 'last_date_listed': '2010-10-10', 'weeks_on_list': 1, 'worst_rank': 20, 'best_rank': 14, 'Amazon_reviews': 388.0, 'Amazon_rating': 3.6, 'NYT_price': 24.99, 'Amazon_price': 10.83, 'Amazon_price_as%_NYT_price': 43.34}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e92'), 'Unnamed: 0': 36, 'title': 'A SHIVER OF LIGHT', 'author': 'Laurell K Hamilton', 'publisher': 'Berkley', 'description': 'In the ninth Meredith Gentry paranormal romance, Merry must save herself and her triplets from Taranis, King of Light and Illusion.', 'Amazon_url': 'http://www.amazon.com/A-Shiver-Light-Merry-Gentry/dp/0425255662?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2014-06-22', 'last_date_listed': '2014-06-22', 'weeks_on_list': 1, 'worst_rank': 5, 'best_rank': 5, 'Amazon_reviews': 1409.0, 'Amazon_rating': 3.9, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e93'), 'Unnamed: 0': 37, 'title': 'A SUDDEN LIGHT', 'author': 'Garth Stein', 'publisher': 'Simon & Schuster', 'description': 'A 14-year-old Seattle boy, staying at his ailing grandfather’s mansion on Puget Sound, explores his family’s dark past.', 'Amazon_url': 'http://www.amazon.com/A-Sudden-Light-Novel/dp/1439187037?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2014-10-19', 'last_date_listed': '2014-10-19', 'weeks_on_list': 1, 'worst_rank': 14, 'best_rank': 14, 'Amazon_reviews': 541.0, 'Amazon_rating': 4.1, 'NYT_price': 0.0, 'Amazon_price': 13.0, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e94'), 'Unnamed: 0': 38, 'title': 'A SUMMER AFFAIR', 'author': 'Elin Hilderbrand', 'publisher': 'Little Brown & Company', 'description': 'A successful married artist is attracted to a billionaire on Nantucket.', 'Amazon_url': 'http://www.amazon.com/A-Summer-Affair-Novel/dp/B003P2VBNU?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2008-07-20', 'last_date_listed': '2008-07-27', 'weeks_on_list': 0, 'worst_rank': 19, 'best_rank': 18, 'Amazon_reviews': 241.0, 'Amazon_rating': 3.7, 'NYT_price': 0.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e95'), 'Unnamed: 0': 39, 'title': 'A THOUSAND MORNINGS', 'author': 'Mary Oliver', 'publisher': 'Penguin Press', 'description': nan, 'Amazon_url': 'http://www.amazon.com/A-Thousand-Mornings-Mary-Oliver/dp/1594204772?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2012-10-28', 'last_date_listed': '2012-11-04', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 19, 'Amazon_reviews': 253.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e96'), 'Unnamed: 0': 40, 'title': 'A TIME FOR PATRIOTS', 'author': 'Dale Brown', 'publisher': 'William Morrow', 'description': nan, 'Amazon_url': 'http://www.amazon.com/A-Time-Patriots-Dale-Brown/dp/0061989991?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2011-05-29', 'last_date_listed': '2011-05-29', 'weeks_on_list': 0, 'worst_rank': 18, 'best_rank': 18, 'Amazon_reviews': 168.0, 'Amazon_rating': 3.7, 'NYT_price': 0.0, 'Amazon_price': 17.87, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e97'), 'Unnamed: 0': 41, 'title': 'A WEEK IN WINTER', 'author': 'Maeve Binchy', 'publisher': 'Knopf', 'description': 'Guests at an inn by the sea on Ireland’s west coast; the final book by Binchy, who died in 2012.\xa0', 'Amazon_url': 'http://www.amazon.com/A-Week-Winter-Maeve-Binchy/dp/0307273571?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2013-03-03', 'last_date_listed': '2013-05-05', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 3451.0, 'Amazon_rating': 4.4, 'NYT_price': 26.95, 'Amazon_price': 8.99, 'Amazon_price_as%_NYT_price': 33.36}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e98'), 'Unnamed: 0': 42, 'title': 'A WINTER DREAM', 'author': 'Richard Paul Evans', 'publisher': 'Simon & Schuster', 'description': 'When Joseph Jacobson stands to take over his father’s business, his 12 brothers cast him out.', 'Amazon_url': 'http://www.amazon.com/A-Winter-Dream-Novel/dp/145162803X?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2012-11-18', 'last_date_listed': '2012-12-02', 'weeks_on_list': 3, 'worst_rank': 6, 'best_rank': 11, 'Amazon_reviews': 418.0, 'Amazon_rating': 4.6, 'NYT_price': 19.99, 'Amazon_price': 10.99, 'Amazon_price_as%_NYT_price': 54.98}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e99'), 'Unnamed: 0': 43, 'title': 'ABRAHAM LINCOLN: VAMPIRE HUNTER', 'author': 'Seth Grahame-Smith', 'publisher': 'Grand Central', 'description': 'Lincoln vs. the undead.', 'Amazon_url': 'http://www.amazon.com/Abraham-Lincoln-Vampire-Seth-Grahame-Smith/dp/0446563072?tag=NYTBS-20', 'times_listed': 8, 'first_date_listed': '2010-03-21', 'last_date_listed': '2010-05-09', 'weeks_on_list': 7, 'worst_rank': 8, 'best_rank': 13, 'Amazon_reviews': 1627.0, 'Amazon_rating': 4.3, 'NYT_price': 21.99, 'Amazon_price': 6.92, 'Amazon_price_as%_NYT_price': 31.47}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9a'), 'Unnamed: 0': 44, 'title': 'ABUSE OF POWER', 'author': 'Michael Savage', 'publisher': 'St. Martin’s', 'description': 'A former war correspondent works to expose a terrorist group and a plot at the highest levels of power.', 'Amazon_url': 'http://www.amazon.com/Abuse-Power-Michael-Savage/dp/0312651619?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2011-10-02', 'last_date_listed': '2011-10-16', 'weeks_on_list': 2, 'worst_rank': 4, 'best_rank': 12, 'Amazon_reviews': 319.0, 'Amazon_rating': 4.3, 'NYT_price': 25.99, 'Amazon_price': 9.74, 'Amazon_price_as%_NYT_price': 37.48}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9b'), 'Unnamed: 0': 45, 'title': 'ABYSS', 'author': 'Troy Denning', 'publisher': 'Del Rey/Ballantine/Lucas', 'description': 'In a "Star Wars" book, Luke Skywalker goes to the Mind Walker’s The detective Alex Cross writes a novel about his great-uncle, who fought the Klan.world to try to redeem the Jedi.', 'Amazon_url': 'http://www.amazon.com/Abyss-Star-Wars-Fate-Legends/dp/0345509188?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2009-09-06', 'last_date_listed': '2009-09-13', 'weeks_on_list': 2, 'worst_rank': 7, 'best_rank': 14, 'Amazon_reviews': 69.0, 'Amazon_rating': 4.1, 'NYT_price': 27.0, 'Amazon_price': 12.95, 'Amazon_price_as%_NYT_price': 47.96}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9c'), 'Unnamed: 0': 46, 'title': 'ACCUSED', 'author': 'Lisa Scottoline', 'publisher': "St. Martin's", 'description': 'Mary DiNunzio is now a partner at the all-women Philadelphia law firm of Rosato & Associates.', 'Amazon_url': 'http://www.amazon.com/Accused-A-Rosato-Associates-Novel-ebook/dp/B009LRWH3Q?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2013-11-17', 'last_date_listed': '2013-11-24', 'weeks_on_list': 2, 'worst_rank': 7, 'best_rank': 14, 'Amazon_reviews': 720.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9d'), 'Unnamed: 0': 47, 'title': 'ACHERON', 'author': 'Sherrilyn Kenyon', 'publisher': 'St. Martin’s', 'description': 'Book 12 of the Dark-Hunter paranormal series.', 'Amazon_url': 'http://www.amazon.com/Acheron-Dark-Hunter-Book-Sherrilyn-Kenyon/dp/0312949413?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2008-08-24', 'last_date_listed': '2008-09-21', 'weeks_on_list': 4, 'worst_rank': 6, 'best_rank': 1, 'Amazon_reviews': 1163.0, 'Amazon_rating': 4.7, 'NYT_price': 24.95, 'Amazon_price': 8.99, 'Amazon_price_as%_NYT_price': 36.03}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9e'), 'Unnamed: 0': 48, 'title': 'ACT OF WAR', 'author': 'Brad Thor', 'publisher': 'Emily Bestler/Atria', 'description': 'The counterterrorism operative Scot Harvath undertakes two dangerous missions as America faces an imminent attack.', 'Amazon_url': 'http://www.amazon.com/Act-War-Thriller-Brad-Thor/dp/1476717125?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2014-07-27', 'last_date_listed': '2014-08-24', 'weeks_on_list': 5, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 3328.0, 'Amazon_rating': 4.4, 'NYT_price': 0.0, 'Amazon_price': 8.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8e9f'), 'Unnamed: 0': 49, 'title': 'ADULTERY', 'author': 'Paulo Coelho', 'publisher': 'Knopf', 'description': '\xa0A married journalist, depressed by boredom, risks everything when she embarks on an affair with a former boyfriend; by the Brazilian writer, the author of “The Alchemist.”\xa0', 'Amazon_url': 'http://www.amazon.com/Adultery-A-novel-Paulo-Coelho/dp/1101874082?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2014-09-07', 'last_date_listed': '2014-10-19', 'weeks_on_list': 4, 'worst_rank': 6, 'best_rank': 15, 'Amazon_reviews': 806.0, 'Amazon_rating': 3.4, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea0'), 'Unnamed: 0': 50, 'title': 'THE AFFAIR', 'author': 'Lee Child', 'publisher': 'Delacorte', 'description': 'It’s 1997 and the military cop Jack Reacher goes undercover in Mississippi to ferret out a possible scandal involving a soldier with powerful friends in Washington.', 'Amazon_url': 'http://www.amazon.com/Affair-bonus-short-story-Second-ebook/dp/B004P8JPS6?tag=NYTBS-20', 'times_listed': 8, 'first_date_listed': '2011-10-16', 'last_date_listed': '2011-12-11', 'weeks_on_list': 7, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 2694.0, 'Amazon_rating': 4.5, 'NYT_price': 28.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 35.68}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea1'), 'Unnamed: 0': 51, 'title': 'AFFLICTION', 'author': 'Laurell K Hamilton', 'publisher': 'Berkley', 'description': 'The vampire hunter Anita Blake encounters a dangerous new breed of zombies.\xa0', 'Amazon_url': 'http://www.amazon.com/Affliction-Anita-Blake-Vampire-Hunter/dp/0425255700?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2013-07-21', 'last_date_listed': '2013-07-28', 'weeks_on_list': 2, 'worst_rank': 5, 'best_rank': 15, 'Amazon_reviews': 1372.0, 'Amazon_rating': 4.3, 'NYT_price': 0.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea2'), 'Unnamed: 0': 52, 'title': 'AFTER ALICE', 'author': 'Gregory Maguire', 'publisher': 'Morrow', 'description': nan, 'Amazon_url': 'http://www.amazon.com/After-Alice-Novel-Gregory-Maguire/dp/0060548959?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2015-11-15', 'last_date_listed': '2016-01-17', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 17, 'Amazon_reviews': nan, 'Amazon_rating': 3.4, 'NYT_price': 0.0, 'Amazon_price': 12.92, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea3'), 'Unnamed: 0': 53, 'title': 'AFTER DEAD', 'author': 'Charlaine Harris', 'publisher': 'Ace', 'description': 'A coda to the Sookie Stackhouse novels that inspired “True Blood.”', 'Amazon_url': 'http://www.amazon.com/After-Dead-World-Sookie-Stackhouse-ebook/dp/B00BDQ3B4W?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2013-11-17', 'last_date_listed': '2013-11-24', 'weeks_on_list': 1, 'worst_rank': 2, 'best_rank': 19, 'Amazon_reviews': 1584.0, 'Amazon_rating': 2.1, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea4'), 'Unnamed: 0': 54, 'title': "AFTER I'M GONE", 'author': 'Laura Lippman', 'publisher': 'Morrow', 'description': nan, 'Amazon_url': 'http://www.amazon.com/After-Im-Gone-A-Novel/dp/0062083392?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2014-03-02', 'last_date_listed': '2014-03-09', 'weeks_on_list': 0, 'worst_rank': 18, 'best_rank': 18, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea5'), 'Unnamed: 0': 55, 'title': 'AFTER THE STORM', 'author': 'Linda Castillo', 'publisher': 'Minotaur', 'description': nan, 'Amazon_url': 'http://www.amazon.com/After-Storm-Kate-Burkholder-Novel/dp/1250061563?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2015-08-02', 'last_date_listed': '2015-08-02', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 20, 'Amazon_reviews': 520.0, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': 8.49, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea6'), 'Unnamed: 0': 56, 'title': 'AFTER YOU', 'author': 'Jojo Moyes', 'publisher': 'Pamela Dorman/Viking', 'description': 'In a sequel to “Me Before You,” Louisa Clark tries to put her life back together after the death of Will Traynor.', 'Amazon_url': 'http://www.amazon.com/After-You-Novel-Jojo-Moyes/dp/0525426590?tag=NYTBS-20', 'times_listed': 28, 'first_date_listed': '2015-10-18', 'last_date_listed': '2016-07-31', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 11, 'Amazon_reviews': 5201.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 11.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea7'), 'Unnamed: 0': 57, 'title': 'STAR WARS: AFTERMATH', 'author': 'Chuck Wendig', 'publisher': 'Del Rey', 'description': 'The Imperial elite haven’t reckoned on the former rebel fighter Norra Wexley.', 'Amazon_url': 'http://www.amazon.com/Aftermath-Star-Journey-Force-Awakens/dp/034551162X?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2015-09-20', 'last_date_listed': '2016-01-10', 'weeks_on_list': 3, 'worst_rank': 5, 'best_rank': 16, 'Amazon_reviews': 2783.0, 'Amazon_rating': 2.9, 'NYT_price': 0.0, 'Amazon_price': 17.32, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea8'), 'Unnamed: 0': 58, 'title': 'AGAINST ALL ENEMIES', 'author': 'Tom Clancy with Peter Telep', 'publisher': 'Putnam', 'description': 'Maxwell Moore, a former C.I.A. officer, pursues the terrorists who killed his colleagues in a bomb attack off the coast of Pakistan.', 'Amazon_url': 'http://www.amazon.com/Against-All-Enemies-Tom-Clancy/dp/042524606X?tag=NYTBS-20', 'times_listed': 9, 'first_date_listed': '2011-07-03', 'last_date_listed': '2011-08-28', 'weeks_on_list': 7, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 620.0, 'Amazon_rating': 3.4, 'NYT_price': 28.95, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 34.51}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ea9'), 'Unnamed: 0': 59, 'title': 'AGAINST ALL THINGS ENDING', 'author': 'Stephen R Donaldson', 'publisher': 'Putnam', 'description': 'The resurrection of Thomas Covenant has awakened the Worm of the World’s End.', 'Amazon_url': 'http://www.amazon.com/Against-Things-Ending-Chronicles-Covenant/dp/039915678X?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2010-11-07', 'last_date_listed': '2010-11-07', 'weeks_on_list': 1, 'worst_rank': 15, 'best_rank': 15, 'Amazon_reviews': 293.0, 'Amazon_rating': 3.8, 'NYT_price': 29.95, 'Amazon_price': 27.37, 'Amazon_price_as%_NYT_price': 91.39}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eaa'), 'Unnamed: 0': 60, 'title': 'AGENDA 21', 'author': 'Glenn Beck with Harriet Parke', 'publisher': 'Threshold Editions/Mercury Radio Arts', 'description': 'A girl questions authority in the U.N.-created totalitarian successor to the United States.', 'Amazon_url': 'http://www.amazon.com/Agenda-21-Glenn-Beck-ebook/dp/B00902UC0W?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2012-12-09', 'last_date_listed': '2013-01-13', 'weeks_on_list': 5, 'worst_rank': 8, 'best_rank': 12, 'Amazon_reviews': 2880.0, 'Amazon_rating': 4.5, 'NYT_price': 26.0, 'Amazon_price': 9.49, 'Amazon_price_as%_NYT_price': 36.5}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eab'), 'Unnamed: 0': 61, 'title': 'AGENDA 21: INTO THE SHADOWS', 'author': 'Glenn Beck with Harriet Parke', 'publisher': 'Threshold Editions', 'description': nan, 'Amazon_url': 'http://www.amazon.com/Agenda-21-Shadows-Glenn-Beck/dp/1476746826?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2015-01-25', 'last_date_listed': '2015-01-25', 'weeks_on_list': 0, 'worst_rank': 18, 'best_rank': 18, 'Amazon_reviews': 2880.0, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': 13.5, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eac'), 'Unnamed: 0': 62, 'title': 'AGINCOURT', 'author': 'Bernard Cornwell', 'publisher': 'Harper', 'description': 'An English archer with a complicated past joins Henry V at the famous battle against the French in 1415.', 'Amazon_url': 'http://www.amazon.com/Agincourt-Bernard-Cornwell/dp/0061578916?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2009-02-08', 'last_date_listed': '2009-03-08', 'weeks_on_list': 4, 'worst_rank': 7, 'best_rank': 10, 'Amazon_reviews': 609.0, 'Amazon_rating': 4.3, 'NYT_price': 27.99, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': 46.41}
# {'_id': ObjectId('5c85a280bd7b6a02852b8ead'), 'Unnamed: 0': 63, 'title': 'AGONY OF THE LEAVES', 'author': 'Laura Childs', 'publisher': 'Berkley', 'description': nan, 'Amazon_url': 'http://www.amazon.com/Agony-Leaves-Tea-Shop-Mystery/dp/0425245535?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2012-03-25', 'last_date_listed': '2012-03-25', 'weeks_on_list': 0, 'worst_rank': 20, 'best_rank': 20, 'Amazon_reviews': 143.0, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': 9.89, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eae'), 'Unnamed: 0': 64, 'title': 'AIMLESS LOVE', 'author': 'Billy Collins', 'publisher': 'Random House', 'description': 'More than 50 new poems as well as selections from previous books from the two-term poet laureate of the Untied States.', 'Amazon_url': 'http://www.amazon.com/Aimless-Love-New-Selected-Poems/dp/0679644059?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2013-11-10', 'last_date_listed': '2013-12-01', 'weeks_on_list': 3, 'worst_rank': 18, 'best_rank': 12, 'Amazon_reviews': 256.0, 'Amazon_rating': 4.8, 'NYT_price': 0.0, 'Amazon_price': 16.86, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eaf'), 'Unnamed: 0': 65, 'title': 'ALEPH', 'author': 'Paulo Coelho', 'publisher': 'Knopf', 'description': 'A crisis of faith is the impetus for a journey through time and space, on a path that teaches love, forgiveness and courage.', 'Amazon_url': 'http://www.amazon.com/Aleph-Paulo-Coelho/dp/0307700186?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2011-10-16', 'last_date_listed': '2011-10-23', 'weeks_on_list': 2, 'worst_rank': 7, 'best_rank': 6, 'Amazon_reviews': 451.0, 'Amazon_rating': 4.2, 'NYT_price': 24.95, 'Amazon_price': 2.99, 'Amazon_price_as%_NYT_price': 11.98}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb0'), 'Unnamed: 0': 66, 'title': 'ALERT', 'author': 'James Patterson and Michael Ledwidge', 'publisher': 'Little, Brown', 'description': "Detective Michael Bennett and the F.B.I.'s Emily Parker must save New York City from a deadly threat.", 'Amazon_url': 'http://www.amazon.com/Alert-Michael-Bennett-James-Patterson/dp/0316407178?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2015-08-23', 'last_date_listed': '2015-09-27', 'weeks_on_list': 5, 'worst_rank': 9, 'best_rank': 15, 'Amazon_reviews': 1494.0, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': 16.98, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb1'), 'Unnamed: 0': 67, 'title': 'ALEX CROSS, RUN', 'author': 'James Patterson', 'publisher': 'Little, Brown', 'description': "While Detective Alex Cross pursues a serial killer (or killers?) in Washington, D.C., he's too busy to notice that someone has been watching him.", 'Amazon_url': 'http://www.amazon.com/Alex-Cross-Run-James-Patterson-ebook/dp/B0076DCP16?tag=NYTBS-20', 'times_listed': 9, 'first_date_listed': '2013-03-10', 'last_date_listed': '2013-05-05', 'weeks_on_list': 8, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 2939.0, 'Amazon_rating': 4.5, 'NYT_price': 28.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 34.46}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb2'), 'Unnamed: 0': 68, 'title': 'ALEX CROSS’S ‘TRIAL’', 'author': 'James Patterson and Richard DiLallo', 'publisher': 'Little, Brown', 'description': 'The detective Alex Cross writes a novel about his great-uncle, who fought the Klan.', 'Amazon_url': 'http://www.amazon.com/Alex-Crosss-Trial-James-Patterson/dp/0446557781?tag=NYTBS-20', 'times_listed': 7, 'first_date_listed': '2009-09-13', 'last_date_listed': '2009-10-25', 'weeks_on_list': 6, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 1754.0, 'Amazon_rating': 4.4, 'NYT_price': 27.99, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': 35.69}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb3'), 'Unnamed: 0': 69, 'title': 'ALL DRESSED IN WHITE', 'author': 'Mary Higgins Clark and Alafair Burke', 'publisher': 'Simon & Schuster', 'description': 'A TV producer investigates a bride’s disappearance for her show, “Under Suspicion.”', 'Amazon_url': 'http://www.amazon.com/All-Dressed-White-Under-Suspicion-ebook/dp/B00UDCI30E?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2015-12-06', 'last_date_listed': '2015-12-27', 'weeks_on_list': 2, 'worst_rank': 7, 'best_rank': 12, 'Amazon_reviews': 1200.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb4'), 'Unnamed: 0': 70, 'title': 'ALL FALL DOWN', 'author': 'Jennifer Weiner', 'publisher': 'Atria', 'description': 'A woman becomes addicted to pain medication.', 'Amazon_url': 'http://www.amazon.com/All-Fall-Down-A-Novel-ebook/dp/B00DPM909W?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2014-07-06', 'last_date_listed': '2014-08-03', 'weeks_on_list': 5, 'worst_rank': 8, 'best_rank': 11, 'Amazon_reviews': 1401.0, 'Amazon_rating': 4.1, 'NYT_price': 0.0, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb5'), 'Unnamed: 0': 71, 'title': "THE ALL-GIRL FILLING STATION'S LAST REUNION", 'author': 'Fannie Flagg', 'publisher': 'Random House', 'description': "An Alabama woman's search for her true identity takes her all the way to Wisconsin and into the lives of four sisters who ran their father’s gas station during World War II.", 'Amazon_url': 'http://www.amazon.com/All-Girl-Filling-Stations-Last-Reunion-ebook/dp/B00CQZ6EKW?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2013-11-24', 'last_date_listed': '2013-12-29', 'weeks_on_list': 4, 'worst_rank': 6, 'best_rank': 10, 'Amazon_reviews': 4401.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb6'), 'Unnamed: 0': 72, 'title': 'ALL THE LIGHT WE CANNOT SEE', 'author': 'Anthony Doerr', 'publisher': 'Scribner', 'description': 'The lives of a blind French girl and a gadget-obsessed German boy before and during World War II; the winner of the 2015 Pulitzer Prize. \xa0', 'Amazon_url': 'http://www.amazon.com/All-Light-We-Cannot-See/dp/1476746583?tag=NYTBS-20', 'times_listed': 141, 'first_date_listed': '2014-05-25', 'last_date_listed': '2017-01-29', 'weeks_on_list': 99, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 28454.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb7'), 'Unnamed: 0': 73, 'title': 'ALL THE LITTLE LIARS', 'author': 'Charlaine Harris', 'publisher': 'Minotaur', 'description': nan, 'Amazon_url': 'http://www.amazon.com/All-Little-Liars-Teagarden-Mysteries/dp/1250090032?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2016-10-23', 'last_date_listed': '2016-10-23', 'weeks_on_list': 0, 'worst_rank': 19, 'best_rank': 19, 'Amazon_reviews': 298.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb8'), 'Unnamed: 0': 74, 'title': 'ALL THE OLD KNIVES', 'author': 'Olen Steinhauer', 'publisher': 'Minotaur', 'description': 'A C.I.A. case officer meets with a former colleague and lover to try to understand a massacre in Vienna in 2006.', 'Amazon_url': 'http://www.amazon.com/All-Old-Knives-A-Novel/dp/1250045428?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2015-03-29', 'last_date_listed': '2015-03-29', 'weeks_on_list': 1, 'worst_rank': 15, 'best_rank': 15, 'Amazon_reviews': nan, 'Amazon_rating': 3.9, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eb9'), 'Unnamed: 0': 75, 'title': 'ALL THE SINGLE LADIES', 'author': 'Dorothea Benton Frank', 'publisher': 'Morrow/HarperCollins', 'description': 'Three friends in South Carolina’s Lowcountry grapple with the challenges of being unmarried.', 'Amazon_url': 'http://www.amazon.com/All-Single-Ladies-A-Novel-ebook/dp/B00NEOM5FM?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2015-06-28', 'last_date_listed': '2015-07-19', 'weeks_on_list': 3, 'worst_rank': 6, 'best_rank': 11, 'Amazon_reviews': 946.0, 'Amazon_rating': 4.1, 'NYT_price': 0.0, 'Amazon_price': 11.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b8eba'), 'Unnamed: 0': 76, 'title': 'ALL THE STARS IN THE HEAVENS', 'author': 'Adriana Trigiani', 'publisher': 'Harper', 'description': 'A fictional treatment of the life of the actress Loretta Young focuses on her rumored affair with the married Clark Gable and her subsequent pregnancy.', 'Amazon_url': 'http://www.amazon.com/All-Stars-Heavens-A-Novel-ebook/dp/B00SG0G27G?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2015-11-01', 'last_date_listed': '2015-11-01', 'weeks_on_list': 1, 'worst_rank': 14, 'best_rank': 14, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# ...
# {'_id': ObjectId('5c85a280bd7b6a02852b976e'), 'Unnamed: 0': 2304, 'title': 'UNCOMMON TYPE', 'author': 'Tom Hanks', 'publisher': 'Knopf', 'description': 'Seventeen short stories, each incorporating a typewriter, by the Academy Award-winning actor.', 'Amazon_url': 'https://www.amazon.com/Uncommon-Type-Stories-Tom-Hanks/dp/1101946156?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2017-11-05', 'last_date_listed': '2018-01-07', 'weeks_on_list': 9, 'worst_rank': 5, 'best_rank': 10, 'Amazon_reviews': 382.0, 'Amazon_rating': 4.0, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b976f'), 'Unnamed: 0': 2305, 'title': 'UNIVERSAL HARVESTER', 'author': 'John Darnielle', 'publisher': 'Farrar, Straus & Giroux', 'description': 'A mystery/thriller set in Iowa.', 'Amazon_url': 'https://www.amazon.com/Universal-Harvester-Novel-John-Darnielle/dp/0374282102?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-02-26', 'last_date_listed': '2017-02-26', 'weeks_on_list': 1, 'worst_rank': 10, 'best_rank': 10, 'Amazon_reviews': 190.0, 'Amazon_rating': 3.0, 'NYT_price': 0.0, 'Amazon_price': 14.98, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9770'), 'Unnamed: 0': 2306, 'title': 'US AGAINST YOU', 'author': 'Fredrik Backman', 'publisher': 'Atria', 'description': 'Beartown’s hockey team gets a new coach and their rivalry with a neighboring team escalates.', 'Amazon_url': 'https://www.amazon.com/Us-Against-You-Novel-Beartown/dp/1501160796?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2018-06-24', 'last_date_listed': '2018-06-24', 'weeks_on_list': 1, 'worst_rank': 9, 'best_rank': 9, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b9771'), 'Unnamed: 0': 2307, 'title': 'USE OF FORCE', 'author': 'Brad Thor', 'publisher': 'Atria/Emily Bestler', 'description': 'The counterterrorism operative Scot Harvath is called in when a missing terrorism suspect drowns off the Italian coast.', 'Amazon_url': 'https://www.amazon.com/Use-Force-Thriller-Scot-Harvath-ebook/dp/B01M2BRLHB?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2017-07-16', 'last_date_listed': '2017-08-13', 'weeks_on_list': 5, 'worst_rank': 8, 'best_rank': 11, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b9772'), 'Unnamed: 0': 2308, 'title': 'VARINA', 'author': 'Charles Frazier', 'publisher': 'Ecco', 'description': 'As the Confederacy and her marriage to Jefferson Davis fall apart, a woman flees Richmond with her children.', 'Amazon_url': 'https://www.amazon.com/Varina-Novel-Charles-Frazier/dp/0062405985?tag=NYTBS-20', 'times_listed': 2, 'first_date_listed': '2018-04-22', 'last_date_listed': '2018-04-29', 'weeks_on_list': 2, 'worst_rank': 13, 'best_rank': 10, 'Amazon_reviews': 293.0, 'Amazon_rating': 4.0, 'NYT_price': 0.0, 'Amazon_price': 15.59, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9773'), 'Unnamed: 0': 2309, 'title': 'VICIOUS CIRCLE', 'author': 'C J Box', 'publisher': 'Putnam', 'description': 'Newly released from prison, Dallas Cates tries to exact revenge on the Wyoming game warden Joe Pickett, who put him there.', 'Amazon_url': 'https://www.amazon.com/Vicious-Circle-Joe-Pickett-Novel-ebook/dp/B01HYUVHIM?tag=NYTBS-20', 'times_listed': 3, 'first_date_listed': '2017-04-09', 'last_date_listed': '2017-04-23', 'weeks_on_list': 3, 'worst_rank': 4, 'best_rank': 11, 'Amazon_reviews': 979.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9774'), 'Unnamed: 0': 2310, 'title': 'THE WANTED', 'author': 'Robert Crais', 'publisher': 'Putnam', 'description': 'A single mother hires Elvis Cole to investigate her teenage son who is on the run after a deadly crime spree.', 'Amazon_url': 'https://www.amazon.com/Wanted-Elvis-Cole-Joe-Pike-ebook/dp/B01M09NRYP?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2018-01-14', 'last_date_listed': '2018-01-14', 'weeks_on_list': 1, 'worst_rank': 9, 'best_rank': 9, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b9775'), 'Unnamed: 0': 2311, 'title': 'WARLIGHT', 'author': 'Michael Ondaatje', 'publisher': 'Knopf', 'description': 'In Britain after World War II, a pair of teenage siblings are taken under the tutelage of a mysterious man.', 'Amazon_url': 'https://www.amazon.com/Warlight-novel-Michael-Ondaatje/dp/0525521194?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2018-05-27', 'last_date_listed': '2018-06-17', 'weeks_on_list': 4, 'worst_rank': 9, 'best_rank': 15, 'Amazon_reviews': 479.0, 'Amazon_rating': 3.9, 'NYT_price': 0.0, 'Amazon_price': 18.31, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9776'), 'Unnamed: 0': 2312, 'title': 'WATCH ME DISAPPEAR', 'author': 'Janelle Brown', 'publisher': 'Spiegel & Grau', 'description': 'When a Berkeley woman vanishes after a hiking trip, her husband and daughter discover disturbing secrets.', 'Amazon_url': 'https://www.amazon.com/Watch-Me-Disappear-Janelle-Brown/dp/0812989465?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-08-06', 'last_date_listed': '2017-08-06', 'weeks_on_list': 1, 'worst_rank': 13, 'best_rank': 13, 'Amazon_reviews': nan, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b9777'), 'Unnamed: 0': 2313, 'title': 'THE WESTERN STAR', 'author': 'Craig Johnson', 'publisher': 'Viking', 'description': 'The 13th Walt Longmire novel. A parole hearing of a serial killer and the decades-old memory of a train ride with Wyoming sheriffs put Longmire on a collision course between past and present.', 'Amazon_url': 'https://www.amazon.com/Western-Star-Longmire-Mystery-ebook/dp/B01N2AAPVU?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-09-24', 'last_date_listed': '2017-09-24', 'weeks_on_list': 1, 'worst_rank': 7, 'best_rank': 7, 'Amazon_reviews': 964.0, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b9778'), 'Unnamed: 0': 2314, 'title': 'WHEN LIFE GIVES YOU LULULEMONS', 'author': 'Lauren Weisberger', 'publisher': 'Simon & Schuster', 'description': 'Emily Charlton plans a comeback from the suburbs. From the author of "The Devil Wears Prada."', 'Amazon_url': 'https://www.amazon.com/When-Life-Gives-You-Lululemons-ebook/dp/B078MC8G1X?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2018-06-24', 'last_date_listed': '2018-07-22', 'weeks_on_list': 5, 'worst_rank': 9, 'best_rank': 10, 'Amazon_reviews': 518.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9779'), 'Unnamed: 0': 2315, 'title': 'TO BE WHERE YOU ARE', 'author': 'Jan Karon', 'publisher': 'Putnam', 'description': 'The 14th novel in the Mitford series. Three generations of Kavanaghs face changes in their lives.', 'Amazon_url': 'https://www.amazon.com/Where-You-Are-Mitford-Novel/dp/0399183736?tag=NYTBS-20', 'times_listed': 4, 'first_date_listed': '2017-10-08', 'last_date_listed': '2017-10-29', 'weeks_on_list': 4, 'worst_rank': 7, 'best_rank': 11, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': 17.5, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b977a'), 'Unnamed: 0': 2316, 'title': 'THE WHISPERING ROOM', 'author': 'Dean Koontz', 'publisher': 'Bantam', 'description': 'Former F.B.I. agent and wanted fugitive Jane Hawk tracks down a group that is brainwashing people into committing suicide.', 'Amazon_url': 'https://www.amazon.com/Whispering-Room-Jane-Hawk-Novel-ebook/dp/B071CJBDJL?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-12-10', 'last_date_listed': '2017-12-10', 'weeks_on_list': 1, 'worst_rank': 11, 'best_rank': 11, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'NYT_price': 0.0, 'Amazon_price': nan, 'Amazon_price_as%_NYT_price': nan}
# {'_id': ObjectId('5c85a280bd7b6a02852b977b'), 'Unnamed: 0': 2317, 'title': 'THE WHISTLER', 'author': 'John Grisham', 'publisher': 'Doubleday', 'description': 'A whistleblower alerts a Florida investigator to judicial corruption involving the Mob and Indian casinos.', 'Amazon_url': 'https://www.amazon.com/Whistler-John-Grisham-ebook/dp/B01C1LUFFK?tag=NYTBS-20', 'times_listed': 22, 'first_date_listed': '2016-11-13', 'last_date_listed': '2017-04-09', 'weeks_on_list': 9, 'worst_rank': 8, 'best_rank': 1, 'Amazon_reviews': 7783.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b977c'), 'Unnamed: 0': 2318, 'title': "THE WHOLE TOWN'S TALKING", 'author': 'Fannie Flagg', 'publisher': 'Random House', 'description': 'A century of life in small-town Elmwood Springs, Mo.', 'Amazon_url': 'https://www.amazon.com/Whole-Towns-Talking-Novel/dp/140006595X?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2016-12-18', 'last_date_listed': '2017-01-15', 'weeks_on_list': 3, 'worst_rank': 19, 'best_rank': 10, 'Amazon_reviews': 1240.0, 'Amazon_rating': 3.9, 'NYT_price': 0.0, 'Amazon_price': 12.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b977d'), 'Unnamed: 0': 2319, 'title': 'THE WIFE BETWEEN US', 'author': 'Greer Hendricks and Sarah Pekkanen', 'publisher': "St. Martin's", 'description': 'The story of a love triangle is told from several points of view.', 'Amazon_url': 'https://www.amazon.com/Wife-Between-Us-Novel/dp/1250130921?tag=NYTBS-20', 'times_listed': 10, 'first_date_listed': '2018-01-28', 'last_date_listed': '2018-04-01', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 11, 'Amazon_reviews': 2516.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b977e'), 'Unnamed: 0': 2320, 'title': 'WINTER SOLSTICE', 'author': 'Elin Hilderbrand', 'publisher': 'Little, Brown', 'description': 'The Quinns celebrate the holidays when one family member returns from the war in Afghanistan but the gathering turns rocky.', 'Amazon_url': 'https://www.amazon.com/Winter-Solstice-Street-Elin-Hilderbrand-ebook/dp/B01N193KPV?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-10-22', 'last_date_listed': '2017-10-22', 'weeks_on_list': 1, 'worst_rank': 13, 'best_rank': 13, 'Amazon_reviews': 317.0, 'Amazon_rating': 4.6, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b977f'), 'Unnamed: 0': 2321, 'title': 'WIRED', 'author': 'Julie Garwood', 'publisher': 'Berkley', 'description': 'An F.B.I. agent recruits an idealistic (and beautiful) hacker to help him find a leaker.', 'Amazon_url': 'https://www.amazon.com/Wired-Buchanan-Fbi-Julie-Garwood/dp/0525954465?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-07-23', 'last_date_listed': '2017-07-23', 'weeks_on_list': 1, 'worst_rank': 7, 'best_rank': 7, 'Amazon_reviews': 791.0, 'Amazon_rating': 4.2, 'NYT_price': 0.0, 'Amazon_price': 7.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9780'), 'Unnamed: 0': 2322, 'title': 'WITHOUT WARNING', 'author': 'Joel C Rosenberg', 'publisher': 'Tyndale House', 'description': 'A journalist pursues the head of ISIS after an attack on the Capitol when the administration fails to take action.', 'Amazon_url': 'https://www.amazon.com/Without-Warning-J-B-Collins-Novel/dp/1496406168?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-04-02', 'last_date_listed': '2017-04-02', 'weeks_on_list': 1, 'worst_rank': 6, 'best_rank': 6, 'Amazon_reviews': 1113.0, 'Amazon_rating': 4.8, 'NYT_price': 0.0, 'Amazon_price': 14.95, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9781'), 'Unnamed: 0': 2323, 'title': 'THE WOMAN IN THE WINDOW', 'author': 'AJ Finn', 'publisher': 'Morrow', 'description': 'A recluse who drinks heavily and takes prescription drugs may have witnessed a crime across from her Harlem townhouse.', 'Amazon_url': 'https://www.amazon.com/Woman-Window-Novel-J-Finn/dp/0062678418?tag=NYTBS-20', 'times_listed': 23, 'first_date_listed': '2018-01-21', 'last_date_listed': '2018-07-15', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 5160.0, 'Amazon_rating': 4.3, 'NYT_price': 0.0, 'Amazon_price': 13.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9782'), 'Unnamed: 0': 2324, 'title': 'THE WOMEN IN THE CASTLE', 'author': 'Jessica Shattuck', 'publisher': 'Morrow/HarperCollins', 'description': 'The widows of three men killed for attempting to assassinate Hitler take refuge together at the war’s end.', 'Amazon_url': 'https://www.amazon.com/Women-Castle-Novel-Jessica-Shattuck/dp/0062563661?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2017-04-16', 'last_date_listed': '2017-05-28', 'weeks_on_list': 6, 'worst_rank': 7, 'best_rank': 10, 'Amazon_reviews': 983.0, 'Amazon_rating': 4.3, 'NYT_price': 0.0, 'Amazon_price': 11.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9783'), 'Unnamed: 0': 2325, 'title': 'THE WRONG SIDE OF GOODBYE', 'author': 'Michael Connelly', 'publisher': 'Little, Brown', 'description': 'he detective Harry Bosch helps a small police department track a serial rapist, while as a P.I. he aids a billionaire in search of a possible heir.', 'Amazon_url': 'https://www.amazon.com/Wrong-Goodbye-Harry-Bosch-Novel-ebook/dp/B01BU1ITMI?tag=NYTBS-20', 'times_listed': 12, 'first_date_listed': '2016-11-20', 'last_date_listed': '2017-02-05', 'weeks_on_list': 9, 'worst_rank': 9, 'best_rank': 10, 'Amazon_reviews': 5977.0, 'Amazon_rating': 4.7, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9784'), 'Unnamed: 0': 2326, 'title': 'Y IS FOR YESTERDAY', 'author': 'Sue Grafton', 'publisher': 'Marian Wood/Putnam', 'description': 'The 25th Kinsey Millhone mystery novel. A former student from an elite private school is released from prison and a sociopath returns to haunt the detective.', 'Amazon_url': 'https://www.amazon.com/Y-Yesterday-Kinsey-Millhone-Novel-ebook/dp/B01MUBJLNC?tag=NYTBS-20', 'times_listed': 6, 'first_date_listed': '2017-09-10', 'last_date_listed': '2017-10-15', 'weeks_on_list': 6, 'worst_rank': 9, 'best_rank': 1, 'Amazon_reviews': 3127.0, 'Amazon_rating': 4.3, 'NYT_price': 0.0, 'Amazon_price': 9.99, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9785'), 'Unnamed: 0': 2327, 'title': 'YEAR ONE', 'author': 'Nora Roberts', 'publisher': "St. Martin's", 'description': 'When a pandemic strikes and the world spins into chaos, several travelers head west to find a new life.', 'Amazon_url': 'https://www.amazon.com/Year-One-Chronicles-Book/dp/1250122953?tag=NYTBS-20', 'times_listed': 5, 'first_date_listed': '2017-12-24', 'last_date_listed': '2018-01-21', 'weeks_on_list': 5, 'worst_rank': 7, 'best_rank': 11, 'Amazon_reviews': 3186.0, 'Amazon_rating': 4.5, 'NYT_price': 0.0, 'Amazon_price': 15.47, 'Amazon_price_as%_NYT_price': inf}
# {'_id': ObjectId('5c85a280bd7b6a02852b9786'), 'Unnamed: 0': 2328, 'title': 'YOU WILL PAY', 'author': 'Lisa Jackson', 'publisher': 'Kensington', 'description': 'Twenty years later, survivors probe the disappearance of two teenage girls from a religious camp.', 'Amazon_url': 'https://www.amazon.com/You-Will-Pay-Lisa-Jackson/dp/1617734667?tag=NYTBS-20', 'times_listed': 1, 'first_date_listed': '2017-06-18', 'last_date_listed': '2017-06-18', 'weeks_on_list': 1, 'worst_rank': 14, 'best_rank': 14, 'Amazon_reviews': 202.0, 'Amazon_rating': 3.7, 'NYT_price': 0.0, 'Amazon_price': 14.49, 'Amazon_price_as%_NYT_price': inf}

# %% [markdown]
# ## What can we do with this data?
#
# We could use this data along two axes:
#
# ##### ANALYSIS AND VISUALIZATION:
# We can look for statistically significant correlations between some of our variables. For exmaple, we could do data visualization examining any significant correlation between number of reviews and ratings, or number of reviews and Amazon discounts, weeks on the list and price discount, etc.
#
# ##### BUILD AN APPLICATION FOR BOOKWORMS(!):
# - This data could be used to build a Flask app. For example, we could render the data sorting it by best deals, or number of reviews, or blockbusters (the bestsellers that lasted the longest on the list).
# - We could also build queries to search for books by keywords in the description, and render the results via Flask.
# - We could also render the results from our previous analysis.
