# %% [markdown]
# ### Extract data from kaggle's file 'nyt2.json'

# %%
# Import dependencies needed
import json
import pandas as pd
from pprint import pprint

# %%
# Load 'nyt2.json' file into dataframe:
raw_nyt = pd.read_json('Resources/nyt2.json', lines=True, orient='columns')
#raw_nyt.head()

# %%
# Save DataFrame 'raw_nyt' into a json file ('output.json') and load it as 'data' we can now work with:
raw_nyt.to_json(path_or_buf='output.json', orient = "records")
with open('output.json') as file:
    data = json.load(file)
#pprint(data)

# %%
# Set up lists to hold reponse info:

nyt_ids = []
urls = []
authors = []
bestsellers_dates = []
descriptions = []
prices = []
published_dates = []
publishers = []
ranks = []
ranks_last_week = []
titles = []
weeks_on_lists = []

# Populate the lists:

for item in data:
    nyt_ids.append(item['_id']['$oid'])
    urls.append(item['amazon_product_url'])
    authors.append(item['author'])
    bestsellers_dates.append(item['bestsellers_date']['$date']['$numberLong'])
    descriptions.append(item['description'])
    published_dates.append(item['published_date']['$date']['$numberLong'])
    publishers.append(item['publisher'])
    ranks.append(item['rank']['$numberInt'])
    ranks_last_week.append(item['rank_last_week']['$numberInt'])
    titles.append(item['title'])
    weeks_on_lists.append(item['weeks_on_list']['$numberInt'])
# Here we have to check for the correct keyname before we can extract the price string:
    price_key, = item['price'].keys()
    if price_key == '$numberInt' or price_key == '$numberDouble':
        prices.append(item['price'][price_key])

# %%
# Create a DataFrame from the lists

bestsellers_dict = {
    "nyt_id": nyt_ids,
    "title": titles,
    "author": authors,
    "url": urls,
    "publisher": publishers,
    "description": descriptions,
    "list_price": prices,
    "published_date": published_dates,
    "bestseller_date": bestsellers_dates,
    "rank": ranks,
    "rank_last_week": ranks_last_week,
    "weeks_on_list": weeks_on_lists
}
bestsellers_data = pd.DataFrame(bestsellers_dict)
#bestsellers_data.head()

# %% [markdown]
# ### Extract info from amazon
#
# In this step, for each unique URL from our bestsellers dataframe, we collect the Amazon listing price, number of customer reviews, and average 5-star rating, and thumbnail image for the book cover.

# %%
# Import dependencies needed
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
# Remove duplicates from list of amazon urls
amazon_urls = list(dict.fromkeys(urls))
len(amazon_urls)
# Out:
# 2329

# %%
# Set-up lists to store scraped info and user-defined functions for the iterations

reviews = []
ratings = []
offers = []
img_urls = []

# %%
def get_nb_reviews(x_url):
    if x_url not in [url for (url, _) in reviews]:
        response = requests.get(x_url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        review = soup.find_all('span', id="acrCustomerReviewText")[0].text
        reviews.append((url, review))

def get_rating(x_url):
    if x_url not in [url for (url, _) in ratings]:
        response = requests.get(x_url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        rating = soup.find('span', class_="a-icon-alt").text
        ratings.append((url, rating))

def get_offer(x_url):
    if x_url not in [url for (url, _) in offers]:
        response = requests.get(x_url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        offer = soup.find('span', class_="a-size-medium a-color-price offer-price a-text-normal").text
        offers.append((url, offer))

def get_img(x_url):
    if x_url not in [url for (url, _) in img_urls]:
        response = requests.get(x_url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        img_url = soup.find('div', id='img-canvas').find('img')['data-a-dynamic-image']
        img_urls.append((url, img_url))

# %%
search_urls = amazon_urls

# %%
# extract info from amazon using requests

missing_urls = []
for url in search_urls:
    try:
        get_img(url)
        get_offer(url)
        get_rating(url)
        get_nb_reviews(url)
        print(url)
    except (AttributeError, RuntimeError, TypeError, NameError, IndexError):
        print("error")
        missing_urls.append(url)
search_urls = missing_urls
# Out:
# http://www.amazon.com/Odd-Hours-Dean-Koontz/dp/0553807056?tag=NYTBS-20
# http://www.amazon.com/The-Host-Novel-Stephenie-Meyer/dp/0316218502?tag=NYTBS-20
# http://www.amazon.com/Love-Youre-With-Emily-Giffin/dp/0312348665?tag=NYTBS-20
# error
# http://www.amazon.com/Snuff-Chuck-Palahniuk/dp/0385517882?tag=NYTBS-20
# http://www.amazon.com/Sundays-at-Tiffanys-James-Patterson/dp/0446199443?tag=NYTBS-20
# http://www.amazon.com/Phantom-Prey-John-Sandford/dp/0425227987?tag=NYTBS-20
# http://www.amazon.com/From-Worse-Southern-Vampire-Mysteries/dp/0441015891?tag=NYTBS-20
# http://www.amazon.com/Where-Are-You-Now-Novel/dp/1416566384?tag=NYTBS-20
# http://www.amazon.com/The-Whole-Truth-David-Baldacci/dp/0446539686?tag=NYTBS-20
# http://www.amazon.com/Careless-Red-Novel-Elizabeth-George/dp/0061160873?tag=NYTBS-20
# http://www.amazon.com/Unaccustomed-Earth-Jhumpa-Lahiri/dp/0307265730?tag=NYTBS-20
# error
# http://www.amazon.com/Twenty-Wishes-Blossom-Street-Books/dp/0778326314?tag=NYTBS-20
# http://www.amazon.com/Hold-Tight-Harlan-Coben/dp/0525950605?tag=NYTBS-20
# http://www.amazon.com/Executive-Privilege-Novel-Phillip-Margolin/dp/0061236217?tag=NYTBS-20
# http://www.amazon.com/Unaccustomed-Vintage-Contemporaries-Jhumpa-Lahiri/dp/0307278255?tag=NYTBS-20
# http://www.amazon.com/Netherland-A-Novel-Joseph-ONeill/dp/0307377040?tag=NYTBS-20
# http://www.amazon.com/The-Appeal-John-Grisham/dp/0440243815?tag=NYTBS-20
# http://www.amazon.com/Indiana-Jones-Kingdom-Crystal-Skull/dp/0345501284?tag=NYTBS-20
# http://www.amazon.com/Blood-Anita-Blake-Vampire-Hunter/dp/0515146374?tag=NYTBS-20
# http://www.amazon.com/Chasing-Harry-Winston-A-Novel/dp/0743290119?tag=NYTBS-20
# http://www.amazon.com/Devil-Care-James-Bond-Novel/dp/0385524285?tag=NYTBS-20
# http://www.amazon.com/Shadow-Power-Paul-Madriani-Novel/dp/B001OW5OR2?tag=NYTBS-20
# http://www.amazon.com/Blue-Smoke-Murder-Elizabeth-Lowell/dp/0060829869?tag=NYTBS-20
# http://www.amazon.com/The-Enchantress-Florence-A-Novel/dp/0679640517?tag=NYTBS-20
# error
# http://www.amazon.com/Plague-Ship-The-Oregon-Files/dp/0425226697?tag=NYTBS-20
# http://www.amazon.com/Turnover-Murder-Hannah-Swensen-Mysteries/dp/0758234899?tag=NYTBS-20
# http://www.amazon.com/House-Rules-Novel-Jodi-Picoult/dp/0743296443?tag=NYTBS-20
# http://www.amazon.com/Abraham-Lincoln-Vampire-Seth-Grahame-Smith/dp/0446563072?tag=NYTBS-20
# http://www.amazon.com/Shaladors-Lady-Black-Jewels-Novel/dp/0451463153?tag=NYTBS-20
# http://www.amazon.com/The-Silent-Sea-Oregon-Files/dp/0425240088?tag=NYTBS-20
# http://www.amazon.com/Star-Wars-Fate-Backlash-Legends/dp/0345509099?tag=NYTBS-20
# http://www.amazon.com/Deep-Shadow-Randy-Wayne-White/dp/0425240096?tag=NYTBS-20
# http://www.amazon.com/Angelology-A-Novel-Series/dp/0143118463?tag=NYTBS-20
# http://www.amazon.com/Hell-Gate-Alex-Cooper-Book/dp/0451412990?tag=NYTBS-20
# http://www.amazon.com/Major-Pettigrews-Last-Stand-Novel/dp/0812981227?tag=NYTBS-20
# http://www.amazon.com/The-Surrendered-Chang-rae-Lee/dp/1594489769?tag=NYTBS-20
# http://www.amazon.com/Think-Twice-Lisa-Scottoline/dp/0312380755?tag=NYTBS-20
# http://www.amazon.com/The-Girl-Who-Chased-Moon/dp/0553807218?tag=NYTBS-20
# error
# http://www.amazon.com/The-Spellmans-Strike-Again-Mysteries/dp/1416593403?tag=NYTBS-20
# http://www.amazon.com/Caught-Harlan-Coben/dp/0451232704?tag=NYTBS-20
# http://www.amazon.com/Bite-Me-A-Love-Story/dp/0061779725?tag=NYTBS-20
# http://www.amazon.com/Matterhorn-A-Novel-Vietnam-War/dp/0802145310?tag=NYTBS-20
# http://www.amazon.com/Shattered-Karen-Robards/dp/0451233549?tag=NYTBS-20
# http://www.amazon.com/The-Mapping-Love-Death-Maisie/dp/0061727687?tag=NYTBS-20
# http://www.amazon.com/Silver-Borne-Mercy-Thompson-Book/dp/044101996X?tag=NYTBS-20
# http://www.amazon.com/Deception-An-Alex-Delaware-Novel/dp/0345505689?tag=NYTBS-20
# http://www.amazon.com/Solar-Ian-McEwan/dp/0307739538?tag=NYTBS-20
# error
# http://www.amazon.com/Changes-A-Novel-Dresden-Files/dp/0451463471?tag=NYTBS-20
# http://www.amazon.com/The-Walk-Novel-Series/dp/1439187312?tag=NYTBS-20
# http://www.amazon.com/River-Sky-Amelia-Peabody-Mysteries/dp/0061246263?tag=NYTBS-20
# http://www.amazon.com/The-Black-Cat-Richard-Mysteries/dp/0670021601?tag=NYTBS-20
# http://www.amazon.com/The-Aloha-Quilt-Quilts-Novels/dp/1416533184?tag=NYTBS-20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-7d09134039ec> in <module>()
#       4 for url in search_urls:
#       5     try:
# ----> 6         get_img(url)
#       7         get_offer(url)
#       8         get_rating(url)
#
# <ipython-input-91-85116846c632> in get_img(x_url)
#      22 def get_img(x_url):
#      23     if x_url not in [url for (url, _) in img_urls]:
# ---> 24         response = requests.get(x_url, headers=headers)
#      25         soup = BeautifulSoup(response.text, 'lxml')
#      26         img_url = soup.find('div', id='img-canvas').find('img')['data-a-dynamic-image']
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     642
#     643         # Resolve redirects if allowed.
# --> 644         history = [resp for resp in gen] if allow_redirects else []
#     645
#     646         # Shuffle things around if there's history.
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     642
#     643         # Resolve redirects if allowed.
# --> 644         history = [resp for resp in gen] if allow_redirects else []
#     645
#     646         # Shuffle things around if there's history.
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     220                     proxies=proxies,
#     221                     allow_redirects=False,
# --> 222                     **adapter_kwargs
#     223                 )
#     224
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     660
#     661         if not stream:
# --> 662             r.content
#     663
#     664         return r
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/models.py in content(self)
#     825                 self._content = None
#     826             else:
# --> 827                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     828
#     829         self._content_consumed = True
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/models.py in generate()
#     747             if hasattr(self.raw, 'stream'):
#     748                 try:
# --> 749                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     750                         yield chunk
#     751                 except ProtocolError as e:
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     459         """
#     460         if self.chunked and self.supports_chunked_reads():
# --> 461             for line in self.read_chunked(amt, decode_content=decode_content):
#     462                 yield line
#     463         else:
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     635
#     636             while True:
# --> 637                 self._update_chunk_length()
#     638                 if self.chunk_left == 0:
#     639                     break
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     567         if self.chunk_left is not None:
#     568             return
# --> 569         line = self._fp.fp.readline()
#     570         line = line.split(b';', 1)[0]
#     571         try:
#
# /anaconda3/envs/pythondata/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     283     def recv_into(self, *args, **kwargs):
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#     287             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
len(reviews)
# Out:
# 1641

# %%
len(ratings)
# Out:
# 1615

# %%
len(offers)
# Out:
# 1237

# %%
len(img_urls)
# Out:
# 1307

# %%
# Create dataframe for reviews
r_keys = []
r_values = []
for r in reviews:
    r_keys.append(r[0])
    r_values.append(r[1].split()[0].replace(",",""))
reviews_dict = {
    'url': r_keys,
    'nb_reviews': r_values
}  
reviews_df = pd.DataFrame(reviews_dict)
reviews_df
# Out:
#                                                     url nb_reviews
# 0     http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...        920
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...        702
# 2     http://www.amazon.com/Unaccustomed-Earth-Jhump...        521
# 3     http://www.amazon.com/Unaccustomed-Vintage-Con...        521
# 4     http://www.amazon.com/The-Beach-House-A-Novel/...        521
# 5     http://www.amazon.com/Queen-Babble-Gets-Hitche...         78
# 6     http://www.amazon.com/Silent-Thunder-Iris-Joha...         80
# 7     http://www.amazon.com/Say-Goodbye-FBI-Profiler...        368
# 8     http://www.amazon.com/Secret-Servant-Gabriel-A...        828
# 9     http://www.amazon.com/The-Lace-Reader-A-Novel/...        633
# 10    http://www.amazon.com/Paul-Dune-Brian-Herbert/...        210
# 11    http://www.amazon.com/Wallflower-Christmas-Wal...        246
# 12    http://www.amazon.com/Midnight-A-Gangster-Love...        750
# 13    http://www.amazon.com/Santa-Clawed-Mrs-Murphy-...        121
# 14    http://www.amazon.com/The-Bodies-Left-Behind-N...        188
# 15    http://www.amazon.com/Cross-Country-Alex-James...        899
# 16    http://www.amazon.com/Plum-Spooky-Stephanie-Be...       1630
# 17    http://www.amazon.com/The-Piano-Teacher-A-Nove...        259
# 18    http://www.amazon.com/What-Did-Love-Wynette-Te...        193
# 19    http://www.amazon.com/Basketball-Jones-E-Lynn-...        158
# 20    http://www.amazon.com/The-Second-Opinion-Micha...        111
# 21    http://www.amazon.com/Cream-Murder-Hannah-Swen...        322
# 22    http://www.amazon.com/Fault-Line-Novel-Barry-E...        331
# 23    http://www.amazon.com/A-Plague-Secrets-John-Le...        142
# 24    http://www.amazon.com/Return-Sullivans-Island-...        254
# 25    http://www.amazon.com/Rules-Vengeance-Christop...        126
# 26    http://www.amazon.com/The-White-Queen-Cousins-...       1494
# 27    http://www.amazon.com/Dreamfever-Fever-Series-...        681
# 28    http://www.amazon.com/Dark-Slayer-Carpathian-C...        400
# 29    http://www.amazon.com/The-Lost-Symbol-Featurin...       5650
# ...                                                 ...        ...
# 1611  http://www.amazon.com/Sixkill-Spenser-Robert-B...        286
# 1612  http://www.amazon.com/Calebs-Crossing-Novel-Ge...        853
# 1613  http://www.amazon.com/The-Hot-Gate-Troy-Rising...        288
# 1614  http://www.amazon.com/Buried-Prey-John-Sandfor...        952
# 1615  http://www.amazon.com/The-Snowman-Harry-Hole-N...       1305
# 1616  http://www.amazon.com/A-Time-Patriots-Dale-Bro...        168
# 1617  http://www.amazon.com/The-Jefferson-Key-A-Nove...        531
# 1618  http://www.amazon.com/Embassytown-China-Mievil...        284
# 1619  http://www.amazon.com/Dreams-Joy-Novel-Lisa-Se...        806
# 1620  http://www.amazon.com/Kiss-Psy-Changeling-Seri...        249
# 1621  http://www.amazon.com/Trader-Secrets-Paul-Madr...        185
# 1622  http://www.amazon.com/The-Kingdom-A-Fargo-Adve...        417
# 1623  http://www.amazon.com/Summer-Rental-Mary-Kay-A...        634
# 1624  http://www.amazon.com/Robopocalypse-Novel-Dani...        811
# 1625  http://www.amazon.com/One-Summer-David-Baldacc...        771
# 1626  http://www.amazon.com/Carte-Blanche-James-Bond...        422
# 1627  http://www.amazon.com/Sisterhood-Everlasting-T...        408
# 1628  http://www.amazon.com/Smokin-Seventeen-Stephan...       1544
# 1629  http://www.amazon.com/The-Devil-Colony-Sigma-F...       2227
# 1630  http://www.amazon.com/Silver-Girl-Novel-Elin-H...        453
# 1631  http://www.amazon.com/Now-You-See-James-Patter...       1151
# 1632  http://www.amazon.com/Betrayal-Trust-J-Beaumon...        426
# 1633  http://www.amazon.com/Escape-Barbara-Delinsky-...        403
# 1634  http://www.amazon.com/Quinn-Eve-Duncan-Forensi...        385
# 1635  http://www.amazon.com/Burnt-Mountain-Anne-Rive...        236
# 1636  http://www.amazon.com/Ghost-Story-Novel-Dresde...       1178
# 1637  http://www.amazon.com/Full-Black-Thriller-Brad...        894
# 1638  http://www.amazon.com/Dick-Franciss-Gamble-Fel...        145
# 1639  http://www.amazon.com/Retribution-Dark-Hunter-...        356
# 1640  http://www.amazon.com/Back-Beyond-C-J-Box/dp/0...        550
#
# [1641 rows x 2 columns]

# %%
# Create dataframe for ratings
s_keys = []
s_values = []
for s in ratings:
    s_keys.append(s[0])
    s_values.append(s[1].split()[0])
stars_dict = {
    'url': s_keys,
    'nb_stars': s_values
}  
stars_df = pd.DataFrame(stars_dict)
stars_df
# Out:
#                                                     url nb_stars
# 0     http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      4.4
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...      4.0
# 2     http://www.amazon.com/Unaccustomed-Earth-Jhump...      4.4
# 3     http://www.amazon.com/Unaccustomed-Vintage-Con...      4.4
# 4     http://www.amazon.com/The-Beach-House-A-Novel/...      4.1
# 5     http://www.amazon.com/Queen-Babble-Gets-Hitche...      3.5
# 6     http://www.amazon.com/Silent-Thunder-Iris-Joha...      4.1
# 7     http://www.amazon.com/Say-Goodbye-FBI-Profiler...      4.2
# 8     http://www.amazon.com/Secret-Servant-Gabriel-A...      4.7
# 9     http://www.amazon.com/The-Lace-Reader-A-Novel/...      4.0
# 10    http://www.amazon.com/Paul-Dune-Brian-Herbert/...      3.7
# 11    http://www.amazon.com/Wallflower-Christmas-Wal...      4.4
# 12    http://www.amazon.com/Midnight-A-Gangster-Love...      4.2
# 13    http://www.amazon.com/Santa-Clawed-Mrs-Murphy-...      4.2
# 14    http://www.amazon.com/The-Bodies-Left-Behind-N...      3.9
# 15    http://www.amazon.com/Cross-Country-Alex-James...      4.0
# 16    http://www.amazon.com/Plum-Spooky-Stephanie-Be...      4.4
# 17    http://www.amazon.com/The-Piano-Teacher-A-Nove...      3.7
# 18    http://www.amazon.com/What-Did-Love-Wynette-Te...      3.8
# 19    http://www.amazon.com/Basketball-Jones-E-Lynn-...      4.4
# 1217  http://www.amazon.com/Deceived-Star-Wars-Repub...       $43.58
# 1218  http://www.amazon.com/The-Secret-Life-Damian-S...        $9.44
# 1219  http://www.amazon.com/Chasing-Fire-Nora-Robert...        $7.99
# 1220  http://www.amazon.com/Hiss-Death-Mrs-Murphy-My...        $7.99
# 1221  http://www.amazon.com/The-Sixth-Man-David-Bald...        $9.00
# 1222  http://www.amazon.com/Eve-Iris-Johansen/dp/031...        $8.66
# 1223  http://www.amazon.com/Southern-Comfort-Fern-Mi...        $7.99
# 1224  http://www.amazon.com/The-Hot-Gate-Troy-Rising...        $7.99
# 1225  http://www.amazon.com/Those-Peril-Hector-Cross...       $19.90
# 1226  http://www.amazon.com/A-Time-Patriots-Dale-Bro...       $17.87
# 1227  http://www.amazon.com/The-Jefferson-Key-A-Nove...        $7.44
# 1228  http://www.amazon.com/Embassytown-China-Mievil...       $19.99
# 1229  http://www.amazon.com/Dreams-Joy-Novel-Lisa-Se...       $11.16
# 1230  http://www.amazon.com/The-Kingdom-A-Fargo-Adve...        $9.99
# 1231  http://www.amazon.com/One-Summer-David-Baldacc...        $8.98
# 1232  http://www.amazon.com/Before-Go-Sleep-S-Watson...       $11.99
# 1233  http://www.amazon.com/Smokin-Seventeen-Stephan...        $8.09
# 1234  http://www.amazon.com/Silver-Girl-Novel-Elin-H...        $7.99
# 1235  http://www.amazon.com/Quinn-Eve-Duncan-Forensi...        $7.99
# 1236  http://www.amazon.com/Full-Black-Thriller-Brad...       $19.94
#
# [1237 rows x 2 columns]

# %%
# Create dataframe for thumbnail urls
i_keys = []
i_values = []
for i in img_urls:
    i_keys.append(i[0])
    i_values.append(i[1])
img_urls_dict = {
    'url': i_keys,
    'img_url': i_values
}  
img_urls_df = pd.DataFrame(img_urls_dict)
img_urls_df.head()
# Out:
#                                                  url  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2  http://www.amazon.com/Unaccustomed-Earth-Jhump...
# 3  http://www.amazon.com/Unaccustomed-Vintage-Con...
# 4  http://www.amazon.com/The-Beach-House-A-Novel/...
#
#                                              img_url
# 0  {"https://images-na.ssl-images-amazon.com/imag...
# 1  {"https://images-na.ssl-images-amazon.com/imag...
# 2  {"https://images-na.ssl-images-amazon.com/imag...
# 3  {"https://images-na.ssl-images-amazon.com/imag...
# 4  {"https://images-na.ssl-images-amazon.com/imag...

# %%
amazon_scrape_df = reviews_df.merge(stars_df, how='outer', on='url', suffixes=('_x', '_y'))
amazon_scrape_df = amazon_scrape_df.merge(offers_df, how='outer', on='url', suffixes=('_x', '_y'))
amazon_scrape_df = amazon_scrape_df.merge(img_urls_df, how='outer', on='url', suffixes=('_x', '_y'))
amazon_scrape_df.count()
# Out:
# url             2046
# nb_reviews      1641
# nb_stars        1615
# amazon_price    1237
# img_url         1307
# dtype: int64

# %%
# Save scraped data to 'more_scraped_data.csv'

amazon_scrape_df.to_csv('Output/more_scraped_data.csv')
