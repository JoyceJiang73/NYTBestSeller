# %% [markdown]
# # EXTRACT

# %% [markdown]
# ### STEP 1: Extract data from kaggle's file 'nyt2.json'
#
# Our first challenge started with the data file 'nyt2.json' we downloaded from kaggle. We expected a traditional json file (a list of dictionaries or a dictionary of dictionaries), but it is, instead, a compilation of json files, one per line. We wrote the code below to transform it into a true json file, which we named 'output.json'.

# %%
# Import dependencies needed

import json
import pandas as pd
from pprint import pprint

# %%
# Load 'nyt2.json' file into dataframe:

raw_nyt = pd.read_json('Resources/nyt2.json', lines=True, orient='columns')
raw_nyt.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b4aa4ead3089013507db18b'}
# 1  {'$oid': '5b4aa4ead3089013507db18c'}
# 2  {'$oid': '5b4aa4ead3089013507db18d'}
# 3  {'$oid': '5b4aa4ead3089013507db18e'}
# 4  {'$oid': '5b4aa4ead3089013507db18f'}
#
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 3  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
#
#                               bestsellers_date  \
# 0  {'$date': {'$numberLong': '1211587200000'}}
# 1  {'$date': {'$numberLong': '1211587200000'}}
# 2  {'$date': {'$numberLong': '1211587200000'}}
# 3  {'$date': {'$numberLong': '1211587200000'}}
# 4  {'$date': {'$numberLong': '1211587200000'}}
#
#                                          description  \
# 0  Odd Thomas, who can communicate with the dead,...
# 1  Aliens have taken control of the minds and bod...
# 2  A woman's happy marriage is shaken when she en...
# 3  A Massachusetts state investigator and his tea...
# 4  An aging porn queens aims to cap her career by...
#
#                         price                               published_date  \
# 0        {'$numberInt': '27'}  {'$date': {'$numberLong': '1212883200000'}}
# 1  {'$numberDouble': '25.99'}  {'$date': {'$numberLong': '1212883200000'}}
# 2  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 3  {'$numberDouble': '22.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 4  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
#
#        publisher                 rank       rank_last_week  \
# 0         Bantam  {'$numberInt': '1'}  {'$numberInt': '0'}
# 1  Little, Brown  {'$numberInt': '2'}  {'$numberInt': '1'}
# 2   St. Martin's  {'$numberInt': '3'}  {'$numberInt': '2'}
# 3         Putnam  {'$numberInt': '4'}  {'$numberInt': '0'}
# 4      Doubleday  {'$numberInt': '5'}  {'$numberInt': '0'}
#
#                       title        weeks_on_list
# 0                 ODD HOURS  {'$numberInt': '1'}
# 1                  THE HOST  {'$numberInt': '3'}
# 2  LOVE THE ONE YOU'RE WITH  {'$numberInt': '2'}
# 3                 THE FRONT  {'$numberInt': '1'}
# 4                     SNUFF  {'$numberInt': '1'}

# %%
# Save DataFrame 'raw_nyt' into a json file ('output.json') and load it as 'data' we can now work with:

raw_nyt.to_json(path_or_buf='output.json', orient = "records")
with open('output.json') as file:
    data = json.load(file)
#pprint(data)

# %%
# Set up lists to hold reponse info:

nyt_ids = []
urls = []
authors = []
bestsellers_dates = []
descriptions = []
prices = []
published_dates = []
publishers = []
ranks = []
ranks_last_week = []
titles = []
weeks_on_lists = []

# Populate the lists:

for item in data:
    nyt_ids.append(item['_id']['$oid'])
    urls.append(item['amazon_product_url'])
    authors.append(item['author'])
    bestsellers_dates.append(item['bestsellers_date']['$date']['$numberLong'])
    descriptions.append(item['description'])
    published_dates.append(item['published_date']['$date']['$numberLong'])
    publishers.append(item['publisher'])
    ranks.append(item['rank']['$numberInt'])
    ranks_last_week.append(item['rank_last_week']['$numberInt'])
    titles.append(item['title'])
    weeks_on_lists.append(item['weeks_on_list']['$numberInt'])
# Here we have to check for the correct keyname before we can extract the price string:
    price_key, = item['price'].keys()
    if price_key == '$numberInt' or price_key == '$numberDouble':
        prices.append(item['price'][price_key])# Populate the lists:

# %%
# Create a DataFrame from the lists

bestsellers_dict = {
    "nyt_id": nyt_ids,
    "title": titles,
    "author": authors,
    "url": urls,
    "publisher": publishers,
    "description": descriptions,
    "list_price": prices,
    "published_date": published_dates,
    "bestseller_date": bestsellers_dates,
    "rank": ranks,
    "rank_last_week": ranks_last_week,
    "weeks_on_list": weeks_on_lists
}
bestsellers_data = pd.DataFrame(bestsellers_dict)
bestsellers_data.head()
# Out:
#                      nyt_id                     title             author  \
# 0  5b4aa4ead3089013507db18b                 ODD HOURS      Dean R Koontz
# 1  5b4aa4ead3089013507db18c                  THE HOST    Stephenie Meyer
# 2  5b4aa4ead3089013507db18d  LOVE THE ONE YOU'RE WITH       Emily Giffin
# 3  5b4aa4ead3089013507db18e                 THE FRONT  Patricia Cornwell
# 4  5b4aa4ead3089013507db18f                     SNUFF    Chuck Palahniuk
#
#                                                  url      publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...         Bantam
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...  Little, Brown
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...   St. Martin's
# 3  http://www.amazon.com/The-Front-Garano-Patrici...         Putnam
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...      Doubleday
#
#                                          description list_price  \
# 0  Odd Thomas, who can communicate with the dead,...         27
# 1  Aliens have taken control of the minds and bod...      25.99
# 2  A woman's happy marriage is shaken when she en...      24.95
# 3  A Massachusetts state investigator and his tea...      22.95
# 4  An aging porn queens aims to cap her career by...      24.95
#
#   published_date bestseller_date rank rank_last_week weeks_on_list
# 0  1212883200000   1211587200000    1              0             1
# 1  1212883200000   1211587200000    2              1             3
# 2  1212883200000   1211587200000    3              2             2
# 3  1212883200000   1211587200000    4              0             1
# 4  1212883200000   1211587200000    5              0             1

# %%
bestsellers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 12 columns):
# nyt_id             10195 non-null object
# title              10195 non-null object
# author             10195 non-null object
# url                10195 non-null object
# publisher          10195 non-null object
# description        10195 non-null object
# list_price         10195 non-null object
# published_date     10195 non-null object
# bestseller_date    10195 non-null object
# rank               10195 non-null object
# rank_last_week     10195 non-null object
# weeks_on_list      10195 non-null object
# dtypes: object(12)
# memory usage: 955.9+ KB

# %% [markdown]
# ### STEP 2: Scrape info from amazon.com
#
# In this step, we identify the list of unique Amazon URLs from our bestsellers_data DataFrame, and we visit each of those URLs to scrape the Amazon price offer, number of customer reviews, and average 5-star rating.
# We encountered our second challenge here, as we had to iterate multiple times through our list of Amazon URLs and repetitively request the info we were seeking. Eventually we were able to scrape info for 1211 URLs out of the 2329 identified in our kaggle dataset.

# %%
# Import dependencies needed

from bs4 import BeautifulSoup
import requests
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
# Get list of unique amazon urls

amazon_urls = list(dict.fromkeys(urls))
len(amazon_urls)
# Out:
# 2329

# %% [raw]
# # Set-up lists to store scraped info and user-defined functions for the iterations
#
# reviews = []
# ratings = []
# offers = []
# img_urls = []
#
# def get_nb_reviews(x_url):
#     if x_url not in [url for (url, _) in reviews]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         review = soup.find_all('span', id="acrCustomerReviewText")[0].text
#         reviews.append((url, review))
#
# def get_rating(x_url):
#     if x_url not in [url for (url, _) in ratings]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         rating = soup.find('span', class_="a-icon-alt").text
#         ratings.append((url, rating))
#
# def get_offer(x_url):
#     if x_url not in [url for (url, _) in offers]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         offer = soup.find('span', class_="a-size-medium a-color-price offer-price a-text-normal").text
#         offers.append((url, offer))
#
# def get_img(x_url):
#     if x_url not in [url for (url, _) in img_urls]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         img_url = soup.find('div', id='img-canvas').find('img')['data-a-dynamic-image']
#         img_urls.append((url, img_url))

# %% [raw]
# # Extract info from amazon using requests
#
# missing_urls = []
# for url in amazon_urls:
#     try:
#         get_offer(url)
#         get_img(url)
#         get_nb_reviews(url)
#         get_rating(url)
#         print(url)
#     except (AttributeError, RuntimeError, TypeError, NameError, IndexError):
#         print("error")
#         missing_urls.append(url)

# %% [markdown]
# # TRANSFORM

# %% [markdown]
# ### STEP 1: Transform data from 'bestsellers_data' DataFrame
#
# All data extracted from the json file and read into our bestsellers_data DataFrame has a the type 'string'. We now need to transform some of into the correct data type. Specifically:
# - 'list_price' should have the float type
# - 'published_date' and 'bestseller_date' should be formatted as dates
# - 'rank', 'rank_last_week', and 'weeks_on_list' should have the integer type

# %%
# Import dependencies needed

import numpy as np
from datetime import datetime

# %%
# Load our file of scraped Amazon data ('join_data.csv') into dataframe

Amazon_data1 = pd.read_csv("Output/join_data.csv")
Amazon_data2 = pd.read_csv("Output/more_scraped_data.csv")
print(Amazon_data1.count())
print(Amazon_data2.count())
print(bestsellers_data.count())
# Out:
# Unnamed: 0    1211
# url           1211
# reviews       1211
# rating        1211
# price         1211
# dtype: int64
# Unnamed: 0      1948
# url             1948
# nb_reviews      1466
# nb_stars        1345
# amazon_price    1146
# img_url         1227
# dtype: int64
# nyt_id             10195
# title              10195
# author             10195
# url                10195
# publisher          10195
# description        10195
# list_price         10195
# published_date     10195
# bestseller_date    10195
# rank               10195
# rank_last_week     10195
# weeks_on_list      10195
# dtype: int64

# %%
# Group bestsellers_data by url

grouped = bestsellers_data.groupby('url')
bestsellers_grouped = grouped['url', 'title', 'author', 'publisher', 'description', 'list_price', 'weeks_on_list'].max()

# Calculate additional columns

bestsellers_grouped['first_date_listed'] = grouped[['published_date']].min()
bestsellers_grouped['last_date_listed'] = grouped[['published_date']].max()
bestsellers_grouped['worst_rank'] = grouped[['rank']].max()
bestsellers_grouped['best_rank'] = grouped[['rank']].min()
bestsellers_grouped['times_listed'] = grouped[['url']].count()
#bestsellers_grouped["better_price"] = bestsellers_df.apply(lambda row : 'Amazon' if row['NYT_Price'] > row['Amazon_Price'] else 'NYT', axis=1)
bestsellers_grouped.count()
# Out:
# url                  2329
# title                2329
# author               2329
# publisher            2329
# description          2329
# list_price           2329
# weeks_on_list        2329
# first_date_listed    2329
# last_date_listed     2329
# worst_rank           2329
# best_rank            2329
# times_listed         2329
# dtype: int64

# %%
# Merge dataframes

df = pd.merge(bestsellers_grouped, Amazon_data1, on='url',how='left')
df = pd.merge(df, Amazon_data2, on='url',how='left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 21 columns):
# url                  2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# list_price           2329 non-null object
# weeks_on_list        2329 non-null object
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null object
# best_rank            2329 non-null object
# times_listed         2329 non-null int64
# Unnamed: 0_x         1211 non-null float64
# reviews              1211 non-null object
# rating               1211 non-null object
# price                1211 non-null object
# Unnamed: 0_y         1948 non-null float64
# nb_reviews           1466 non-null object
# nb_stars             1345 non-null object
# amazon_price         1146 non-null object
# img_url              1227 non-null object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 400.3+ KB
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2961: FutureWarning: 'url' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Drop columns 'Unnamed: 0'

df.drop('Unnamed: 0_x', axis=1, inplace=True)
df.drop('Unnamed: 0_y', axis=1, inplace=True)

# %%
# Convert all price columns to float:

df['list_price'] = df['list_price'].apply(lambda x : float(x))
df['price']=df['price'].replace('[\$,]', '', regex=True).astype(float)
df['amazon_price']=df['amazon_price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Convert all date columns from unix time stamp to date format:

df['first_date_listed'] = df['first_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))
df['last_date_listed'] = df['last_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))

# %%
# Convert 'weeks_on_list' and 'reviews; to integer, 'rating' to float:

df['weeks_on_list'] = df['weeks_on_list'].apply(lambda x : int(x))

# %%
#df['reviews'] = df['reviews'].str.replace(',', '')
#df['reviews'] = df['reviews'].apply(lambda x : int(x.split()[0]))
#df['rating'] = df['rating'].apply(lambda x : x.split()[0])
df.head()
# Out:
#                                                  url  \
# 0  http://www.amazon.com/10th-Anniversary-Womens-...
# 1  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# 2  http://www.amazon.com/11th-Hour-Womens-Murder-...
# 3  http://www.amazon.com/1225-Christmas-Tree-Lane...
# 4  http://www.amazon.com/12th-Never-Womens-Murder...
#
#                       title                             author      publisher  \
# 0          10TH ANNIVERSARY  James Patterson and Maxine Paetro  Little, Brown
# 1                  11/22/63                       Stephen King       Scribner
# 2                 11TH HOUR  James Patterson and Maxine Paetro  Little, Brown
# 3  1225 CHRISTMAS TREE LANE                    Debbie Macomber           Mira
# 4             12TH OF NEVER  James Patterson and Maxine Paetro  Little, Brown
#
#                                          description  list_price  \
# 0  Detective Lindsay Boxer’s long-awaited wedding...       27.99
# 1  An English teacher travels back to 1958 by way...       35.00
# 2  When a millionaire is gunned down, Detective L...       27.99
# 3  Puppies that need good homes and an ex-husband...       16.95
# 4  One week after the birth of her baby, Detectiv...        0.00
#
#    weeks_on_list first_date_listed last_date_listed worst_rank best_rank  \
# 0              8        2011-05-22       2011-07-24          9        16
# 1              9        2011-11-27       2012-05-13          6         1
# 2              8        2012-05-27       2012-07-29          6         1
# 3              4        2011-10-16       2011-11-27          8        10
# 4              6        2013-05-19       2013-06-30          8         1
#
#    times_listed                 reviews              rating  price  \
# 0            10   1365 customer reviews  4.6 out of 5 stars   9.99
# 1            23  26427 customer reviews  4.5 out of 5 stars  10.99
# 2            10   1858 customer reviews  4.6 out of 5 stars   9.99
# 3             7                     NaN                 NaN    NaN
# 4             7   3789 customer reviews  4.5 out of 5 stars   9.99
#
#                 nb_reviews            nb_stars  amazon_price  \
# 0   1,365 customer reviews                 NaN          8.87
# 1  26,432 customer reviews                 NaN           NaN
# 2                      NaN                 NaN         10.00
# 3     741 customer reviews                 NaN          5.98
# 4   3,790 customer reviews  4.5 out of 5 stars         12.00
#
#                                              img_url
# 0                                                NaN
# 1                                                NaN
# 2  {"https://images-na.ssl-images-amazon.com/imag...
# 3  {"https://images-na.ssl-images-amazon.com/imag...
# 4  {"https://images-na.ssl-images-amazon.com/imag...

# %%
# Rename some columns

df = df.rename(columns={"list_price":"NYT_Price", "price":"Amazon_Price", 'url':'Amazon_url', 'reviews': 'nb_Amazon_reviews', 'rating': 'star_rating'})

# %%
# Group data by bestseller

grouped = df.groupby('Amazon_url')
bestsellers_df = grouped['Amazon_url', 'title', 'author', 'publisher', 'description', 'star_rating', 'nb_Amazon_reviews', 'weeks_on_list', 'NYT_Price', 'Amazon_Price'].max()

# Calculate additional columns

bestsellers_df['first_date_listed'] = grouped[['published_date']].min()
bestsellers_df['last_date_listed'] = grouped[['published_date']].max()
bestsellers_df['worst_rank'] = grouped[['rank']].max()
bestsellers_df['best_rank'] = grouped[['rank']].min()
bestsellers_df['times_listed'] = grouped[['Amazon_url']].count()
bestsellers_df["better_price"] = bestsellers_df.apply(lambda row : 'Amazon' if row['NYT_Price'] > row['Amazon_Price'] else 'NYT', axis=1)
bestsellers_df.head()
# Out:
#                                                                                            Amazon_url  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  http://www.amazon.com/10th-Anniversary-Womens-...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  http://www.amazon.com/11th-Hour-Womens-Murder-...
# http://www.amazon.com/12th-Never-Womens-Murder-...  http://www.amazon.com/12th-Never-Womens-Murder...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  http://www.amazon.com/14th-Deadly-Womens-Murde...
#
#                                                                title  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  10TH ANNIVERSARY
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          11/22/63
# http://www.amazon.com/11th-Hour-Womens-Murder-C...         11TH HOUR
# http://www.amazon.com/12th-Never-Womens-Murder-...     12TH OF NEVER
# http://www.amazon.com/14th-Deadly-Womens-Murder...   14TH DEADLY SIN
#
#                                                                                author  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  James Patterson and Maxine Paetro
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                       Stephen King
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  James Patterson and Maxine Paetro
# http://www.amazon.com/12th-Never-Womens-Murder-...  James Patterson and Maxine Paetro
# http://www.amazon.com/14th-Deadly-Womens-Murder...  James Patterson and Maxine Paetro
#
#                                                         publisher  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Little, Brown
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       Scribner
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  Little, Brown
# http://www.amazon.com/12th-Never-Womens-Murder-...  Little, Brown
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Little, Brown
#
#                                                                                           description  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Detective Lindsay Boxer’s long-awaited wedding...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  An English teacher travels back to 1958 by way...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  When a millionaire is gunned down, Detective L...
# http://www.amazon.com/12th-Never-Womens-Murder-...  One week after the birth of her baby, Detectiv...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Detective Lindsay Boxer and her friends must r...
#
#                                                     star_rating  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          4.6
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          4.5
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          4.6
# http://www.amazon.com/12th-Never-Womens-Murder-...          4.5
# http://www.amazon.com/14th-Deadly-Womens-Murder...          4.3
#
#                                                     nb_Amazon_reviews  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...               1365
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...              26427
# http://www.amazon.com/11th-Hour-Womens-Murder-C...               1858
# http://www.amazon.com/12th-Never-Womens-Murder-...               3789
# http://www.amazon.com/14th-Deadly-Womens-Murder...               4140
#
#                                                     weeks_on_list  NYT_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...              8      27.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...             21      35.00
# http://www.amazon.com/11th-Hour-Womens-Murder-C...              8      27.99
# http://www.amazon.com/12th-Never-Womens-Murder-...              6       0.00
# http://www.amazon.com/14th-Deadly-Womens-Murder...              7       0.00
#
#                                                     Amazon_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          9.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...         10.99
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          9.99
# http://www.amazon.com/12th-Never-Womens-Murder-...          9.99
# http://www.amazon.com/14th-Deadly-Womens-Murder...          9.99
#
#                                                    first_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...        2011-05-22
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...        2011-11-27
# http://www.amazon.com/11th-Hour-Womens-Murder-C...        2012-05-27
# http://www.amazon.com/12th-Never-Womens-Murder-...        2013-05-19
# http://www.amazon.com/14th-Deadly-Womens-Murder...        2015-05-24
#
#                                                    last_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...       2011-07-24
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       2012-05-13
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       2012-07-29
# http://www.amazon.com/12th-Never-Womens-Murder-...       2013-06-30
# http://www.amazon.com/14th-Deadly-Womens-Murder...       2015-07-12
#
#                                                     worst_rank  best_rank  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          18          2
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          20          1
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          20          1
# http://www.amazon.com/12th-Never-Womens-Murder-...          19          1
# http://www.amazon.com/14th-Deadly-Womens-Murder...          20          1
#
#                                                     times_listed better_price
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...            10       Amazon
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...            23       Amazon
# http://www.amazon.com/11th-Hour-Womens-Murder-C...            10       Amazon
# http://www.amazon.com/12th-Never-Womens-Murder-...             7          NYT
# http://www.amazon.com/14th-Deadly-Womens-Murder...             8          NYT

# %% [markdown]
# # LOAD

# %% [markdown]
# ### STEP 1: Load data from 'bestsellers_df' into a MongoDB database
#
# Explain why we chose to load into MongoDB as opposed to MySQL for example.

# %%
# Import dependencies needed

import pymongo

# %%
# Initialize PyMongo to work with MongoDB

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Check if database exists already and drop it if so

dblist = client.list_database_names()
if "nyt_bestsellers" in dblist:
    client.drop_database("nyt_bestsellers")

# %%
# Define database and collection

db = client.nyt_bestsellers
collection = db.bestsellers

# %%
# Create a list of dictionaries that hold the mongoDB documents to be inserted

post = bestsellers_df.to_dict(orient='records')
print(f"Posting {len(post)} documents into collection of bestsellers inside nyt_bestsellers mongo database...")

# Insert the list of documents into the database

collection.insert_many(post)
# Out:
# Posting 1211 into collection of bestsellers inside nyt_bestsellers_db

# %%
# Verify results

results = collection.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3ef9'), 'Amazon_url': 'http://www.amazon.com/10th-Anniversary-Womens-Murder-Club/dp/1455511463?tag=NYTBS-20', 'title': '10TH ANNIVERSARY', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'Detective Lindsay Boxer’s long-awaited wedding celebration becomes a distant memory when the Women’s Murder Club is called in to find a missing baby.', 'star_rating': 4.6, 'nb_Amazon_reviews': 1365, 'weeks_on_list': 8, 'NYT_Price': 27.99, 'Amazon_Price': 9.99, 'first_date_listed': '2011-05-22', 'last_date_listed': '2011-07-24', 'worst_rank': 18, 'best_rank': 2, 'times_listed': 10, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3efa'), 'Amazon_url': 'http://www.amazon.com/11-22-63-A-Novel/dp/1451627297?tag=NYTBS-20', 'title': '11/22/63', 'author': 'Stephen King', 'publisher': 'Scribner', 'description': 'An English teacher travels back to 1958 by way of a time portal in a Maine diner. His assignment: Stop Lee Harvey Oswald.', 'star_rating': 4.5, 'nb_Amazon_reviews': 26427, 'weeks_on_list': 21, 'NYT_Price': 35.0, 'Amazon_Price': 10.99, 'first_date_listed': '2011-11-27', 'last_date_listed': '2012-05-13', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 23, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3efb'), 'Amazon_url': 'http://www.amazon.com/11th-Hour-Womens-Murder-Club/dp/0446571830?tag=NYTBS-20', 'title': '11TH HOUR', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': "When a millionaire is gunned down, Detective Lindsay Boxer and the Women's Murder Club discover that the murder weapon is linked to the deaths of four of San Francisco's most untouchable criminals.", 'star_rating': 4.6, 'nb_Amazon_reviews': 1858, 'weeks_on_list': 8, 'NYT_Price': 27.99, 'Amazon_Price': 9.99, 'first_date_listed': '2012-05-27', 'last_date_listed': '2012-07-29', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 10, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3efc'), 'Amazon_url': 'http://www.amazon.com/12th-Never-Womens-Murder-Club/dp/1455515795?tag=NYTBS-20', 'title': '12TH OF NEVER', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'One week after the birth of her baby, Detective Lindsay Boxer must return to work to investigate a string of grisly murders; a Women’s Murder Club novel.\xa0', 'star_rating': 4.5, 'nb_Amazon_reviews': 3789, 'weeks_on_list': 6, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2013-05-19', 'last_date_listed': '2013-06-30', 'worst_rank': 19, 'best_rank': 1, 'times_listed': 7, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3efd'), 'Amazon_url': 'http://www.amazon.com/14th-Deadly-Womens-Murder-Club/dp/031640702X?tag=NYTBS-20', 'title': '14TH DEADLY SIN', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': 'Detective Lindsay Boxer and her friends must risk their lives to save the city and one another when a rash of murders grips San Francisco.', 'star_rating': 4.3, 'nb_Amazon_reviews': 4140, 'weeks_on_list': 7, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2015-05-24', 'last_date_listed': '2015-07-12', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 8, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3efe'), 'Amazon_url': 'http://www.amazon.com/15th-Affair-Womens-Murder-Club/dp/0316407070?tag=NYTBS-20', 'title': '15TH AFFAIR', 'author': 'James Patterson and Maxine Paetro', 'publisher': 'Little, Brown', 'description': "When a brutal murder threatens the domestic happiness of the San Francisco police detective Lindsay Boxer, she turns for help to the Women's Murder Club.", 'star_rating': 4.5, 'nb_Amazon_reviews': 2913, 'weeks_on_list': 7, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-05-22', 'last_date_listed': '2016-07-10', 'worst_rank': 18, 'best_rank': 1, 'times_listed': 8, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3eff'), 'Amazon_url': 'http://www.amazon.com/1Q84-Haruki-Murakami-ebook/dp/B004LROUW2?tag=NYTBS-20', 'title': '1Q84', 'author': 'Haruki Murakami', 'publisher': 'Knopf', 'description': 'In 1980s Tokyo, a woman who punishes perpetrators of domestic violence has ties to an aspiring novelist with an unusual project.', 'star_rating': 4.0, 'nb_Amazon_reviews': 1892, 'weeks_on_list': 9, 'NYT_Price': 30.5, 'Amazon_Price': 12.99, 'first_date_listed': '2011-11-13', 'last_date_listed': '2012-01-15', 'worst_rank': 18, 'best_rank': 2, 'times_listed': 10, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f00'), 'Amazon_url': 'http://www.amazon.com/2030-Real-Story-Happens-America-ebook/dp/B004OA62WC?tag=NYTBS-20', 'title': '2030', 'author': 'Albert Brooks', 'publisher': "St. Martin's", 'description': 'In 2030, the young resent the elderly for draining the weakening economy, and a devastating earthquake in Los Angeles tests the administration of the country’s first Jewish president.', 'star_rating': 3.7, 'nb_Amazon_reviews': 493, 'weeks_on_list': 3, 'NYT_Price': 25.99, 'Amazon_Price': 9.99, 'first_date_listed': '2011-05-29', 'last_date_listed': '2011-06-19', 'worst_rank': 19, 'best_rank': 14, 'times_listed': 4, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f01'), 'Amazon_url': 'http://www.amazon.com/44-Charles-Street-A-Novel/dp/0440245176?tag=NYTBS-20', 'title': '44 CHARLES STREET', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': 'The owner of a Greenwich Village town house takes in boarders and bonds with her tenants.', 'star_rating': 4.2, 'nb_Amazon_reviews': 433, 'weeks_on_list': 5, 'NYT_Price': 28.0, 'Amazon_Price': 7.99, 'first_date_listed': '2011-04-24', 'last_date_listed': '2011-05-22', 'worst_rank': 13, 'best_rank': 4, 'times_listed': 5, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f02'), 'Amazon_url': 'http://www.amazon.com/61-Hours-Jack-Reacher-Novel/dp/0440243696?tag=NYTBS-20', 'title': '61 HOURS', 'author': 'Lee Child', 'publisher': 'Delacorte', 'description': 'Jack Reacher helps the police in a small South Dakota town protect a witness in a drug trial.', 'star_rating': 4.3, 'nb_Amazon_reviews': 2403, 'weeks_on_list': 6, 'NYT_Price': 28.0, 'Amazon_Price': 9.99, 'first_date_listed': '2010-06-06', 'last_date_listed': '2010-07-25', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 7, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f03'), 'Amazon_url': 'http://www.amazon.com/A-Change-Altitude-Novel/dp/0316020710?tag=NYTBS-20', 'title': 'A CHANGE IN ALTITUDE', 'author': 'Anita Shreve', 'publisher': 'Little, Brown', 'description': 'A young woman’s life is transformed by a mountain-climbing accident in Kenya.', 'star_rating': 3.4, 'nb_Amazon_reviews': 238, 'weeks_on_list': 1, 'NYT_Price': 26.99, 'Amazon_Price': 5.99, 'first_date_listed': '2009-10-11', 'last_date_listed': '2009-10-18', 'worst_rank': 17, 'best_rank': 11, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f04'), 'Amazon_url': 'http://www.amazon.com/A-Crown-Imperiled-Chaoswar-Saga/dp/006146841X?tag=NYTBS-20', 'title': 'A CROWN IMPERILED', 'author': 'Raymond E Feist', 'publisher': 'Harper Voyager', 'description': '', 'star_rating': 4.4, 'nb_Amazon_reviews': 824, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 4.99, 'first_date_listed': '2012-04-01', 'last_date_listed': '2012-04-01', 'worst_rank': 20, 'best_rank': 20, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f05'), 'Amazon_url': 'http://www.amazon.com/A-Darker-Place-Jack-Higgins/dp/0399155503?tag=NYTBS-20', 'title': 'A DARKER PLACE', 'author': 'Jack Higgins', 'publisher': 'Putnam', 'description': 'A Russian defector becomes a counterspy.', 'star_rating': 4.1, 'nb_Amazon_reviews': 91, 'weeks_on_list': 3, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'first_date_listed': '2009-02-15', 'last_date_listed': '2009-03-01', 'worst_rank': 14, 'best_rank': 10, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f06'), 'Amazon_url': 'http://www.amazon.com/A-Devil-Waiting-Jack-Higgins/dp/0425250571?tag=NYTBS-20', 'title': 'A DEVIL IS WAITING', 'author': 'Jack Higgins', 'publisher': 'Putnam', 'description': 'Sean Dillon helps to foil a plot to assassinate the president in London.', 'star_rating': 4.1, 'nb_Amazon_reviews': 178, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 8.99, 'first_date_listed': '2012-01-22', 'last_date_listed': '2012-01-22', 'worst_rank': 15, 'best_rank': 15, 'times_listed': 1, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f07'), 'Amazon_url': 'http://www.amazon.com/A-God-Ruins-Novel-ebook/dp/B00NERQQXG?tag=NYTBS-20', 'title': 'A GOD IN RUINS', 'author': 'Kate Atkinson', 'publisher': 'Little, Brown', 'description': 'Postwar Britain as seen through the members of a well-to-do family.', 'star_rating': 4.2, 'nb_Amazon_reviews': 940, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2015-05-24', 'last_date_listed': '2015-06-07', 'worst_rank': 16, 'best_rank': 6, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f08'), 'Amazon_url': 'http://www.amazon.com/A-Good-Woman-Novel/dp/0440243300?tag=NYTBS-20', 'title': 'A GOOD WOMAN', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': 'An American society girl who made a new life as a doctor in World War I France returns to New York.', 'star_rating': 4.5, 'nb_Amazon_reviews': 381, 'weeks_on_list': 2, 'NYT_Price': 27.0, 'Amazon_Price': 7.99, 'first_date_listed': '2008-11-16', 'last_date_listed': '2009-01-11', 'worst_rank': 20, 'best_rank': 5, 'times_listed': 5, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f09'), 'Amazon_url': 'http://www.amazon.com/A-Heartbeat-Away-Michael-Palmer-ebook/dp/B00457X86M?tag=NYTBS-20', 'title': 'A HEARTBEAT AWAY', 'author': 'Michael Palmer', 'publisher': 'St. Martin’s', 'description': 'A terrorist group unleashes a deadly virus in the Capitol on the night of the State of the Union address.', 'star_rating': 3.9, 'nb_Amazon_reviews': 183, 'weeks_on_list': 2, 'NYT_Price': 27.99, 'Amazon_Price': 7.99, 'first_date_listed': '2011-03-06', 'last_date_listed': '2011-03-13', 'worst_rank': 15, 'best_rank': 10, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0a'), 'Amazon_url': 'http://www.amazon.com/A-Little-Life-Hanya-Yanagihara/dp/0804172706?tag=NYTBS-20', 'title': 'A LITTLE LIFE', 'author': 'Hanya Yanagihara', 'publisher': 'Doubleday', 'description': 'Four college friends, one with a traumatic past, move to New York seeking fame and fortune.', 'star_rating': 4.2, 'nb_Amazon_reviews': 3436, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2016-01-17', 'last_date_listed': '2016-01-24', 'worst_rank': 19, 'best_rank': 19, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0b'), 'Amazon_url': 'http://www.amazon.com/A-Memory-Light-Wheel-Time-ebook/dp/B00BMKDTNC?tag=NYTBS-20', 'title': 'A MEMORY OF LIGHT', 'author': 'Robert Jordan and Brandon Sanderson', 'publisher': 'Tor/Tom Doherty', 'description': 'The 14th and final novel in the Wheel of Time fantasy series.', 'star_rating': 4.6, 'nb_Amazon_reviews': 4293, 'weeks_on_list': 12, 'NYT_Price': 34.99, 'Amazon_Price': 9.99, 'first_date_listed': '2013-01-27', 'last_date_listed': '2013-05-05', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 13, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0c'), 'Amazon_url': 'http://www.amazon.com/A-Mercy-Toni-Morrison/dp/0307276767?tag=NYTBS-20', 'title': 'A MERCY', 'author': 'Toni Morrison', 'publisher': 'Knopf', 'description': 'In 17th-\xadcentury America, a slave mother urges a Northern farmer to buy her daughter so that she can have a better life; from the Nobel Prize-winning author of “Beloved.”', 'star_rating': 3.9, 'nb_Amazon_reviews': 294, 'weeks_on_list': 11, 'NYT_Price': 23.95, 'Amazon_Price': 9.99, 'first_date_listed': '2008-11-30', 'last_date_listed': '2009-02-08', 'worst_rank': 15, 'best_rank': 5, 'times_listed': 11, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0d'), 'Amazon_url': 'http://www.amazon.com/A-Perfect-Life-Novel-ebook/dp/B00HXYKYDE?tag=NYTBS-20', 'title': 'A PERFECT LIFE', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': "A television anchor's on-air poise belies her unsettled life.", 'star_rating': 4.4, 'nb_Amazon_reviews': 1648, 'weeks_on_list': 4, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2014-08-10', 'last_date_listed': '2014-09-07', 'worst_rank': 18, 'best_rank': 4, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0e'), 'Amazon_url': 'http://www.amazon.com/A-Reliable-Wife-Robert-Goolrick/dp/1565125967?tag=NYTBS-20', 'title': 'A RELIABLE WIFE', 'author': 'Robert Goolrick', 'publisher': 'Algonquin', 'description': 'Complications ensue when a wealthy Wisconsin widower in 1907 advertises for a spouse.', 'star_rating': 3.3, 'nb_Amazon_reviews': 1399, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 9.58, 'first_date_listed': '2009-05-10', 'last_date_listed': '2009-05-10', 'worst_rank': 17, 'best_rank': 17, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f0f'), 'Amazon_url': 'http://www.amazon.com/A-Summer-Affair-Novel/dp/B003P2VBNU?tag=NYTBS-20', 'title': 'A SUMMER AFFAIR', 'author': 'Elin Hilderbrand', 'publisher': 'Little Brown & Company', 'description': 'A successful married artist is attracted to a billionaire on Nantucket.', 'star_rating': 3.7, 'nb_Amazon_reviews': 241, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2008-07-20', 'last_date_listed': '2008-07-27', 'worst_rank': 19, 'best_rank': 18, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f10'), 'Amazon_url': 'http://www.amazon.com/A-Week-Winter-Maeve-Binchy/dp/0307273571?tag=NYTBS-20', 'title': 'A WEEK IN WINTER', 'author': 'Maeve Binchy', 'publisher': 'Knopf', 'description': 'Guests at an inn by the sea on Ireland’s west coast; the final book by Binchy, who died in 2012.\xa0', 'star_rating': 4.4, 'nb_Amazon_reviews': 3451, 'weeks_on_list': 9, 'NYT_Price': 26.95, 'Amazon_Price': 8.99, 'first_date_listed': '2013-03-03', 'last_date_listed': '2013-05-05', 'worst_rank': 17, 'best_rank': 1, 'times_listed': 10, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f11'), 'Amazon_url': 'http://www.amazon.com/A-Winter-Dream-Novel/dp/145162803X?tag=NYTBS-20', 'title': 'A WINTER DREAM', 'author': 'Richard Paul Evans', 'publisher': 'Simon & Schuster', 'description': 'When Joseph Jacobson stands to take over his father’s business, his 12 brothers cast him out.', 'star_rating': 4.6, 'nb_Amazon_reviews': 418, 'weeks_on_list': 3, 'NYT_Price': 19.99, 'Amazon_Price': 10.99, 'first_date_listed': '2012-11-18', 'last_date_listed': '2012-12-02', 'worst_rank': 16, 'best_rank': 6, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f12'), 'Amazon_url': 'http://www.amazon.com/Abraham-Lincoln-Vampire-Seth-Grahame-Smith/dp/0446563072?tag=NYTBS-20', 'title': 'ABRAHAM LINCOLN: VAMPIRE HUNTER', 'author': 'Seth Grahame-Smith', 'publisher': 'Grand Central', 'description': 'Lincoln vs. the undead.', 'star_rating': 4.3, 'nb_Amazon_reviews': 1627, 'weeks_on_list': 7, 'NYT_Price': 21.99, 'Amazon_Price': 6.92, 'first_date_listed': '2010-03-21', 'last_date_listed': '2010-05-09', 'worst_rank': 19, 'best_rank': 4, 'times_listed': 8, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f13'), 'Amazon_url': 'http://www.amazon.com/Acheron-Dark-Hunter-Book-Sherrilyn-Kenyon/dp/0312949413?tag=NYTBS-20', 'title': 'ACHERON', 'author': 'Sherrilyn Kenyon', 'publisher': 'St. Martin’s', 'description': 'Book 12 of the Dark-Hunter paranormal series.', 'star_rating': 4.7, 'nb_Amazon_reviews': 1163, 'weeks_on_list': 4, 'NYT_Price': 24.95, 'Amazon_Price': 8.99, 'first_date_listed': '2008-08-24', 'last_date_listed': '2008-09-21', 'worst_rank': 17, 'best_rank': 1, 'times_listed': 5, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f14'), 'Amazon_url': 'http://www.amazon.com/Act-War-Thriller-Brad-Thor/dp/1476717125?tag=NYTBS-20', 'title': 'ACT OF WAR', 'author': 'Brad Thor', 'publisher': 'Emily Bestler/Atria', 'description': 'The counterterrorism operative Scot Harvath undertakes two dangerous missions as America faces an imminent attack.', 'star_rating': 4.4, 'nb_Amazon_reviews': 3328, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 8.99, 'first_date_listed': '2014-07-27', 'last_date_listed': '2014-08-24', 'worst_rank': 13, 'best_rank': 1, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f15'), 'Amazon_url': 'http://www.amazon.com/Adultery-A-novel-Paulo-Coelho/dp/1101874082?tag=NYTBS-20', 'title': 'ADULTERY', 'author': 'Paulo Coelho', 'publisher': 'Knopf', 'description': '\xa0A married journalist, depressed by boredom, risks everything when she embarks on an affair with a former boyfriend; by the Brazilian writer, the author of “The Alchemist.”\xa0', 'star_rating': 3.4, 'nb_Amazon_reviews': 806, 'weeks_on_list': 4, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2014-09-07', 'last_date_listed': '2014-10-19', 'worst_rank': 19, 'best_rank': 2, 'times_listed': 6, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f16'), 'Amazon_url': 'http://www.amazon.com/Affair-bonus-short-story-Second-ebook/dp/B004P8JPS6?tag=NYTBS-20', 'title': 'THE AFFAIR', 'author': 'Lee Child', 'publisher': 'Delacorte', 'description': 'It’s 1997 and the military cop Jack Reacher goes undercover in Mississippi to ferret out a possible scandal involving a soldier with powerful friends in Washington.', 'star_rating': 4.5, 'nb_Amazon_reviews': 2694, 'weeks_on_list': 7, 'NYT_Price': 28.0, 'Amazon_Price': 9.99, 'first_date_listed': '2011-10-16', 'last_date_listed': '2011-12-11', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 8, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f17'), 'Amazon_url': 'http://www.amazon.com/Affliction-Anita-Blake-Vampire-Hunter/dp/0425255700?tag=NYTBS-20', 'title': 'AFFLICTION', 'author': 'Laurell K Hamilton', 'publisher': 'Berkley', 'description': 'The vampire hunter Anita Blake encounters a dangerous new breed of zombies.\xa0', 'star_rating': 4.3, 'nb_Amazon_reviews': 1372, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2013-07-21', 'last_date_listed': '2013-07-28', 'worst_rank': 15, 'best_rank': 5, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f18'), 'Amazon_url': 'http://www.amazon.com/After-You-Novel-Jojo-Moyes/dp/0525426590?tag=NYTBS-20', 'title': 'AFTER YOU', 'author': 'Jojo Moyes', 'publisher': 'Pamela Dorman/Viking', 'description': 'In a sequel to “Me Before You,” Louisa Clark tries to put her life back together after the death of Will Traynor.', 'star_rating': 4.2, 'nb_Amazon_reviews': 5201, 'weeks_on_list': 21, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2015-10-18', 'last_date_listed': '2016-07-31', 'worst_rank': 19, 'best_rank': 3, 'times_listed': 28, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f19'), 'Amazon_url': 'http://www.amazon.com/Against-All-Enemies-Tom-Clancy/dp/042524606X?tag=NYTBS-20', 'title': 'AGAINST ALL ENEMIES', 'author': 'Tom Clancy with Peter Telep', 'publisher': 'Putnam', 'description': 'Maxwell Moore, a former C.I.A. officer, pursues the terrorists who killed his colleagues in a bomb attack off the coast of Pakistan.', 'star_rating': 3.4, 'nb_Amazon_reviews': 620, 'weeks_on_list': 7, 'NYT_Price': 28.95, 'Amazon_Price': 9.99, 'first_date_listed': '2011-07-03', 'last_date_listed': '2011-08-28', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 9, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1a'), 'Amazon_url': 'http://www.amazon.com/Agenda-21-Glenn-Beck-ebook/dp/B00902UC0W?tag=NYTBS-20', 'title': 'AGENDA 21', 'author': 'Glenn Beck with Harriet Parke', 'publisher': 'Threshold Editions/Mercury Radio Arts', 'description': 'A girl questions authority in the U.N.-created totalitarian successor to the United States.', 'star_rating': 4.5, 'nb_Amazon_reviews': 2880, 'weeks_on_list': 5, 'NYT_Price': 26.0, 'Amazon_Price': 9.49, 'first_date_listed': '2012-12-09', 'last_date_listed': '2013-01-13', 'worst_rank': 17, 'best_rank': 3, 'times_listed': 6, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1b'), 'Amazon_url': 'http://www.amazon.com/Agincourt-Bernard-Cornwell/dp/0061578916?tag=NYTBS-20', 'title': 'AGINCOURT', 'author': 'Bernard Cornwell', 'publisher': 'Harper', 'description': 'An English archer with a complicated past joins Henry V at the famous battle against the French in 1415.', 'star_rating': 4.3, 'nb_Amazon_reviews': 609, 'weeks_on_list': 4, 'NYT_Price': 27.99, 'Amazon_Price': 12.99, 'first_date_listed': '2009-02-08', 'last_date_listed': '2009-03-08', 'worst_rank': 20, 'best_rank': 4, 'times_listed': 5, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1c'), 'Amazon_url': 'http://www.amazon.com/Aleph-Paulo-Coelho/dp/0307700186?tag=NYTBS-20', 'title': 'ALEPH', 'author': 'Paulo Coelho', 'publisher': 'Knopf', 'description': 'A crisis of faith is the impetus for a journey through time and space, on a path that teaches love, forgiveness and courage.', 'star_rating': 4.2, 'nb_Amazon_reviews': 451, 'weeks_on_list': 2, 'NYT_Price': 24.95, 'Amazon_Price': 2.99, 'first_date_listed': '2011-10-16', 'last_date_listed': '2011-10-23', 'worst_rank': 7, 'best_rank': 6, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1d'), 'Amazon_url': 'http://www.amazon.com/Alex-Cross-Run-James-Patterson-ebook/dp/B0076DCP16?tag=NYTBS-20', 'title': 'ALEX CROSS, RUN', 'author': 'James Patterson', 'publisher': 'Little, Brown', 'description': "While Detective Alex Cross pursues a serial killer (or killers?) in Washington, D.C., he's too busy to notice that someone has been watching him.", 'star_rating': 4.5, 'nb_Amazon_reviews': 2939, 'weeks_on_list': 8, 'NYT_Price': 28.99, 'Amazon_Price': 9.99, 'first_date_listed': '2013-03-10', 'last_date_listed': '2013-05-05', 'worst_rank': 18, 'best_rank': 1, 'times_listed': 9, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1e'), 'Amazon_url': 'http://www.amazon.com/Alex-Crosss-Trial-James-Patterson/dp/0446557781?tag=NYTBS-20', 'title': 'ALEX CROSS’S ‘TRIAL’', 'author': 'James Patterson and Richard DiLallo', 'publisher': 'Little, Brown', 'description': 'The detective Alex Cross writes a novel about his great-uncle, who fought the Klan.', 'star_rating': 4.4, 'nb_Amazon_reviews': 1754, 'weeks_on_list': 6, 'NYT_Price': 27.99, 'Amazon_Price': 9.99, 'first_date_listed': '2009-09-13', 'last_date_listed': '2009-10-25', 'worst_rank': 16, 'best_rank': 1, 'times_listed': 7, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f1f'), 'Amazon_url': 'http://www.amazon.com/All-Dressed-White-Under-Suspicion-ebook/dp/B00UDCI30E?tag=NYTBS-20', 'title': 'ALL DRESSED IN WHITE', 'author': 'Mary Higgins Clark and Alafair Burke', 'publisher': 'Simon & Schuster', 'description': 'A TV producer investigates a bride’s disappearance for her show, “Under Suspicion.”', 'star_rating': 4.6, 'nb_Amazon_reviews': 1200, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2015-12-06', 'last_date_listed': '2015-12-27', 'worst_rank': 19, 'best_rank': 7, 'times_listed': 4, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f20'), 'Amazon_url': 'http://www.amazon.com/All-Fall-Down-A-Novel-ebook/dp/B00DPM909W?tag=NYTBS-20', 'title': 'ALL FALL DOWN', 'author': 'Jennifer Weiner', 'publisher': 'Atria', 'description': 'A woman becomes addicted to pain medication.', 'star_rating': 4.1, 'nb_Amazon_reviews': 1401, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2014-07-06', 'last_date_listed': '2014-08-03', 'worst_rank': 15, 'best_rank': 5, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f21'), 'Amazon_url': 'http://www.amazon.com/All-Light-We-Cannot-See/dp/1476746583?tag=NYTBS-20', 'title': 'ALL THE LIGHT WE CANNOT SEE', 'author': 'Anthony Doerr', 'publisher': 'Scribner', 'description': 'The lives of a blind French girl and a gadget-obsessed German boy before and during World War II; the winner of the 2015 Pulitzer Prize. \xa0', 'star_rating': 4.6, 'nb_Amazon_reviews': 28454, 'weeks_on_list': 134, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2014-05-25', 'last_date_listed': '2017-01-29', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 141, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f22'), 'Amazon_url': 'http://www.amazon.com/All-Single-Ladies-A-Novel-ebook/dp/B00NEOM5FM?tag=NYTBS-20', 'title': 'ALL THE SINGLE LADIES', 'author': 'Dorothea Benton Frank', 'publisher': 'Morrow/HarperCollins', 'description': 'Three friends in South Carolina’s Lowcountry grapple with the challenges of being unmarried.', 'star_rating': 4.1, 'nb_Amazon_reviews': 946, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2015-06-28', 'last_date_listed': '2015-07-19', 'worst_rank': 19, 'best_rank': 6, 'times_listed': 4, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f23'), 'Amazon_url': 'http://www.amazon.com/Almost-Forgot-About-You-Novel/dp/1101902574?tag=NYTBS-20', 'title': 'I ALMOST FORGOT ABOUT YOU', 'author': 'Terry McMillan', 'publisher': 'Crown', 'description': 'A middle-aged optometrist, twice divorced and tired of her work, decides to reinvent her life.', 'star_rating': 4.3, 'nb_Amazon_reviews': 1083, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-06-26', 'last_date_listed': '2016-07-24', 'worst_rank': 20, 'best_rank': 12, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f24'), 'Amazon_url': 'http://www.amazon.com/America-A-Novel-Ethan-Canin/dp/0679456805?tag=NYTBS-20', 'title': 'AMERICA AMERICA', 'author': 'Ethan Canin', 'publisher': 'Random House', 'description': 'A boy becomes entangled with a powerful family in upstate New York in the early 1970s.', 'star_rating': 3.9, 'nb_Amazon_reviews': 97, 'weeks_on_list': 2, 'NYT_Price': 27.0, 'Amazon_Price': 11.99, 'first_date_listed': '2008-07-13', 'last_date_listed': '2008-07-27', 'worst_rank': 19, 'best_rank': 15, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f25'), 'Amazon_url': 'http://www.amazon.com/American-Assassin-Thriller-Mitch-Rapp-ebook/dp/B003UV8T9A?tag=NYTBS-20', 'title': 'AMERICAN ASSASSIN', 'author': 'Vince Flynn', 'publisher': 'Atria', 'description': 'In the wake of the Lockerbie bombing, Mitch Rapp takes on his first antiterrorist assignment.', 'star_rating': 4.6, 'nb_Amazon_reviews': 5574, 'weeks_on_list': 8, 'NYT_Price': 27.99, 'Amazon_Price': 8.99, 'first_date_listed': '2010-10-31', 'last_date_listed': '2011-01-09', 'worst_rank': 17, 'best_rank': 1, 'times_listed': 11, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f26'), 'Amazon_url': 'http://www.amazon.com/American-Wife-Random-Readers-Circle/dp/0812975405?tag=NYTBS-20', 'title': 'AMERICAN WIFE', 'author': 'Curtis Sittenfeld', 'publisher': 'Random House', 'description': 'A pretty librarian marries the alcoholic son of a wealthy political family who somehow becomes president.', 'star_rating': 3.5, 'nb_Amazon_reviews': 514, 'weeks_on_list': 5, 'NYT_Price': 26.0, 'Amazon_Price': 11.99, 'first_date_listed': '2008-09-21', 'last_date_listed': '2008-10-26', 'worst_rank': 19, 'best_rank': 3, 'times_listed': 6, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f27'), 'Amazon_url': 'http://www.amazon.com/Among-Mad-Maisie-Dobbs-Book/dp/0312429258?tag=NYTBS-20', 'title': 'AMONG THE MAD', 'author': 'Jacqueline Winspear', 'publisher': 'Holt', 'description': 'Maisie Dobbs is involved in a hunt for a man who promises to wreak destruction on London.', 'star_rating': 4.5, 'nb_Amazon_reviews': 312, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 9.99, 'first_date_listed': '2009-03-08', 'last_date_listed': '2009-03-08', 'worst_rank': 9, 'best_rank': 9, 'times_listed': 1, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f28'), 'Amazon_url': 'http://www.amazon.com/An-Officer-Spy-A-novel/dp/0385349580?tag=NYTBS-20', 'title': 'AN OFFICER AND A SPY', 'author': 'Robert Harris', 'publisher': 'Knopf', 'description': 'A fictionalized account of the Dreyfus Affair focuses on Lt. Col. Georges Picquart, who discovered evidence exonerating Dreyfus and bravely defended him.', 'star_rating': 4.5, 'nb_Amazon_reviews': 1491, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2014-02-16', 'last_date_listed': '2014-03-02', 'worst_rank': 14, 'best_rank': 8, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f29'), 'Amazon_url': 'http://www.amazon.com/Anathem-Neal-Stephenson/dp/B003B3NW7G?tag=NYTBS-20', 'title': 'ANATHEM', 'author': 'Neal Stephenson', 'publisher': 'William Morrow', 'description': 'An order of cloistered mathematicians and scientists must save their Earth-like planet when catastrophe threatens.', 'star_rating': 4.1, 'nb_Amazon_reviews': 916, 'weeks_on_list': 4, 'NYT_Price': 29.95, 'Amazon_Price': 8.99, 'first_date_listed': '2008-09-28', 'last_date_listed': '2008-10-19', 'worst_rank': 15, 'best_rank': 1, 'times_listed': 4, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2a'), 'Amazon_url': 'http://www.amazon.com/And-Mountains-Echoed-Khaled-Hosseini/dp/1594632383?tag=NYTBS-20', 'title': 'AND THE MOUNTAINS ECHOED', 'author': 'Khaled Hosseini', 'publisher': 'Riverhead', 'description': 'A multigenerational family saga, by the author of “The Kite Runner,” centering on a brother and sister from a remote, impoverished village in Afghanistan.', 'star_rating': 4.2, 'nb_Amazon_reviews': 8097, 'weeks_on_list': 24, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2013-06-09', 'last_date_listed': '2014-01-19', 'worst_rank': 20, 'best_rank': 2, 'times_listed': 28, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2b'), 'Amazon_url': 'http://www.amazon.com/Angels-Game-Carlos-Ruiz-Zafon/dp/0767931114?tag=NYTBS-20', 'title': "THE ANGEL'S GAME", 'author': 'Carlos Ruiz Zafón', 'publisher': 'Doubleday', 'description': 'A Barcelona writer accepts a sinister commission.', 'star_rating': 4.2, 'nb_Amazon_reviews': 588, 'weeks_on_list': 5, 'NYT_Price': 26.95, 'Amazon_Price': 8.99, 'first_date_listed': '2009-07-05', 'last_date_listed': '2009-08-16', 'worst_rank': 18, 'best_rank': 3, 'times_listed': 6, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2c'), 'Amazon_url': 'http://www.amazon.com/Angels-Table-Shirley-Goodness-Christmas-ebook/dp/B007WKE4TE?tag=NYTBS-20', 'title': 'ANGELS AT THE TABLE', 'author': 'Debbie Macomber', 'publisher': 'Ballantine', 'description': 'Angels cook up a plan to reunite a young couple.', 'star_rating': 4.5, 'nb_Amazon_reviews': 640, 'weeks_on_list': 3, 'NYT_Price': 18.0, 'Amazon_Price': 5.99, 'first_date_listed': '2012-11-11', 'last_date_listed': '2012-11-25', 'worst_rank': 13, 'best_rank': 9, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2d'), 'Amazon_url': 'http://www.amazon.com/Another-Brooklyn-Novel-Jacqueline-Woodson/dp/0062359983?tag=NYTBS-20', 'title': 'ANOTHER BROOKLYN', 'author': 'Jacqueline Woodson', 'publisher': 'Amistad/HarperCollins', 'description': "An adult novel by an award-winning children's book author centers on memories of growing up and the close friendship of four girls.", 'star_rating': 4.1, 'nb_Amazon_reviews': 324, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2016-08-28', 'last_date_listed': '2016-09-04', 'worst_rank': 20, 'best_rank': 16, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2e'), 'Amazon_url': 'http://www.amazon.com/Apprentice-Death-J-D-Robb/dp/1101987979?tag=NYTBS-20', 'title': 'APPRENTICE IN DEATH', 'author': 'J D Robb', 'publisher': 'Berkley', 'description': 'Lt. Eve Dallas of the N.Y.P.D. is on the case when three skaters are shot by a sniper. By Nora Roberts, writing pseudonymously.', 'star_rating': 4.8, 'nb_Amazon_reviews': 2457, 'weeks_on_list': 4, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2016-09-25', 'last_date_listed': '2016-10-23', 'worst_rank': 20, 'best_rank': 1, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f2f'), 'Amazon_url': 'http://www.amazon.com/Arctic-Drift-Dirk-Novel-Adventure/dp/0399155295?tag=NYTBS-20', 'title': 'ARCTIC DRIFT', 'author': 'Clive Cussler and Dirk Cussler', 'publisher': 'Putnam', 'description': 'In his 20th adventure, Dirk Pitt searches for a crucial element that will help reverse global warming.', 'star_rating': 4.3, 'nb_Amazon_reviews': 341, 'weeks_on_list': 6, 'NYT_Price': 27.95, 'Amazon_Price': 4.99, 'first_date_listed': '2008-12-14', 'last_date_listed': '2009-02-01', 'worst_rank': 19, 'best_rank': 3, 'times_listed': 8, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f30'), 'Amazon_url': 'http://www.amazon.com/As-Crow-Flies-Longmire-Mysteries/dp/0670023515?tag=NYTBS-20', 'title': 'AS THE CROW FLIES', 'author': 'Craig Johnson', 'publisher': 'Viking', 'description': '', 'star_rating': 4.7, 'nb_Amazon_reviews': 608, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2012-06-03', 'last_date_listed': '2012-06-03', 'worst_rank': 17, 'best_rank': 17, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f31'), 'Amazon_url': 'http://www.amazon.com/Ascension-Star-Wars-Fate-Legends-ebook/dp/B004J4WM7M?tag=NYTBS-20', 'title': 'ASCENSION', 'author': 'Christie Golden', 'publisher': 'LucasBooks', 'description': 'The Jedi face the Sith, a deposed dictator and an evil entity hungry to become a god; a “Star Wars: Fate of the Jedi” book.', 'star_rating': 4.1, 'nb_Amazon_reviews': 203, 'weeks_on_list': 2, 'NYT_Price': 27.0, 'Amazon_Price': 7.99, 'first_date_listed': '2011-08-28', 'last_date_listed': '2011-09-04', 'worst_rank': 16, 'best_rank': 7, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f32'), 'Amazon_url': 'http://www.amazon.com/Ashley-Bell-Novel-Dean-Koontz-ebook/dp/B00VCZOKM6?tag=NYTBS-20', 'title': 'ASHLEY BELL', 'author': 'Dean Koontz', 'publisher': 'Bantam', 'description': 'A young Southern California writer who survived a fatal diagnosis sets out to find a woman she has been told she must save, overcoming many obstacles in the process.', 'star_rating': 3.9, 'nb_Amazon_reviews': 1919, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2015-12-27', 'last_date_listed': '2016-01-31', 'worst_rank': 17, 'best_rank': 12, 'times_listed': 6, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f33'), 'Amazon_url': 'http://www.amazon.com/Assassination-Option-Clandestine-Operations-Novel/dp/039917124X?tag=NYTBS-20', 'title': 'THE ASSASSINATION OPTION', 'author': 'W E B Griffin and William E Butterworth IV', 'publisher': 'Putnam', 'description': 'The second novel in a new series about the Cold War and the early C.I.A.', 'star_rating': 4.2, 'nb_Amazon_reviews': 689, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2015-01-18', 'last_date_listed': '2015-01-18', 'worst_rank': 7, 'best_rank': 7, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f34'), 'Amazon_url': 'http://www.amazon.com/Assegai-Wilbur-Smith/dp/0312570406?tag=NYTBS-20', 'title': 'ASSEGAI', 'author': 'Wilbur Smith', 'publisher': 'Thomas Dunne/St. Martin’s', 'description': 'A professional hunting  guide in British East Africa on the brink of World War I spies on a German client and his mysterious mistress.', 'star_rating': 4.3, 'nb_Amazon_reviews': 231, 'weeks_on_list': 3, 'NYT_Price': 27.95, 'Amazon_Price': 9.99, 'first_date_listed': '2009-05-31', 'last_date_listed': '2009-06-14', 'worst_rank': 15, 'best_rank': 9, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f35'), 'Amazon_url': 'http://www.amazon.com/At-Edge-Orchard-Tracy-Chevalier/dp/0525953000?tag=NYTBS-20', 'title': 'AT THE EDGE OF THE ORCHARD', 'author': 'Tracy Chevalier', 'publisher': 'Viking', 'description': 'Two generations of 19th-century American pioneer life unfold in Chevalier’s eighth novel.', 'star_rating': 3.9, 'nb_Amazon_reviews': 375, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 4.99, 'first_date_listed': '2016-04-03', 'last_date_listed': '2016-04-10', 'worst_rank': 19, 'best_rank': 14, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f36'), 'Amazon_url': 'http://www.amazon.com/At-Waters-Edge-A-Novel/dp/0385523238?tag=NYTBS-20', 'title': "AT THE WATER'S EDGE", 'author': 'Sara Gruen', 'publisher': 'Spiegel & Grau', 'description': 'In the course of a search for the Loch Ness monster, a Philadelphia socialite uncovers secrets about her husband.', 'star_rating': 3.9, 'nb_Amazon_reviews': 2690, 'weeks_on_list': 7, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2015-04-19', 'last_date_listed': '2015-06-21', 'worst_rank': 18, 'best_rank': 6, 'times_listed': 10, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f37'), 'Amazon_url': 'http://www.amazon.com/Avenue-Mysteries-John-Irving/dp/1451664168?tag=NYTBS-20', 'title': 'AVENUE OF MYSTERIES', 'author': 'John Irving', 'publisher': 'Simon & Schuster', 'description': 'In Irving’s 14th novel, a Mexican writer on a journey to the Philippines recalls his escape from a humble childhood.', 'star_rating': 3.4, 'nb_Amazon_reviews': 597, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2015-11-22', 'last_date_listed': '2016-01-03', 'worst_rank': 20, 'best_rank': 5, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f38'), 'Amazon_url': 'http://www.amazon.com/Bad-Blood-Virgil-Flowers-novel/dp/0399156909?tag=NYTBS-20', 'title': 'BAD BLOOD', 'author': 'John Sandford', 'publisher': 'Putnam', 'description': 'Virgil Flowers is summoned to investigate a monstrous multigenerational conspiracy.', 'star_rating': 4.4, 'nb_Amazon_reviews': 751, 'weeks_on_list': 4, 'NYT_Price': 27.95, 'Amazon_Price': 4.99, 'first_date_listed': '2010-10-10', 'last_date_listed': '2010-10-31', 'worst_rank': 13, 'best_rank': 4, 'times_listed': 4, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f39'), 'Amazon_url': 'http://www.amazon.com/Bark-Stories-Lorrie-Moore/dp/0307594130?tag=NYTBS-20', 'title': 'BARK', 'author': 'Lorrie Moore', 'publisher': 'Knopf', 'description': 'Moore’s first story collection in 16 years.', 'star_rating': 3.6, 'nb_Amazon_reviews': 157, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2014-03-16', 'last_date_listed': '2014-03-16', 'worst_rank': 13, 'best_rank': 13, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3a'), 'Amazon_url': 'http://www.amazon.com/Basketball-Jones-E-Lynn-Harris/dp/0767926277?tag=NYTBS-20', 'title': 'BASKETBALL JONES', 'author': 'E Lynn Harris', 'publisher': 'Doubleday', 'description': 'An N.B.A. star hides his male lover.', 'star_rating': 4.4, 'nb_Amazon_reviews': 158, 'weeks_on_list': 2, 'NYT_Price': 22.95, 'Amazon_Price': 10.99, 'first_date_listed': '2009-02-15', 'last_date_listed': '2009-03-01', 'worst_rank': 19, 'best_rank': 11, 'times_listed': 3, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3b'), 'Amazon_url': 'http://www.amazon.com/Beach-Town-Mary-Kay-Andrews/dp/1250065933?tag=NYTBS-20', 'title': 'BEACH TOWN', 'author': 'Mary Kay Andrews', 'publisher': "St. Martin's", 'description': 'Complications arise when a Hollywood location scout tries to arrange a shoot in a Florida Gulf Coast town.', 'star_rating': 4.1, 'nb_Amazon_reviews': 782, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2015-06-07', 'last_date_listed': '2015-06-28', 'worst_rank': 17, 'best_rank': 6, 'times_listed': 4, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3c'), 'Amazon_url': 'http://www.amazon.com/Beat-Reaper-Novel-Josh-Bazell/dp/0316032212?tag=NYTBS-20', 'title': 'BEAT THE REAPER', 'author': 'Josh Bazell', 'publisher': 'Little, Brown', 'description': 'A former hit man for the mob who has become a doctor is threatened when a gangster patient recognizes him.', 'star_rating': 4.0, 'nb_Amazon_reviews': 389, 'weeks_on_list': 2, 'NYT_Price': 24.99, 'Amazon_Price': 9.99, 'first_date_listed': '2009-02-01', 'last_date_listed': '2009-02-08', 'worst_rank': 14, 'best_rank': 13, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3d'), 'Amazon_url': 'http://www.amazon.com/Beautiful-Day-Novel-Elin-Hilderbrand-ebook/dp/B00A2DKQ72?tag=NYTBS-20', 'title': 'BEAUTIFUL DAY', 'author': 'Elin Hilderbrand', 'publisher': 'Reagan Arthur/Little, Brown', 'description': 'Various sorts of disaster threaten a Nantucket wedding.\xa0', 'star_rating': 4.3, 'nb_Amazon_reviews': 804, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2013-07-14', 'last_date_listed': '2013-08-11', 'worst_rank': 19, 'best_rank': 7, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3e'), 'Amazon_url': 'http://www.amazon.com/Beautiful-Ruins-Novel-Jess-Walter/dp/0061928178?tag=NYTBS-20', 'title': 'BEAUTIFUL RUINS', 'author': 'Jess Walter', 'publisher': 'Harper/HarperCollins', 'description': 'Ruins both emotional and architectural, in Italy, Hollywood and elsewhere, figure in this sweeping novel.', 'star_rating': 3.9, 'nb_Amazon_reviews': 2901, 'weeks_on_list': 4, 'NYT_Price': 25.99, 'Amazon_Price': 11.49, 'first_date_listed': '2012-07-15', 'last_date_listed': '2012-08-19', 'worst_rank': 19, 'best_rank': 11, 'times_listed': 6, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f3f'), 'Amazon_url': 'http://www.amazon.com/Beautiful-You-Novel-Chuck-Palahniuk/dp/0385538030?tag=NYTBS-20', 'title': 'BEAUTIFUL YOU', 'author': 'Chuck Palahniuk', 'publisher': 'Doubleday', 'description': 'A Manhattan lawyer inadvertently becomes a test subject for a line of sex toys.', 'star_rating': 3.0, 'nb_Amazon_reviews': 351, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 10.99, 'first_date_listed': '2014-11-09', 'last_date_listed': '2014-11-16', 'worst_rank': 16, 'best_rank': 5, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f40'), 'Amazon_url': 'http://www.amazon.com/Before-Fall-Noah-Hawley-ebook/dp/B0151YQUTE?tag=NYTBS-20', 'title': 'BEFORE THE FALL', 'author': 'Noah Hawley', 'publisher': 'Grand Central', 'description': 'After a private jet crashes, a firestorm of media madness ensues.', 'star_rating': 4.0, 'nb_Amazon_reviews': 4075, 'weeks_on_list': 14, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-06-19', 'last_date_listed': '2016-09-18', 'worst_rank': 15, 'best_rank': 2, 'times_listed': 14, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f41'), 'Amazon_url': 'http://www.amazon.com/Before-Go-Sleep-S-Watson/dp/0062060562?tag=NYTBS-20', 'title': 'BEFORE I GO TO SLEEP', 'author': 'S J Watson', 'publisher': 'Harper/HarperCollins', 'description': 'After a mysterious accident, an amnesiac cannot remember her past or form new memories.', 'star_rating': 4.1, 'nb_Amazon_reviews': 3756, 'weeks_on_list': 2, 'NYT_Price': 25.99, 'Amazon_Price': 11.99, 'first_date_listed': '2011-07-03', 'last_date_listed': '2011-08-14', 'worst_rank': 20, 'best_rank': 7, 'times_listed': 5, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f42'), 'Amazon_url': 'http://www.amazon.com/Behind-Closed-Doors-intriguing-psychological/dp/1250121000?tag=NYTBS-20', 'title': 'BEHIND CLOSED DOORS', 'author': 'B A Paris', 'publisher': 'St. Martin’s', 'description': 'What cracks exist in an "it couple\'s" relationship?', 'star_rating': 4.1, 'nb_Amazon_reviews': 5050, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-08-28', 'last_date_listed': '2016-09-25', 'worst_rank': 19, 'best_rank': 15, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f43'), 'Amazon_url': 'http://www.amazon.com/Being-Elizabeth-Barbara-Taylor-Bradford/dp/0312354630?tag=NYTBS-20', 'title': 'BEING ELIZABETH', 'author': 'Barbara Taylor Bradford', 'publisher': 'St. Martin’s', 'description': 'A 25-year-old newly in control of her family’s corporate empire faces tough choices in business and in love.', 'star_rating': 3.6, 'nb_Amazon_reviews': 93, 'weeks_on_list': 1, 'NYT_Price': 27.95, 'Amazon_Price': 7.99, 'first_date_listed': '2008-09-07', 'last_date_listed': '2008-09-14', 'worst_rank': 18, 'best_rank': 12, 'times_listed': 2, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f44'), 'Amazon_url': 'http://www.amazon.com/Bel-Air-Dead-Stone-Barrington-Novel-ebook/dp/B004LRPDP0?tag=NYTBS-20', 'title': 'BEL-AIR DEAD', 'author': 'Stuart Woods', 'publisher': 'Putnam', 'description': 'The New York lawyer Stone Barrington makes enemies when he represents a widow in the sale of a world-famous movie studio.', 'star_rating': 4.2, 'nb_Amazon_reviews': 211, 'weeks_on_list': 3, 'NYT_Price': 25.95, 'Amazon_Price': 9.99, 'first_date_listed': '2011-05-15', 'last_date_listed': '2011-06-05', 'worst_rank': 17, 'best_rank': 3, 'times_listed': 4, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f45'), 'Amazon_url': 'http://www.amazon.com/Best-Friends-Forever-Jennifer-Weiner/dp/0743294297?tag=NYTBS-20', 'title': 'BEST FRIENDS FOREVER', 'author': 'Jennifer Weiner', 'publisher': 'Atria', 'description': 'Childhood friends, estranged in high school, reunite years later when the popular one needs the mousy one’s help.', 'star_rating': 3.4, 'nb_Amazon_reviews': 334, 'weeks_on_list': 7, 'NYT_Price': 26.99, 'Amazon_Price': 11.99, 'first_date_listed': '2009-08-02', 'last_date_listed': '2009-09-13', 'worst_rank': 15, 'best_rank': 1, 'times_listed': 7, 'better_price': 'Amazon'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f46'), 'Amazon_url': 'http://www.amazon.com/Best-Kept-Secret-Clifton-Chronicles/dp/1250040779?tag=NYTBS-20', 'title': 'BEST KEPT SECRET', 'author': 'Jeffrey Archer', 'publisher': "St. Martin's", 'description': 'In Volume 3 of the Clifton Chronicles, the focus shifts to a new generation — Sebastian, the son of Harry and Emma Clifton.\xa0', 'star_rating': 4.3, 'nb_Amazon_reviews': 2431, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2013-05-19', 'last_date_listed': '2013-06-16', 'worst_rank': 15, 'best_rank': 4, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df3f47'), 'Amazon_url': 'http://www.amazon.com/Betrayal-A-Novel-Danielle-Steel-ebook/dp/B005BUG6TI?tag=NYTBS-20', 'title': 'BETRAYAL', 'author': 'Danielle Steel', 'publisher': 'Delacorte Press', 'description': 'A happy and successful Hollywood director discovers that someone is embezzling large sums of her money.', 'star_rating': 4.4, 'nb_Amazon_reviews': 632, 'weeks_on_list': 5, 'NYT_Price': 28.0, 'Amazon_Price': 7.99, 'first_date_listed': '2012-04-15', 'last_date_listed': '2012-05-27', 'worst_rank': 19, 'best_rank': 3, 'times_listed': 6, 'better_price': 'Amazon'}
# ...
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439a'), 'Amazon_url': 'https://www.amazon.com/Spymaster-Thriller-Scot-Harvath-Book-ebook/dp/B075RMMZ6K?tag=NYTBS-20', 'title': 'SPYMASTER', 'author': 'Brad Thor', 'publisher': 'Emily Bestler/Atria', 'description': 'The 18th book in the Scot Harvath series. As a war looms, a counterterrorism operative takes on a new role his own way.', 'star_rating': 4.5, 'nb_Amazon_reviews': 719, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'first_date_listed': '2018-07-22', 'last_date_listed': '2018-07-22', 'worst_rank': 2, 'best_rank': 2, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439b'), 'Amazon_url': 'https://www.amazon.com/Still-Me-Novel-Jojo-Moyes-ebook/dp/B073YTMMQS?tag=NYTBS-20', 'title': 'STILL ME', 'author': 'Jojo Moyes', 'publisher': 'Pamela Dorman/Viking', 'description': 'Louisa Clark moves to New York and is torn between high society and the life she enjoys at a vintage clothing store.', 'star_rating': 4.7, 'nb_Amazon_reviews': 1267, 'weeks_on_list': 7, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2018-02-18', 'last_date_listed': '2018-04-01', 'worst_rank': 14, 'best_rank': 2, 'times_listed': 7, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439c'), 'Amazon_url': 'https://www.amazon.com/Swing-Time-Zadie-Smith/dp/1594203989?tag=NYTBS-20', 'title': 'SWING TIME', 'author': 'Zadie Smith', 'publisher': 'Penguin Press', 'description': 'The British novelist explores friendship, race, music and global politics.', 'star_rating': 3.5, 'nb_Amazon_reviews': 349, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2016-12-04', 'last_date_listed': '2017-01-15', 'worst_rank': 20, 'best_rank': 14, 'times_listed': 6, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439d'), 'Amazon_url': 'https://www.amazon.com/Tea-Girl-Hummingbird-Lane/dp/1501154826?tag=NYTBS-20', 'title': 'THE TEA GIRL OF HUMMINGBIRD LANE', 'author': 'Lisa See', 'publisher': 'Scribner', 'description': 'A woman from rural China eventually moves to California, where the daughter she gave up for adoption lives.', 'star_rating': 4.5, 'nb_Amazon_reviews': 1580, 'weeks_on_list': 4, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2017-04-09', 'last_date_listed': '2017-04-30', 'worst_rank': 14, 'best_rank': 6, 'times_listed': 4, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439e'), 'Amazon_url': 'https://www.amazon.com/Temptation-Forgiveness-Commissario-Brunetti-Mystery-ebook/dp/B074WFFPVG?tag=NYTBS-20', 'title': 'THE TEMPTATION OF FORGIVENESS', 'author': 'Donna Leon', 'publisher': 'Atlantic Monthly', 'description': 'The 27th book in the Commissario Guido Brunetti series.', 'star_rating': 4.1, 'nb_Amazon_reviews': 242, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.49, 'first_date_listed': '2018-04-08', 'last_date_listed': '2018-04-08', 'worst_rank': 11, 'best_rank': 11, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df439f'), 'Amazon_url': 'https://www.amazon.com/Testimony-Scott-Turow/dp/1455553549?tag=NYTBS-20', 'title': 'TESTIMONY', 'author': 'Scott Turow', 'publisher': 'Grand Central', 'description': 'A former Illinois prosecutor joins the International Criminal Court to investigate a massacre in Bosnia.', 'star_rating': 3.5, 'nb_Amazon_reviews': 617, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-06-04', 'last_date_listed': '2017-07-02', 'worst_rank': 14, 'best_rank': 6, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a0'), 'Amazon_url': 'https://www.amazon.com/Then-She-Was-Gone-Novel-ebook/dp/B074MDD3H6?tag=NYTBS-20', 'title': 'THEN SHE WAS GONE', 'author': 'Lisa Jewell', 'publisher': 'Atria', 'description': 'Ten years after her daughter disappears, a woman tries to get her life in order but remains haunted by unanswered questions.', 'star_rating': 4.3, 'nb_Amazon_reviews': 744, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2018-05-06', 'last_date_listed': '2018-05-06', 'worst_rank': 13, 'best_rank': 13, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a1'), 'Amazon_url': 'https://www.amazon.com/There-novel-Tommy-Orange/dp/0525520376?tag=NYTBS-20', 'title': 'THERE THERE', 'author': 'Tommy Orange', 'publisher': 'Knopf', 'description': 'A multigenerational story exploring the plight of the urban Native American.', 'star_rating': 4.1, 'nb_Amazon_reviews': 480, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 13.99, 'first_date_listed': '2018-06-24', 'last_date_listed': '2018-07-22', 'worst_rank': 13, 'best_rank': 6, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a2'), 'Amazon_url': 'https://www.amazon.com/Thief-Novel-Black-Dagger-Brotherhood/dp/0451475216?tag=NYTBS-20', 'title': 'THE THIEF', 'author': 'JR Ward', 'publisher': 'Ballantine', 'description': 'The 16th book in the Black Dagger Brotherhood series. Sola Morte falls for a man who sells weapons to a group of vampire warriors.', 'star_rating': 4.7, 'nb_Amazon_reviews': 766, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2018-04-29', 'last_date_listed': '2018-04-29', 'worst_rank': 4, 'best_rank': 4, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a3'), 'Amazon_url': 'https://www.amazon.com/This-Grave-Hour-Maisie-Dobbs-ebook/dp/B01HBPQV2W?tag=NYTBS-20', 'title': 'IN THIS GRAVE HOUR', 'author': 'Jacqueline Winspear', 'publisher': 'Harper/HarperCollins', 'description': 'The psychologist and investigator Maisie Dobbs gets an assignment as World War II begins.', 'star_rating': 4.7, 'nb_Amazon_reviews': 488, 'weeks_on_list': 2, 'NYT_Price': 0.0, 'Amazon_Price': 10.99, 'first_date_listed': '2017-04-02', 'last_date_listed': '2017-04-09', 'worst_rank': 15, 'best_rank': 5, 'times_listed': 2, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a4'), 'Amazon_url': 'https://www.amazon.com/Thrawn-Star-Wars-Timothy-Zahn/dp/0345511271?tag=NYTBS-20', 'title': 'THRAWN', 'author': 'Timothy Zahn', 'publisher': 'Del Rey', 'description': 'The origins of Grand Admiral Thrawn, an iconic “Star Wars” villain.', 'star_rating': 4.7, 'nb_Amazon_reviews': 1136, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-04-30', 'last_date_listed': '2017-05-14', 'worst_rank': 12, 'best_rank': 2, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a5'), 'Amazon_url': 'https://www.amazon.com/Two-Heart-James-Patterson/dp/0316468908?tag=NYTBS-20', 'title': 'TWO FROM THE HEART', 'author': 'James Patterson and Frank Costantini, Emily Raymond and Brian Sitts', 'publisher': 'Little, Brown', 'description': 'Two stories about the power of stories.', 'star_rating': 3.8, 'nb_Amazon_reviews': 140, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-04-30', 'last_date_listed': '2017-05-14', 'worst_rank': 15, 'best_rank': 6, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a6'), 'Amazon_url': 'https://www.amazon.com/Typhoon-Oregon-Files-Clive-Cussler-ebook/dp/B06WRQG5NS?tag=NYTBS-20', 'title': 'TYPHOON FURY', 'author': 'Clive Cussler and Boyd Morrison', 'publisher': 'Putnam', 'description': 'Juan Cabrillo chases a Filipino insurgent during a megastorm.', 'star_rating': 4.7, 'nb_Amazon_reviews': 570, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-11-26', 'last_date_listed': '2017-12-10', 'worst_rank': 14, 'best_rank': 5, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a7'), 'Amazon_url': 'https://www.amazon.com/Unbound-Stone-Barrington-Novel-Stuart-ebook/dp/B071YC1VHD?tag=NYTBS-20', 'title': 'UNBOUND', 'author': 'Stuart Woods', 'publisher': 'Putnam', 'description': 'The 44th book in the Stone Barrington series.', 'star_rating': 4.4, 'nb_Amazon_reviews': 305, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2018-01-21', 'last_date_listed': '2018-01-21', 'worst_rank': 7, 'best_rank': 7, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a8'), 'Amazon_url': 'https://www.amazon.com/Uncommon-Type-Stories-Tom-Hanks/dp/1101946156?tag=NYTBS-20', 'title': 'UNCOMMON TYPE', 'author': 'Tom Hanks', 'publisher': 'Knopf', 'description': 'Seventeen short stories, each incorporating a typewriter, by the Academy Award-winning actor.', 'star_rating': 4.0, 'nb_Amazon_reviews': 382, 'weeks_on_list': 10, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-11-05', 'last_date_listed': '2018-01-07', 'worst_rank': 15, 'best_rank': 3, 'times_listed': 10, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43a9'), 'Amazon_url': 'https://www.amazon.com/Vicious-Circle-Joe-Pickett-Novel-ebook/dp/B01HYUVHIM?tag=NYTBS-20', 'title': 'VICIOUS CIRCLE', 'author': 'C J Box', 'publisher': 'Putnam', 'description': 'Newly released from prison, Dallas Cates tries to exact revenge on the Wyoming game warden Joe Pickett, who put him there.', 'star_rating': 4.6, 'nb_Amazon_reviews': 979, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-04-09', 'last_date_listed': '2017-04-23', 'worst_rank': 11, 'best_rank': 2, 'times_listed': 3, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43aa'), 'Amazon_url': 'https://www.amazon.com/When-Life-Gives-You-Lululemons-ebook/dp/B078MC8G1X?tag=NYTBS-20', 'title': 'WHEN LIFE GIVES YOU LULULEMONS', 'author': 'Lauren Weisberger', 'publisher': 'Simon & Schuster', 'description': 'Emily Charlton plans a comeback from the suburbs. From the author of "The Devil Wears Prada."', 'star_rating': 4.2, 'nb_Amazon_reviews': 518, 'weeks_on_list': 5, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2018-06-24', 'last_date_listed': '2018-07-22', 'worst_rank': 10, 'best_rank': 7, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43ab'), 'Amazon_url': 'https://www.amazon.com/Whistler-John-Grisham-ebook/dp/B01C1LUFFK?tag=NYTBS-20', 'title': 'THE WHISTLER', 'author': 'John Grisham', 'publisher': 'Doubleday', 'description': 'A whistleblower alerts a Florida investigator to judicial corruption involving the Mob and Indian casinos.', 'star_rating': 4.2, 'nb_Amazon_reviews': 7783, 'weeks_on_list': 22, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-11-13', 'last_date_listed': '2017-04-09', 'worst_rank': 14, 'best_rank': 1, 'times_listed': 22, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43ac'), 'Amazon_url': 'https://www.amazon.com/Whole-Towns-Talking-Novel/dp/140006595X?tag=NYTBS-20', 'title': "THE WHOLE TOWN'S TALKING", 'author': 'Fannie Flagg', 'publisher': 'Random House', 'description': 'A century of life in small-town Elmwood Springs, Mo.', 'star_rating': 3.9, 'nb_Amazon_reviews': 1240, 'weeks_on_list': 3, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'first_date_listed': '2016-12-18', 'last_date_listed': '2017-01-15', 'worst_rank': 19, 'best_rank': 10, 'times_listed': 5, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43ad'), 'Amazon_url': 'https://www.amazon.com/Wife-Between-Us-Novel/dp/1250130921?tag=NYTBS-20', 'title': 'THE WIFE BETWEEN US', 'author': 'Greer Hendricks and Sarah Pekkanen', 'publisher': "St. Martin's", 'description': 'The story of a love triangle is told from several points of view.', 'star_rating': 4.2, 'nb_Amazon_reviews': 2516, 'weeks_on_list': 10, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2018-01-28', 'last_date_listed': '2018-04-01', 'worst_rank': 15, 'best_rank': 2, 'times_listed': 10, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43ae'), 'Amazon_url': 'https://www.amazon.com/Winter-Solstice-Street-Elin-Hilderbrand-ebook/dp/B01N193KPV?tag=NYTBS-20', 'title': 'WINTER SOLSTICE', 'author': 'Elin Hilderbrand', 'publisher': 'Little, Brown', 'description': 'The Quinns celebrate the holidays when one family member returns from the war in Afghanistan but the gathering turns rocky.', 'star_rating': 4.6, 'nb_Amazon_reviews': 317, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-10-22', 'last_date_listed': '2017-10-22', 'worst_rank': 13, 'best_rank': 13, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43af'), 'Amazon_url': 'https://www.amazon.com/Wired-Buchanan-Fbi-Julie-Garwood/dp/0525954465?tag=NYTBS-20', 'title': 'WIRED', 'author': 'Julie Garwood', 'publisher': 'Berkley', 'description': 'An F.B.I. agent recruits an idealistic (and beautiful) hacker to help him find a leaker.', 'star_rating': 4.2, 'nb_Amazon_reviews': 791, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'first_date_listed': '2017-07-23', 'last_date_listed': '2017-07-23', 'worst_rank': 7, 'best_rank': 7, 'times_listed': 1, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43b0'), 'Amazon_url': 'https://www.amazon.com/Woman-Window-Novel-J-Finn/dp/0062678418?tag=NYTBS-20', 'title': 'THE WOMAN IN THE WINDOW', 'author': 'AJ Finn', 'publisher': 'Morrow', 'description': 'A recluse who drinks heavily and takes prescription drugs may have witnessed a crime across from her Harlem townhouse.', 'star_rating': 4.3, 'nb_Amazon_reviews': 5160, 'weeks_on_list': 23, 'NYT_Price': 0.0, 'Amazon_Price': 13.99, 'first_date_listed': '2018-01-21', 'last_date_listed': '2018-07-15', 'worst_rank': 14, 'best_rank': 1, 'times_listed': 23, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43b1'), 'Amazon_url': 'https://www.amazon.com/Women-Castle-Novel-Jessica-Shattuck/dp/0062563661?tag=NYTBS-20', 'title': 'THE WOMEN IN THE CASTLE', 'author': 'Jessica Shattuck', 'publisher': 'Morrow/HarperCollins', 'description': 'The widows of three men killed for attempting to assassinate Hitler take refuge together at the war’s end.', 'star_rating': 4.3, 'nb_Amazon_reviews': 983, 'weeks_on_list': 6, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'first_date_listed': '2017-04-16', 'last_date_listed': '2017-05-28', 'worst_rank': 14, 'best_rank': 6, 'times_listed': 6, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43b2'), 'Amazon_url': 'https://www.amazon.com/Wrong-Goodbye-Harry-Bosch-Novel-ebook/dp/B01BU1ITMI?tag=NYTBS-20', 'title': 'THE WRONG SIDE OF GOODBYE', 'author': 'Michael Connelly', 'publisher': 'Little, Brown', 'description': 'he detective Harry Bosch helps a small police department track a serial rapist, while as a P.I. he aids a billionaire in search of a possible heir.', 'star_rating': 4.7, 'nb_Amazon_reviews': 5977, 'weeks_on_list': 11, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2016-11-20', 'last_date_listed': '2017-02-05', 'worst_rank': 17, 'best_rank': 2, 'times_listed': 12, 'better_price': 'NYT'}
# {'_id': ObjectId('5c7fff2bbd7b6a0de2df43b3'), 'Amazon_url': 'https://www.amazon.com/Y-Yesterday-Kinsey-Millhone-Novel-ebook/dp/B01MUBJLNC?tag=NYTBS-20', 'title': 'Y IS FOR YESTERDAY', 'author': 'Sue Grafton', 'publisher': 'Marian Wood/Putnam', 'description': 'The 25th Kinsey Millhone mystery novel. A former student from an elite private school is released from prison and a sociopath returns to haunt the detective.', 'star_rating': 4.3, 'nb_Amazon_reviews': 3127, 'weeks_on_list': 6, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'first_date_listed': '2017-09-10', 'last_date_listed': '2017-10-15', 'worst_rank': 11, 'best_rank': 1, 'times_listed': 6, 'better_price': 'NYT'}

# %% [markdown]
# ### STEP 2: Render data using Flask
#
# In this step we build an app to render our data.

# %%
# Import and set-up Flask

from flask import Flask, jsonify
app = Flask(__name__)

# Define Flask routes

@app.route("/")
def welcome():
    return (
        f"Welcome to Best of the NYT BestSellers!<br/>"
        f"Available Routes:<br/>"
        f"/api/v1.0/justice-league"
    )


if __name__ == "__main__":
    app.run(debug=True)
