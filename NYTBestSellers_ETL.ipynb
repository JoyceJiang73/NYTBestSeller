# %% [markdown]
# # EXTRACT

# %% [markdown]
# ### STEP 1: Extract data from kaggle's file 'nyt2.json'
#
# Our first challenge started with the data file 'nyt2.json' we downloaded from kaggle. We expected a traditional json file (a list of dictionaries or a dictionary of dictionaries), but it is, instead, a compilation of json files, one per line. We wrote the code below to transform it into a true json file, which we named 'output.json'.

# %%
# Import dependencies needed

import json
import pandas as pd
from pprint import pprint

# %%
# Load 'nyt2.json' file into dataframe:

raw_nyt = pd.read_json('Resources/nyt2.json', lines=True, orient='columns')
raw_nyt.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b4aa4ead3089013507db18b'}
# 1  {'$oid': '5b4aa4ead3089013507db18c'}
# 2  {'$oid': '5b4aa4ead3089013507db18d'}
# 3  {'$oid': '5b4aa4ead3089013507db18e'}
# 4  {'$oid': '5b4aa4ead3089013507db18f'}
#
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 3  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
#
#                               bestsellers_date  \
# 0  {'$date': {'$numberLong': '1211587200000'}}
# 1  {'$date': {'$numberLong': '1211587200000'}}
# 2  {'$date': {'$numberLong': '1211587200000'}}
# 3  {'$date': {'$numberLong': '1211587200000'}}
# 4  {'$date': {'$numberLong': '1211587200000'}}
#
#                                          description  \
# 0  Odd Thomas, who can communicate with the dead,...
# 1  Aliens have taken control of the minds and bod...
# 2  A woman's happy marriage is shaken when she en...
# 3  A Massachusetts state investigator and his tea...
# 4  An aging porn queens aims to cap her career by...
#
#                         price                               published_date  \
# 0        {'$numberInt': '27'}  {'$date': {'$numberLong': '1212883200000'}}
# 1  {'$numberDouble': '25.99'}  {'$date': {'$numberLong': '1212883200000'}}
# 2  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 3  {'$numberDouble': '22.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 4  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
#
#        publisher                 rank       rank_last_week  \
# 0         Bantam  {'$numberInt': '1'}  {'$numberInt': '0'}
# 1  Little, Brown  {'$numberInt': '2'}  {'$numberInt': '1'}
# 2   St. Martin's  {'$numberInt': '3'}  {'$numberInt': '2'}
# 3         Putnam  {'$numberInt': '4'}  {'$numberInt': '0'}
# 4      Doubleday  {'$numberInt': '5'}  {'$numberInt': '0'}
#
#                       title        weeks_on_list
# 0                 ODD HOURS  {'$numberInt': '1'}
# 1                  THE HOST  {'$numberInt': '3'}
# 2  LOVE THE ONE YOU'RE WITH  {'$numberInt': '2'}
# 3                 THE FRONT  {'$numberInt': '1'}
# 4                     SNUFF  {'$numberInt': '1'}

# %%
# Save DataFrame 'raw_nyt' into a json file ('output.json') and load it as 'data' we can now work with:

raw_nyt.to_json(path_or_buf='output.json', orient = "records")
with open('output.json') as file:
    data = json.load(file)
#pprint(data)

# %%
# Set up lists to hold reponse info:

nyt_ids = []
urls = []
authors = []
bestsellers_dates = []
descriptions = []
prices = []
published_dates = []
publishers = []
ranks = []
ranks_last_week = []
titles = []
weeks_on_lists = []

# Populate the lists:

for item in data:
    nyt_ids.append(item['_id']['$oid'])
    urls.append(item['amazon_product_url'])
    authors.append(item['author'])
    bestsellers_dates.append(item['bestsellers_date']['$date']['$numberLong'])
    descriptions.append(item['description'])
    published_dates.append(item['published_date']['$date']['$numberLong'])
    publishers.append(item['publisher'])
    ranks.append(item['rank']['$numberInt'])
    ranks_last_week.append(item['rank_last_week']['$numberInt'])
    titles.append(item['title'])
    weeks_on_lists.append(item['weeks_on_list']['$numberInt'])
# Here we have to check for the correct keyname before we can extract the price string:
    price_key, = item['price'].keys()
    if price_key == '$numberInt' or price_key == '$numberDouble':
        prices.append(item['price'][price_key])# Populate the lists:

# %%
# Create a DataFrame from the lists

bestsellers_dict = {
    "nyt_id": nyt_ids,
    "title": titles,
    "author": authors,
    "url": urls,
    "publisher": publishers,
    "description": descriptions,
    "list_price": prices,
    "published_date": published_dates,
    "bestseller_date": bestsellers_dates,
    "rank": ranks,
    "rank_last_week": ranks_last_week,
    "weeks_on_list": weeks_on_lists
}
bestsellers_data = pd.DataFrame(bestsellers_dict)
bestsellers_data.head()
# Out:
#                      nyt_id                     title             author  \
# 0  5b4aa4ead3089013507db18b                 ODD HOURS      Dean R Koontz
# 1  5b4aa4ead3089013507db18c                  THE HOST    Stephenie Meyer
# 2  5b4aa4ead3089013507db18d  LOVE THE ONE YOU'RE WITH       Emily Giffin
# 3  5b4aa4ead3089013507db18e                 THE FRONT  Patricia Cornwell
# 4  5b4aa4ead3089013507db18f                     SNUFF    Chuck Palahniuk
#
#                                                  url      publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...         Bantam
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...  Little, Brown
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...   St. Martin's
# 3  http://www.amazon.com/The-Front-Garano-Patrici...         Putnam
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...      Doubleday
#
#                                          description list_price  \
# 0  Odd Thomas, who can communicate with the dead,...         27
# 1  Aliens have taken control of the minds and bod...      25.99
# 2  A woman's happy marriage is shaken when she en...      24.95
# 3  A Massachusetts state investigator and his tea...      22.95
# 4  An aging porn queens aims to cap her career by...      24.95
#
#   published_date bestseller_date rank rank_last_week weeks_on_list
# 0  1212883200000   1211587200000    1              0             1
# 1  1212883200000   1211587200000    2              1             3
# 2  1212883200000   1211587200000    3              2             2
# 3  1212883200000   1211587200000    4              0             1
# 4  1212883200000   1211587200000    5              0             1

# %%
bestsellers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 12 columns):
# nyt_id             10195 non-null object
# title              10195 non-null object
# author             10195 non-null object
# url                10195 non-null object
# publisher          10195 non-null object
# description        10195 non-null object
# list_price         10195 non-null object
# published_date     10195 non-null object
# bestseller_date    10195 non-null object
# rank               10195 non-null object
# rank_last_week     10195 non-null object
# weeks_on_list      10195 non-null object
# dtypes: object(12)
# memory usage: 955.9+ KB

# %% [markdown]
# ### STEP 2: Scrape info from amazon.com
#
# In this step, we identify the list of unique Amazon URLs from our bestsellers_data DataFrame, and we visit each of those URLs to scrape the Amazon price offer, number of customer reviews, and average 5-star rating.
# We encountered our second challenge here, as we had to iterate multiple times through our list of Amazon URLs and repetitively request the info we were seeking. Eventually we were able to scrape info for 1211 URLs out of the 2329 identified in our kaggle dataset.

# %%
# Import dependencies needed

from bs4 import BeautifulSoup
import requests
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
# Get list of unique amazon urls

amazon_urls = list(dict.fromkeys(urls))
len(amazon_urls)
# Out:
# 2329

# %% [raw]
# # Set-up lists to store scraped info and user-defined functions for the iterations
#
# reviews = []
# ratings = []
# offers = []
# img_urls = []
#
# def get_nb_reviews(x_url):
#     if x_url not in [url for (url, _) in reviews]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         review = soup.find_all('span', id="acrCustomerReviewText")[0].text
#         reviews.append((url, review))
#
# def get_rating(x_url):
#     if x_url not in [url for (url, _) in ratings]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         rating = soup.find('span', class_="a-icon-alt").text
#         ratings.append((url, rating))
#
# def get_offer(x_url):
#     if x_url not in [url for (url, _) in offers]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         offer = soup.find('span', class_="a-size-medium a-color-price offer-price a-text-normal").text
#         offers.append((url, offer))
#
# def get_img(x_url):
#     if x_url not in [url for (url, _) in img_urls]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         img_url = soup.find('div', id='img-canvas').find('img')['data-a-dynamic-image']
#         img_urls.append((url, img_url))

# %% [raw]
# # Extract info from amazon using requests
#
# missing_urls = []
# for url in amazon_urls:
#     try:
#         get_offer(url)
#         get_img(url)
#         get_nb_reviews(url)
#         get_rating(url)
#         print(url)
#     except (AttributeError, RuntimeError, TypeError, NameError, IndexError):
#         print("error")
#         missing_urls.append(url)

# %% [markdown]
# # TRANSFORM

# %% [markdown]
# ### STEP 1: Transform data from 'bestsellers_data' DataFrame
#
# All data extracted from the json file and read into our bestsellers_data DataFrame has a the type 'string'. We now need to transform some of into the correct data type. Specifically:
# - 'list_price' should have the float type
# - 'published_date' and 'bestseller_date' should be formatted as dates
# - 'rank', 'rank_last_week', and 'weeks_on_list' should have the integer type

# %%
# Import dependencies needed

import numpy as np
from datetime import datetime

# %%
# Load our file of scraped Amazon data ('join_data.csv') into dataframe

Amazon_data = pd.read_csv("Output/join_data.csv")
Amazon_data.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 1          20  http://www.amazon.com/The-Whole-Truth-David-Ba...
# 2          24  http://www.amazon.com/Story-Edgar-Sawtelle-Dav...
# 3         288  http://www.amazon.com/The-Quilters-Kitchen-Qui...
# 4         289  http://www.amazon.com/Testimony-A-Novel-Anita-...
#
#                   reviews              rating    price
# 0    237 customer reviews  3.5 out of 5 stars   $9.99
# 1  1,064 customer reviews  4.4 out of 5 stars   $9.99
# 2  2,573 customer reviews  3.8 out of 5 stars   $8.99
# 3    218 customer reviews  3.6 out of 5 stars  $10.99
# 4    408 customer reviews  3.9 out of 5 stars   $7.99

# %%
# Merge both dataframes

df = pd.merge(bestsellers_data, Amazon_data , on='url',how='inner')
df.head()
# Out:
#                      nyt_id      title         author  \
# 0  5b4aa4ead3089013507db18b  ODD HOURS  Dean R Koontz
# 1  5b4aa4ead3089013507db1a1  ODD HOURS  Dean R Koontz
# 2  5b4aa4ead3089013507db1b9  ODD HOURS  Dean R Koontz
# 3  5b4aa4ead3089013507db1ce  ODD HOURS  Dean R Koontz
# 4  5b4aa4ead3089013507db1e6  ODD HOURS  Dean R Koontz
#
#                                                  url publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 1  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 2  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 3  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 4  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
#
#                                          description list_price  \
# 0  Odd Thomas, who can communicate with the dead,...         27
# 1  Odd Thomas, who can communicate with the dead,...         27
# 2  Odd Thomas, who can communicate with the dead,...         27
# 3  Odd Thomas, who can communicate with the dead,...         27
# 4  Odd Thomas, who can communicate with the dead,...         27
#
#   published_date bestseller_date rank rank_last_week weeks_on_list  \
# 0  1212883200000   1211587200000    1              0             1
# 1  1213488000000   1212192000000    3              1             2
# 2  1214092800000   1212796800000    7              3             3
# 3  1214697600000   1213401600000    8              7             4
# 4  1215302400000   1214006400000   12              8             5
#
#    Unnamed: 0               reviews              rating   price
# 0        8319  920 customer reviews  4.4 out of 5 stars  $7.99
# 1        8319  920 customer reviews  4.4 out of 5 stars  $7.99
# 2        8319  920 customer reviews  4.4 out of 5 stars  $7.99
# 3        8319  920 customer reviews  4.4 out of 5 stars  $7.99
# 4        8319  920 customer reviews  4.4 out of 5 stars  $7.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7639 entries, 0 to 7638
# Data columns (total 16 columns):
# nyt_id             7639 non-null object
# title              7639 non-null object
# author             7639 non-null object
# url                7639 non-null object
# publisher          7639 non-null object
# description        7639 non-null object
# list_price         7639 non-null object
# published_date     7639 non-null object
# bestseller_date    7639 non-null object
# rank               7639 non-null object
# rank_last_week     7639 non-null object
# weeks_on_list      7639 non-null object
# Unnamed: 0         7639 non-null int64
# reviews            7639 non-null object
# rating             7639 non-null object
# price              7639 non-null object
# dtypes: int64(1), object(15)
# memory usage: 1014.6+ KB

# %%
# Drop column 'Unnamed: 0'

df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Convert 'list_price' and 'price' to float:

df['list_price'] = df['list_price'].apply(lambda x : float(x))
df['price']=df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Convert 'published_date' and 'bestseller_date' from unix time stamp to date format:

df['published_date'] = df['published_date'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))
df['bestseller_date'] = df['bestseller_date'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))

# %%
# Convert 'rank', rank_last_week', and 'weeks_on_list' to integer:

df['rank'] = df['rank'].apply(lambda x : int(x))
df['rank_last_week'] = df['rank_last_week'].apply(lambda x : int(x))
df['weeks_on_list'] = df['weeks_on_list'].apply(lambda x : int(x))

# %%
df['reviews'] = df['reviews'].str.replace(',', '')
df['reviews'] = df['reviews'].apply(lambda x : int(x.split()[0]))
df['rating'] = df['rating'].apply(lambda x : float(x.split()[0]))
df.head()
# Out:
#                      nyt_id      title         author  \
# 0  5b4aa4ead3089013507db18b  ODD HOURS  Dean R Koontz
# 1  5b4aa4ead3089013507db1a1  ODD HOURS  Dean R Koontz
# 2  5b4aa4ead3089013507db1b9  ODD HOURS  Dean R Koontz
# 3  5b4aa4ead3089013507db1ce  ODD HOURS  Dean R Koontz
# 4  5b4aa4ead3089013507db1e6  ODD HOURS  Dean R Koontz
#
#                                                  url publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 1  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 2  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 3  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
# 4  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...    Bantam
#
#                                          description  list_price  \
# 0  Odd Thomas, who can communicate with the dead,...        27.0
# 1  Odd Thomas, who can communicate with the dead,...        27.0
# 2  Odd Thomas, who can communicate with the dead,...        27.0
# 3  Odd Thomas, who can communicate with the dead,...        27.0
# 4  Odd Thomas, who can communicate with the dead,...        27.0
#
#   published_date bestseller_date  rank  rank_last_week  weeks_on_list  \
# 0     2008-06-08      2008-05-24     1               0              1
# 1     2008-06-15      2008-05-31     3               1              2
# 2     2008-06-22      2008-06-07     7               3              3
# 3     2008-06-29      2008-06-14     8               7              4
# 4     2008-07-06      2008-06-21    12               8              5
#
#    reviews  rating  price
# 0      920     4.4   7.99
# 1      920     4.4   7.99
# 2      920     4.4   7.99
# 3      920     4.4   7.99
# 4      920     4.4   7.99

# %%
# Rename some columns

df = df.rename(columns={"list_price":"NYT_Price", "price":"Amazon_Price", 'url':'Amazon_url', 'reviews': 'nb_Amazon_reviews', 'rating': 'star_rating'})

# %%
# Group data by bestseller

grouped = df.groupby('Amazon_url')
bestsellers_df = grouped['Amazon_url', 'title', 'author', 'publisher', 'description', 'star_rating', 'nb_Amazon_reviews', 'weeks_on_list', 'NYT_Price', 'Amazon_Price'].max()

# Calculate additional columns

bestsellers_df['first_date_listed'] = grouped[['published_date']].min()
bestsellers_df['last_date_listed'] = grouped[['published_date']].max()
bestsellers_df['worst_rank'] = grouped[['rank']].max()
bestsellers_df['best_rank'] = grouped[['rank']].min()
bestsellers_df['times_listed'] = grouped[['Amazon_url']].count()
bestsellers_df["better_price"] = bestsellers_df.apply(lambda row : 'Amazon' if row['NYT_Price'] > row['Amazon_Price'] else 'NYT', axis=1)
bestsellers_df.head()
# Out:
#                                                                                            Amazon_url  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  http://www.amazon.com/10th-Anniversary-Womens-...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  http://www.amazon.com/11th-Hour-Womens-Murder-...
# http://www.amazon.com/12th-Never-Womens-Murder-...  http://www.amazon.com/12th-Never-Womens-Murder...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  http://www.amazon.com/14th-Deadly-Womens-Murde...
#
#                                                                title  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  10TH ANNIVERSARY
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          11/22/63
# http://www.amazon.com/11th-Hour-Womens-Murder-C...         11TH HOUR
# http://www.amazon.com/12th-Never-Womens-Murder-...     12TH OF NEVER
# http://www.amazon.com/14th-Deadly-Womens-Murder...   14TH DEADLY SIN
#
#                                                                                author  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  James Patterson and Maxine Paetro
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                       Stephen King
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  James Patterson and Maxine Paetro
# http://www.amazon.com/12th-Never-Womens-Murder-...  James Patterson and Maxine Paetro
# http://www.amazon.com/14th-Deadly-Womens-Murder...  James Patterson and Maxine Paetro
#
#                                                         publisher  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Little, Brown
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       Scribner
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  Little, Brown
# http://www.amazon.com/12th-Never-Womens-Murder-...  Little, Brown
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Little, Brown
#
#                                                                                           description  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Detective Lindsay Boxer’s long-awaited wedding...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  An English teacher travels back to 1958 by way...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  When a millionaire is gunned down, Detective L...
# http://www.amazon.com/12th-Never-Womens-Murder-...  One week after the birth of her baby, Detectiv...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Detective Lindsay Boxer and her friends must r...
#
#                                                     star_rating  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          4.6
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          4.5
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          4.6
# http://www.amazon.com/12th-Never-Womens-Murder-...          4.5
# http://www.amazon.com/14th-Deadly-Womens-Murder...          4.3
#
#                                                     nb_Amazon_reviews  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...               1365
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...              26427
# http://www.amazon.com/11th-Hour-Womens-Murder-C...               1858
# http://www.amazon.com/12th-Never-Womens-Murder-...               3789
# http://www.amazon.com/14th-Deadly-Womens-Murder...               4140
#
#                                                     weeks_on_list  NYT_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...              8      27.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...             21      35.00
# http://www.amazon.com/11th-Hour-Womens-Murder-C...              8      27.99
# http://www.amazon.com/12th-Never-Womens-Murder-...              6       0.00
# http://www.amazon.com/14th-Deadly-Womens-Murder...              7       0.00
#
#                                                     Amazon_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          9.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...         10.99
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          9.99
# http://www.amazon.com/12th-Never-Womens-Murder-...          9.99
# http://www.amazon.com/14th-Deadly-Womens-Murder...          9.99
#
#                                                    first_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...        2011-05-22
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...        2011-11-27
# http://www.amazon.com/11th-Hour-Womens-Murder-C...        2012-05-27
# http://www.amazon.com/12th-Never-Womens-Murder-...        2013-05-19
# http://www.amazon.com/14th-Deadly-Womens-Murder...        2015-05-24
#
#                                                    last_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...       2011-07-24
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       2012-05-13
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       2012-07-29
# http://www.amazon.com/12th-Never-Womens-Murder-...       2013-06-30
# http://www.amazon.com/14th-Deadly-Womens-Murder...       2015-07-12
#
#                                                     worst_rank  best_rank  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          18          2
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          20          1
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          20          1
# http://www.amazon.com/12th-Never-Womens-Murder-...          19          1
# http://www.amazon.com/14th-Deadly-Womens-Murder...          20          1
#
#                                                     times_listed better_price
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...            10       Amazon
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...            23       Amazon
# http://www.amazon.com/11th-Hour-Womens-Murder-C...            10       Amazon
# http://www.amazon.com/12th-Never-Womens-Murder-...             7          NYT
# http://www.amazon.com/14th-Deadly-Womens-Murder...             8          NYT

# %% [markdown]
# # LOAD

# %%
# Import dependencies needed

import pymongo

# %%
# Initialize PyMongo to work with MongoDB

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection

db = client.nyt_bestsellers
collection = db.bestsellers

# %%
bestsellers_df.head()
# Out:
#                                                                                            Amazon_url  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  http://www.amazon.com/10th-Anniversary-Womens-...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  http://www.amazon.com/11th-Hour-Womens-Murder-...
# http://www.amazon.com/12th-Never-Womens-Murder-...  http://www.amazon.com/12th-Never-Womens-Murder...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  http://www.amazon.com/14th-Deadly-Womens-Murde...
#
#                                                                title  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  10TH ANNIVERSARY
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          11/22/63
# http://www.amazon.com/11th-Hour-Womens-Murder-C...         11TH HOUR
# http://www.amazon.com/12th-Never-Womens-Murder-...     12TH OF NEVER
# http://www.amazon.com/14th-Deadly-Womens-Murder...   14TH DEADLY SIN
#
#                                                                                author  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  James Patterson and Maxine Paetro
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                       Stephen King
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  James Patterson and Maxine Paetro
# http://www.amazon.com/12th-Never-Womens-Murder-...  James Patterson and Maxine Paetro
# http://www.amazon.com/14th-Deadly-Womens-Murder...  James Patterson and Maxine Paetro
#
#                                                         publisher  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Little, Brown
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       Scribner
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  Little, Brown
# http://www.amazon.com/12th-Never-Womens-Murder-...  Little, Brown
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Little, Brown
#
#                                                                                           description  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Detective Lindsay Boxer’s long-awaited wedding...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  An English teacher travels back to 1958 by way...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  When a millionaire is gunned down, Detective L...
# http://www.amazon.com/12th-Never-Womens-Murder-...  One week after the birth of her baby, Detectiv...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Detective Lindsay Boxer and her friends must r...
#
#                                                     star_rating  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          4.6
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          4.5
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          4.6
# http://www.amazon.com/12th-Never-Womens-Murder-...          4.5
# http://www.amazon.com/14th-Deadly-Womens-Murder...          4.3
#
#                                                     nb_Amazon_reviews  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...               1365
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...              26427
# http://www.amazon.com/11th-Hour-Womens-Murder-C...               1858
# http://www.amazon.com/12th-Never-Womens-Murder-...               3789
# http://www.amazon.com/14th-Deadly-Womens-Murder...               4140
#
#                                                     weeks_on_list  NYT_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...              8      27.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...             21      35.00
# http://www.amazon.com/11th-Hour-Womens-Murder-C...              8      27.99
# http://www.amazon.com/12th-Never-Womens-Murder-...              6       0.00
# http://www.amazon.com/14th-Deadly-Womens-Murder...              7       0.00
#
#                                                     Amazon_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          9.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...         10.99
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          9.99
# http://www.amazon.com/12th-Never-Womens-Murder-...          9.99
# http://www.amazon.com/14th-Deadly-Womens-Murder...          9.99
#
#                                                    first_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...        2011-05-22
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...        2011-11-27
# http://www.amazon.com/11th-Hour-Womens-Murder-C...        2012-05-27
# http://www.amazon.com/12th-Never-Womens-Murder-...        2013-05-19
# http://www.amazon.com/14th-Deadly-Womens-Murder...        2015-05-24
#
#                                                    last_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...       2011-07-24
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       2012-05-13
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       2012-07-29
# http://www.amazon.com/12th-Never-Womens-Murder-...       2013-06-30
# http://www.amazon.com/14th-Deadly-Womens-Murder...       2015-07-12
#
#                                                     worst_rank  best_rank  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          18          2
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          20          1
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          20          1
# http://www.amazon.com/12th-Never-Womens-Murder-...          19          1
# http://www.amazon.com/14th-Deadly-Womens-Murder...          20          1
#
#                                                     times_listed better_price
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...            10       Amazon
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...            23       Amazon
# http://www.amazon.com/11th-Hour-Womens-Murder-C...            10       Amazon
# http://www.amazon.com/12th-Never-Womens-Murder-...             7          NYT
# http://www.amazon.com/14th-Deadly-Womens-Murder...             8          NYT

# %%
data = bestsellers_df.to_dict(orient='records')
len(data)
# Out:
# 1211

# %%
data
# Out:
# [{'Amazon_url': 'http://www.amazon.com/10th-Anniversary-Womens-Murder-Club/dp/1455511463?tag=NYTBS-20',
#   'title': '10TH ANNIVERSARY',
#   'author': 'James Patterson and Maxine Paetro',
#   'publisher': 'Little, Brown',
#   'description': 'Detective Lindsay Boxer’s long-awaited wedding celebration becomes a distant memory when the Women’s Murder Club is called in to find a missing baby.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 1365,
#   'weeks_on_list': 8,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-05-22',
#   'last_date_listed': '2011-07-24',
#   'worst_rank': 18,
#   'best_rank': 2,
#   'times_listed': 10,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/11-22-63-A-Novel/dp/1451627297?tag=NYTBS-20',
#   'title': '11/22/63',
#   'author': 'Stephen King',
#   'publisher': 'Scribner',
#   'description': 'An English teacher travels back to 1958 by way of a time portal in a Maine diner. His assignment: Stop Lee Harvey Oswald.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 26427,
#   'weeks_on_list': 21,
#   'NYT_Price': 35.0,
#   'Amazon_Price': 10.99,
#   'first_date_listed': '2011-11-27',
#   'last_date_listed': '2012-05-13',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 23,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/11th-Hour-Womens-Murder-Club/dp/0446571830?tag=NYTBS-20',
#   'title': '11TH HOUR',
#   'author': 'James Patterson and Maxine Paetro',
#   'publisher': 'Little, Brown',
#   'description': "When a millionaire is gunned down, Detective Lindsay Boxer and the Women's Murder Club discover that the murder weapon is linked to the deaths of four of San Francisco's most untouchable criminals.",
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 1858,
#   'weeks_on_list': 8,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2012-05-27',
#   'last_date_listed': '2012-07-29',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 10,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/12th-Never-Womens-Murder-Club/dp/1455515795?tag=NYTBS-20',
#   'title': '12TH OF NEVER',
#   'author': 'James Patterson and Maxine Paetro',
#   'publisher': 'Little, Brown',
#   'description': 'One week after the birth of her baby, Detective Lindsay Boxer must return to work to investigate a string of grisly murders; a Women’s Murder Club novel.\xa0',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 3789,
#   'weeks_on_list': 6,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2013-05-19',
#   'last_date_listed': '2013-06-30',
#   'worst_rank': 19,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/14th-Deadly-Womens-Murder-Club/dp/031640702X?tag=NYTBS-20',
#   'title': '14TH DEADLY SIN',
#   'author': 'James Patterson and Maxine Paetro',
#   'publisher': 'Little, Brown',
#   'description': 'Detective Lindsay Boxer and her friends must risk their lives to save the city and one another when a rash of murders grips San Francisco.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 4140,
#   'weeks_on_list': 7,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-05-24',
#   'last_date_listed': '2015-07-12',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 8,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/15th-Affair-Womens-Murder-Club/dp/0316407070?tag=NYTBS-20',
#   'title': '15TH AFFAIR',
#   'author': 'James Patterson and Maxine Paetro',
#   'publisher': 'Little, Brown',
#   'description': "When a brutal murder threatens the domestic happiness of the San Francisco police detective Lindsay Boxer, she turns for help to the Women's Murder Club.",
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 2913,
#   'weeks_on_list': 7,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2016-05-22',
#   'last_date_listed': '2016-07-10',
#   'worst_rank': 18,
#   'best_rank': 1,
#   'times_listed': 8,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/1Q84-Haruki-Murakami-ebook/dp/B004LROUW2?tag=NYTBS-20',
#   'title': '1Q84',
#   'author': 'Haruki Murakami',
#   'publisher': 'Knopf',
#   'description': 'In 1980s Tokyo, a woman who punishes perpetrators of domestic violence has ties to an aspiring novelist with an unusual project.',
#   'star_rating': 4.0,
#   'nb_Amazon_reviews': 1892,
#   'weeks_on_list': 9,
#   'NYT_Price': 30.5,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2011-11-13',
#   'last_date_listed': '2012-01-15',
#   'worst_rank': 18,
#   'best_rank': 2,
#   'times_listed': 10,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/2030-Real-Story-Happens-America-ebook/dp/B004OA62WC?tag=NYTBS-20',
#   'title': '2030',
#   'author': 'Albert Brooks',
#   'publisher': "St. Martin's",
#   'description': 'In 2030, the young resent the elderly for draining the weakening economy, and a devastating earthquake in Los Angeles tests the administration of the country’s first Jewish president.',
#   'star_rating': 3.7,
#   'nb_Amazon_reviews': 493,
#   'weeks_on_list': 3,
#   'NYT_Price': 25.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-05-29',
#   'last_date_listed': '2011-06-19',
#   'worst_rank': 19,
#   'best_rank': 14,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/44-Charles-Street-A-Novel/dp/0440245176?tag=NYTBS-20',
#   'title': '44 CHARLES STREET',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte',
#   'description': 'The owner of a Greenwich Village town house takes in boarders and bonds with her tenants.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 433,
#   'weeks_on_list': 5,
#   'NYT_Price': 28.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2011-04-24',
#   'last_date_listed': '2011-05-22',
#   'worst_rank': 13,
#   'best_rank': 4,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/61-Hours-Jack-Reacher-Novel/dp/0440243696?tag=NYTBS-20',
#   'title': '61 HOURS',
#   'author': 'Lee Child',
#   'publisher': 'Delacorte',
#   'description': 'Jack Reacher helps the police in a small South Dakota town protect a witness in a drug trial.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 2403,
#   'weeks_on_list': 6,
#   'NYT_Price': 28.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2010-06-06',
#   'last_date_listed': '2010-07-25',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Change-Altitude-Novel/dp/0316020710?tag=NYTBS-20',
#   'title': 'A CHANGE IN ALTITUDE',
#   'author': 'Anita Shreve',
#   'publisher': 'Little, Brown',
#   'description': 'A young woman’s life is transformed by a mountain-climbing accident in Kenya.',
#   'star_rating': 3.4,
#   'nb_Amazon_reviews': 238,
#   'weeks_on_list': 1,
#   'NYT_Price': 26.99,
#   'Amazon_Price': 5.99,
#   'first_date_listed': '2009-10-11',
#   'last_date_listed': '2009-10-18',
#   'worst_rank': 17,
#   'best_rank': 11,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Crown-Imperiled-Chaoswar-Saga/dp/006146841X?tag=NYTBS-20',
#   'title': 'A CROWN IMPERILED',
#   'author': 'Raymond E Feist',
#   'publisher': 'Harper Voyager',
#   'description': '',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 824,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 4.99,
#   'first_date_listed': '2012-04-01',
#   'last_date_listed': '2012-04-01',
#   'worst_rank': 20,
#   'best_rank': 20,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Darker-Place-Jack-Higgins/dp/0399155503?tag=NYTBS-20',
#   'title': 'A DARKER PLACE',
#   'author': 'Jack Higgins',
#   'publisher': 'Putnam',
#   'description': 'A Russian defector becomes a counterspy.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 91,
#   'weeks_on_list': 3,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-02-15',
#   'last_date_listed': '2009-03-01',
#   'worst_rank': 14,
#   'best_rank': 10,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Devil-Waiting-Jack-Higgins/dp/0425250571?tag=NYTBS-20',
#   'title': 'A DEVIL IS WAITING',
#   'author': 'Jack Higgins',
#   'publisher': 'Putnam',
#   'description': 'Sean Dillon helps to foil a plot to assassinate the president in London.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 178,
#   'weeks_on_list': 1,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2012-01-22',
#   'last_date_listed': '2012-01-22',
#   'worst_rank': 15,
#   'best_rank': 15,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-God-Ruins-Novel-ebook/dp/B00NERQQXG?tag=NYTBS-20',
#   'title': 'A GOD IN RUINS',
#   'author': 'Kate Atkinson',
#   'publisher': 'Little, Brown',
#   'description': 'Postwar Britain as seen through the members of a well-to-do family.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 940,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2015-05-24',
#   'last_date_listed': '2015-06-07',
#   'worst_rank': 16,
#   'best_rank': 6,
#   'times_listed': 3,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Good-Woman-Novel/dp/0440243300?tag=NYTBS-20',
#   'title': 'A GOOD WOMAN',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte',
#   'description': 'An American society girl who made a new life as a doctor in World War I France returns to New York.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 381,
#   'weeks_on_list': 2,
#   'NYT_Price': 27.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2008-11-16',
#   'last_date_listed': '2009-01-11',
#   'worst_rank': 20,
#   'best_rank': 5,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Heartbeat-Away-Michael-Palmer-ebook/dp/B00457X86M?tag=NYTBS-20',
#   'title': 'A HEARTBEAT AWAY',
#   'author': 'Michael Palmer',
#   'publisher': 'St. Martin’s',
#   'description': 'A terrorist group unleashes a deadly virus in the Capitol on the night of the State of the Union address.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 183,
#   'weeks_on_list': 2,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2011-03-06',
#   'last_date_listed': '2011-03-13',
#   'worst_rank': 15,
#   'best_rank': 10,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Little-Life-Hanya-Yanagihara/dp/0804172706?tag=NYTBS-20',
#   'title': 'A LITTLE LIFE',
#   'author': 'Hanya Yanagihara',
#   'publisher': 'Doubleday',
#   'description': 'Four college friends, one with a traumatic past, move to New York seeking fame and fortune.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 3436,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2016-01-17',
#   'last_date_listed': '2016-01-24',
#   'worst_rank': 19,
#   'best_rank': 19,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Memory-Light-Wheel-Time-ebook/dp/B00BMKDTNC?tag=NYTBS-20',
#   'title': 'A MEMORY OF LIGHT',
#   'author': 'Robert Jordan and Brandon Sanderson',
#   'publisher': 'Tor/Tom Doherty',
#   'description': 'The 14th and final novel in the Wheel of Time fantasy series.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 4293,
#   'weeks_on_list': 12,
#   'NYT_Price': 34.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2013-01-27',
#   'last_date_listed': '2013-05-05',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 13,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Mercy-Toni-Morrison/dp/0307276767?tag=NYTBS-20',
#   'title': 'A MERCY',
#   'author': 'Toni Morrison',
#   'publisher': 'Knopf',
#   'description': 'In 17th-\xadcentury America, a slave mother urges a Northern farmer to buy her daughter so that she can have a better life; from the Nobel Prize-winning author of “Beloved.”',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 294,
#   'weeks_on_list': 11,
#   'NYT_Price': 23.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2008-11-30',
#   'last_date_listed': '2009-02-08',
#   'worst_rank': 15,
#   'best_rank': 5,
#   'times_listed': 11,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Perfect-Life-Novel-ebook/dp/B00HXYKYDE?tag=NYTBS-20',
#   'title': 'A PERFECT LIFE',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte',
#   'description': "A television anchor's on-air poise belies her unsettled life.",
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 1648,
#   'weeks_on_list': 4,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2014-08-10',
#   'last_date_listed': '2014-09-07',
#   'worst_rank': 18,
#   'best_rank': 4,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Reliable-Wife-Robert-Goolrick/dp/1565125967?tag=NYTBS-20',
#   'title': 'A RELIABLE WIFE',
#   'author': 'Robert Goolrick',
#   'publisher': 'Algonquin',
#   'description': 'Complications ensue when a wealthy Wisconsin widower in 1907 advertises for a spouse.',
#   'star_rating': 3.3,
#   'nb_Amazon_reviews': 1399,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.58,
#   'first_date_listed': '2009-05-10',
#   'last_date_listed': '2009-05-10',
#   'worst_rank': 17,
#   'best_rank': 17,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Summer-Affair-Novel/dp/B003P2VBNU?tag=NYTBS-20',
#   'title': 'A SUMMER AFFAIR',
#   'author': 'Elin Hilderbrand',
#   'publisher': 'Little Brown & Company',
#   'description': 'A successful married artist is attracted to a billionaire on Nantucket.',
#   'star_rating': 3.7,
#   'nb_Amazon_reviews': 241,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2008-07-20',
#   'last_date_listed': '2008-07-27',
#   'worst_rank': 19,
#   'best_rank': 18,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/A-Week-Winter-Maeve-Binchy/dp/0307273571?tag=NYTBS-20',
#   'title': 'A WEEK IN WINTER',
#   'author': 'Maeve Binchy',
#   'publisher': 'Knopf',
#   'description': 'Guests at an inn by the sea on Ireland’s west coast; the final book by Binchy, who died in 2012.\xa0',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 3451,
#   'weeks_on_list': 9,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2013-03-03',
#   'last_date_listed': '2013-05-05',
#   'worst_rank': 17,
#   'best_rank': 1,
#   'times_listed': 10,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/A-Winter-Dream-Novel/dp/145162803X?tag=NYTBS-20',
#   'title': 'A WINTER DREAM',
#   'author': 'Richard Paul Evans',
#   'publisher': 'Simon & Schuster',
#   'description': 'When Joseph Jacobson stands to take over his father’s business, his 12 brothers cast him out.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 418,
#   'weeks_on_list': 3,
#   'NYT_Price': 19.99,
#   'Amazon_Price': 10.99,
#   'first_date_listed': '2012-11-18',
#   'last_date_listed': '2012-12-02',
#   'worst_rank': 16,
#   'best_rank': 6,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Abraham-Lincoln-Vampire-Seth-Grahame-Smith/dp/0446563072?tag=NYTBS-20',
#   'title': 'ABRAHAM LINCOLN: VAMPIRE HUNTER',
#   'author': 'Seth Grahame-Smith',
#   'publisher': 'Grand Central',
#   'description': 'Lincoln vs. the undead.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 1627,
#   'weeks_on_list': 7,
#   'NYT_Price': 21.99,
#   'Amazon_Price': 6.92,
#   'first_date_listed': '2010-03-21',
#   'last_date_listed': '2010-05-09',
#   'worst_rank': 19,
#   'best_rank': 4,
#   'times_listed': 8,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Acheron-Dark-Hunter-Book-Sherrilyn-Kenyon/dp/0312949413?tag=NYTBS-20',
#   'title': 'ACHERON',
#   'author': 'Sherrilyn Kenyon',
#   'publisher': 'St. Martin’s',
#   'description': 'Book 12 of the Dark-Hunter paranormal series.',
#   'star_rating': 4.7,
#   'nb_Amazon_reviews': 1163,
#   'weeks_on_list': 4,
#   'NYT_Price': 24.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2008-08-24',
#   'last_date_listed': '2008-09-21',
#   'worst_rank': 17,
#   'best_rank': 1,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Act-War-Thriller-Brad-Thor/dp/1476717125?tag=NYTBS-20',
#   'title': 'ACT OF WAR',
#   'author': 'Brad Thor',
#   'publisher': 'Emily Bestler/Atria',
#   'description': 'The counterterrorism operative Scot Harvath undertakes two dangerous missions as America faces an imminent attack.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 3328,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2014-07-27',
#   'last_date_listed': '2014-08-24',
#   'worst_rank': 13,
#   'best_rank': 1,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Adultery-A-novel-Paulo-Coelho/dp/1101874082?tag=NYTBS-20',
#   'title': 'ADULTERY',
#   'author': 'Paulo Coelho',
#   'publisher': 'Knopf',
#   'description': '\xa0A married journalist, depressed by boredom, risks everything when she embarks on an affair with a former boyfriend; by the Brazilian writer, the author of “The Alchemist.”\xa0',
#   'star_rating': 3.4,
#   'nb_Amazon_reviews': 806,
#   'weeks_on_list': 4,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2014-09-07',
#   'last_date_listed': '2014-10-19',
#   'worst_rank': 19,
#   'best_rank': 2,
#   'times_listed': 6,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Affair-bonus-short-story-Second-ebook/dp/B004P8JPS6?tag=NYTBS-20',
#   'title': 'THE AFFAIR',
#   'author': 'Lee Child',
#   'publisher': 'Delacorte',
#   'description': 'It’s 1997 and the military cop Jack Reacher goes undercover in Mississippi to ferret out a possible scandal involving a soldier with powerful friends in Washington.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 2694,
#   'weeks_on_list': 7,
#   'NYT_Price': 28.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-10-16',
#   'last_date_listed': '2011-12-11',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 8,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Affliction-Anita-Blake-Vampire-Hunter/dp/0425255700?tag=NYTBS-20',
#   'title': 'AFFLICTION',
#   'author': 'Laurell K Hamilton',
#   'publisher': 'Berkley',
#   'description': 'The vampire hunter Anita Blake encounters a dangerous new breed of zombies.\xa0',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 1372,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2013-07-21',
#   'last_date_listed': '2013-07-28',
#   'worst_rank': 15,
#   'best_rank': 5,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/After-You-Novel-Jojo-Moyes/dp/0525426590?tag=NYTBS-20',
#   'title': 'AFTER YOU',
#   'author': 'Jojo Moyes',
#   'publisher': 'Pamela Dorman/Viking',
#   'description': 'In a sequel to “Me Before You,” Louisa Clark tries to put her life back together after the death of Will Traynor.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 5201,
#   'weeks_on_list': 21,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2015-10-18',
#   'last_date_listed': '2016-07-31',
#   'worst_rank': 19,
#   'best_rank': 3,
#   'times_listed': 28,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Against-All-Enemies-Tom-Clancy/dp/042524606X?tag=NYTBS-20',
#   'title': 'AGAINST ALL ENEMIES',
#   'author': 'Tom Clancy with Peter Telep',
#   'publisher': 'Putnam',
#   'description': 'Maxwell Moore, a former C.I.A. officer, pursues the terrorists who killed his colleagues in a bomb attack off the coast of Pakistan.',
#   'star_rating': 3.4,
#   'nb_Amazon_reviews': 620,
#   'weeks_on_list': 7,
#   'NYT_Price': 28.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-07-03',
#   'last_date_listed': '2011-08-28',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 9,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Agenda-21-Glenn-Beck-ebook/dp/B00902UC0W?tag=NYTBS-20',
#   'title': 'AGENDA 21',
#   'author': 'Glenn Beck with Harriet Parke',
#   'publisher': 'Threshold Editions/Mercury Radio Arts',
#   'description': 'A girl questions authority in the U.N.-created totalitarian successor to the United States.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 2880,
#   'weeks_on_list': 5,
#   'NYT_Price': 26.0,
#   'Amazon_Price': 9.49,
#   'first_date_listed': '2012-12-09',
#   'last_date_listed': '2013-01-13',
#   'worst_rank': 17,
#   'best_rank': 3,
#   'times_listed': 6,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Agincourt-Bernard-Cornwell/dp/0061578916?tag=NYTBS-20',
#   'title': 'AGINCOURT',
#   'author': 'Bernard Cornwell',
#   'publisher': 'Harper',
#   'description': 'An English archer with a complicated past joins Henry V at the famous battle against the French in 1415.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 609,
#   'weeks_on_list': 4,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2009-02-08',
#   'last_date_listed': '2009-03-08',
#   'worst_rank': 20,
#   'best_rank': 4,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Aleph-Paulo-Coelho/dp/0307700186?tag=NYTBS-20',
#   'title': 'ALEPH',
#   'author': 'Paulo Coelho',
#   'publisher': 'Knopf',
#   'description': 'A crisis of faith is the impetus for a journey through time and space, on a path that teaches love, forgiveness and courage.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 451,
#   'weeks_on_list': 2,
#   'NYT_Price': 24.95,
#   'Amazon_Price': 2.99,
#   'first_date_listed': '2011-10-16',
#   'last_date_listed': '2011-10-23',
#   'worst_rank': 7,
#   'best_rank': 6,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Alex-Cross-Run-James-Patterson-ebook/dp/B0076DCP16?tag=NYTBS-20',
#   'title': 'ALEX CROSS, RUN',
#   'author': 'James Patterson',
#   'publisher': 'Little, Brown',
#   'description': "While Detective Alex Cross pursues a serial killer (or killers?) in Washington, D.C., he's too busy to notice that someone has been watching him.",
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 2939,
#   'weeks_on_list': 8,
#   'NYT_Price': 28.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2013-03-10',
#   'last_date_listed': '2013-05-05',
#   'worst_rank': 18,
#   'best_rank': 1,
#   'times_listed': 9,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Alex-Crosss-Trial-James-Patterson/dp/0446557781?tag=NYTBS-20',
#   'title': 'ALEX CROSS’S ‘TRIAL’',
#   'author': 'James Patterson and Richard DiLallo',
#   'publisher': 'Little, Brown',
#   'description': 'The detective Alex Cross writes a novel about his great-uncle, who fought the Klan.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 1754,
#   'weeks_on_list': 6,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-09-13',
#   'last_date_listed': '2009-10-25',
#   'worst_rank': 16,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/All-Dressed-White-Under-Suspicion-ebook/dp/B00UDCI30E?tag=NYTBS-20',
#   'title': 'ALL DRESSED IN WHITE',
#   'author': 'Mary Higgins Clark and Alafair Burke',
#   'publisher': 'Simon & Schuster',
#   'description': 'A TV producer investigates a bride’s disappearance for her show, “Under Suspicion.”',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 1200,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2015-12-06',
#   'last_date_listed': '2015-12-27',
#   'worst_rank': 19,
#   'best_rank': 7,
#   'times_listed': 4,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/All-Fall-Down-A-Novel-ebook/dp/B00DPM909W?tag=NYTBS-20',
#   'title': 'ALL FALL DOWN',
#   'author': 'Jennifer Weiner',
#   'publisher': 'Atria',
#   'description': 'A woman becomes addicted to pain medication.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 1401,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2014-07-06',
#   'last_date_listed': '2014-08-03',
#   'worst_rank': 15,
#   'best_rank': 5,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/All-Light-We-Cannot-See/dp/1476746583?tag=NYTBS-20',
#   'title': 'ALL THE LIGHT WE CANNOT SEE',
#   'author': 'Anthony Doerr',
#   'publisher': 'Scribner',
#   'description': 'The lives of a blind French girl and a gadget-obsessed German boy before and during World War II; the winner of the 2015 Pulitzer Prize. \xa0',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 28454,
#   'weeks_on_list': 134,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2014-05-25',
#   'last_date_listed': '2017-01-29',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 141,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/All-Single-Ladies-A-Novel-ebook/dp/B00NEOM5FM?tag=NYTBS-20',
#   'title': 'ALL THE SINGLE LADIES',
#   'author': 'Dorothea Benton Frank',
#   'publisher': 'Morrow/HarperCollins',
#   'description': 'Three friends in South Carolina’s Lowcountry grapple with the challenges of being unmarried.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 946,
#   'weeks_on_list': 3,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2015-06-28',
#   'last_date_listed': '2015-07-19',
#   'worst_rank': 19,
#   'best_rank': 6,
#   'times_listed': 4,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Almost-Forgot-About-You-Novel/dp/1101902574?tag=NYTBS-20',
#   'title': 'I ALMOST FORGOT ABOUT YOU',
#   'author': 'Terry McMillan',
#   'publisher': 'Crown',
#   'description': 'A middle-aged optometrist, twice divorced and tired of her work, decides to reinvent her life.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 1083,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2016-06-26',
#   'last_date_listed': '2016-07-24',
#   'worst_rank': 20,
#   'best_rank': 12,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/America-A-Novel-Ethan-Canin/dp/0679456805?tag=NYTBS-20',
#   'title': 'AMERICA AMERICA',
#   'author': 'Ethan Canin',
#   'publisher': 'Random House',
#   'description': 'A boy becomes entangled with a powerful family in upstate New York in the early 1970s.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 97,
#   'weeks_on_list': 2,
#   'NYT_Price': 27.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2008-07-13',
#   'last_date_listed': '2008-07-27',
#   'worst_rank': 19,
#   'best_rank': 15,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/American-Assassin-Thriller-Mitch-Rapp-ebook/dp/B003UV8T9A?tag=NYTBS-20',
#   'title': 'AMERICAN ASSASSIN',
#   'author': 'Vince Flynn',
#   'publisher': 'Atria',
#   'description': 'In the wake of the Lockerbie bombing, Mitch Rapp takes on his first antiterrorist assignment.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 5574,
#   'weeks_on_list': 8,
#   'NYT_Price': 27.99,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2010-10-31',
#   'last_date_listed': '2011-01-09',
#   'worst_rank': 17,
#   'best_rank': 1,
#   'times_listed': 11,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/American-Wife-Random-Readers-Circle/dp/0812975405?tag=NYTBS-20',
#   'title': 'AMERICAN WIFE',
#   'author': 'Curtis Sittenfeld',
#   'publisher': 'Random House',
#   'description': 'A pretty librarian marries the alcoholic son of a wealthy political family who somehow becomes president.',
#   'star_rating': 3.5,
#   'nb_Amazon_reviews': 514,
#   'weeks_on_list': 5,
#   'NYT_Price': 26.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2008-09-21',
#   'last_date_listed': '2008-10-26',
#   'worst_rank': 19,
#   'best_rank': 3,
#   'times_listed': 6,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Among-Mad-Maisie-Dobbs-Book/dp/0312429258?tag=NYTBS-20',
#   'title': 'AMONG THE MAD',
#   'author': 'Jacqueline Winspear',
#   'publisher': 'Holt',
#   'description': 'Maisie Dobbs is involved in a hunt for a man who promises to wreak destruction on London.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 312,
#   'weeks_on_list': 1,
#   'NYT_Price': 25.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-03-08',
#   'last_date_listed': '2009-03-08',
#   'worst_rank': 9,
#   'best_rank': 9,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/An-Officer-Spy-A-novel/dp/0385349580?tag=NYTBS-20',
#   'title': 'AN OFFICER AND A SPY',
#   'author': 'Robert Harris',
#   'publisher': 'Knopf',
#   'description': 'A fictionalized account of the Dreyfus Affair focuses on Lt. Col. Georges Picquart, who discovered evidence exonerating Dreyfus and bravely defended him.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 1491,
#   'weeks_on_list': 3,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2014-02-16',
#   'last_date_listed': '2014-03-02',
#   'worst_rank': 14,
#   'best_rank': 8,
#   'times_listed': 3,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Anathem-Neal-Stephenson/dp/B003B3NW7G?tag=NYTBS-20',
#   'title': 'ANATHEM',
#   'author': 'Neal Stephenson',
#   'publisher': 'William Morrow',
#   'description': 'An order of cloistered mathematicians and scientists must save their Earth-like planet when catastrophe threatens.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 916,
#   'weeks_on_list': 4,
#   'NYT_Price': 29.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2008-09-28',
#   'last_date_listed': '2008-10-19',
#   'worst_rank': 15,
#   'best_rank': 1,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/And-Mountains-Echoed-Khaled-Hosseini/dp/1594632383?tag=NYTBS-20',
#   'title': 'AND THE MOUNTAINS ECHOED',
#   'author': 'Khaled Hosseini',
#   'publisher': 'Riverhead',
#   'description': 'A multigenerational family saga, by the author of “The Kite Runner,” centering on a brother and sister from a remote, impoverished village in Afghanistan.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 8097,
#   'weeks_on_list': 24,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2013-06-09',
#   'last_date_listed': '2014-01-19',
#   'worst_rank': 20,
#   'best_rank': 2,
#   'times_listed': 28,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Angels-Game-Carlos-Ruiz-Zafon/dp/0767931114?tag=NYTBS-20',
#   'title': "THE ANGEL'S GAME",
#   'author': 'Carlos Ruiz Zafón',
#   'publisher': 'Doubleday',
#   'description': 'A Barcelona writer accepts a sinister commission.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 588,
#   'weeks_on_list': 5,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2009-07-05',
#   'last_date_listed': '2009-08-16',
#   'worst_rank': 18,
#   'best_rank': 3,
#   'times_listed': 6,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Angels-Table-Shirley-Goodness-Christmas-ebook/dp/B007WKE4TE?tag=NYTBS-20',
#   'title': 'ANGELS AT THE TABLE',
#   'author': 'Debbie Macomber',
#   'publisher': 'Ballantine',
#   'description': 'Angels cook up a plan to reunite a young couple.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 640,
#   'weeks_on_list': 3,
#   'NYT_Price': 18.0,
#   'Amazon_Price': 5.99,
#   'first_date_listed': '2012-11-11',
#   'last_date_listed': '2012-11-25',
#   'worst_rank': 13,
#   'best_rank': 9,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Another-Brooklyn-Novel-Jacqueline-Woodson/dp/0062359983?tag=NYTBS-20',
#   'title': 'ANOTHER BROOKLYN',
#   'author': 'Jacqueline Woodson',
#   'publisher': 'Amistad/HarperCollins',
#   'description': "An adult novel by an award-winning children's book author centers on memories of growing up and the close friendship of four girls.",
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 324,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2016-08-28',
#   'last_date_listed': '2016-09-04',
#   'worst_rank': 20,
#   'best_rank': 16,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Apprentice-Death-J-D-Robb/dp/1101987979?tag=NYTBS-20',
#   'title': 'APPRENTICE IN DEATH',
#   'author': 'J D Robb',
#   'publisher': 'Berkley',
#   'description': 'Lt. Eve Dallas of the N.Y.P.D. is on the case when three skaters are shot by a sniper. By Nora Roberts, writing pseudonymously.',
#   'star_rating': 4.8,
#   'nb_Amazon_reviews': 2457,
#   'weeks_on_list': 4,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2016-09-25',
#   'last_date_listed': '2016-10-23',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Arctic-Drift-Dirk-Novel-Adventure/dp/0399155295?tag=NYTBS-20',
#   'title': 'ARCTIC DRIFT',
#   'author': 'Clive Cussler and Dirk Cussler',
#   'publisher': 'Putnam',
#   'description': 'In his 20th adventure, Dirk Pitt searches for a crucial element that will help reverse global warming.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 341,
#   'weeks_on_list': 6,
#   'NYT_Price': 27.95,
#   'Amazon_Price': 4.99,
#   'first_date_listed': '2008-12-14',
#   'last_date_listed': '2009-02-01',
#   'worst_rank': 19,
#   'best_rank': 3,
#   'times_listed': 8,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/As-Crow-Flies-Longmire-Mysteries/dp/0670023515?tag=NYTBS-20',
#   'title': 'AS THE CROW FLIES',
#   'author': 'Craig Johnson',
#   'publisher': 'Viking',
#   'description': '',
#   'star_rating': 4.7,
#   'nb_Amazon_reviews': 608,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2012-06-03',
#   'last_date_listed': '2012-06-03',
#   'worst_rank': 17,
#   'best_rank': 17,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Ascension-Star-Wars-Fate-Legends-ebook/dp/B004J4WM7M?tag=NYTBS-20',
#   'title': 'ASCENSION',
#   'author': 'Christie Golden',
#   'publisher': 'LucasBooks',
#   'description': 'The Jedi face the Sith, a deposed dictator and an evil entity hungry to become a god; a “Star Wars: Fate of the Jedi” book.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 203,
#   'weeks_on_list': 2,
#   'NYT_Price': 27.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2011-08-28',
#   'last_date_listed': '2011-09-04',
#   'worst_rank': 16,
#   'best_rank': 7,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Ashley-Bell-Novel-Dean-Koontz-ebook/dp/B00VCZOKM6?tag=NYTBS-20',
#   'title': 'ASHLEY BELL',
#   'author': 'Dean Koontz',
#   'publisher': 'Bantam',
#   'description': 'A young Southern California writer who survived a fatal diagnosis sets out to find a woman she has been told she must save, overcoming many obstacles in the process.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 1919,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-12-27',
#   'last_date_listed': '2016-01-31',
#   'worst_rank': 17,
#   'best_rank': 12,
#   'times_listed': 6,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Assassination-Option-Clandestine-Operations-Novel/dp/039917124X?tag=NYTBS-20',
#   'title': 'THE ASSASSINATION OPTION',
#   'author': 'W E B Griffin and William E Butterworth IV',
#   'publisher': 'Putnam',
#   'description': 'The second novel in a new series about the Cold War and the early C.I.A.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 689,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-01-18',
#   'last_date_listed': '2015-01-18',
#   'worst_rank': 7,
#   'best_rank': 7,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Assegai-Wilbur-Smith/dp/0312570406?tag=NYTBS-20',
#   'title': 'ASSEGAI',
#   'author': 'Wilbur Smith',
#   'publisher': 'Thomas Dunne/St. Martin’s',
#   'description': 'A professional hunting  guide in British East Africa on the brink of World War I spies on a German client and his mysterious mistress.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 231,
#   'weeks_on_list': 3,
#   'NYT_Price': 27.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-05-31',
#   'last_date_listed': '2009-06-14',
#   'worst_rank': 15,
#   'best_rank': 9,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/At-Edge-Orchard-Tracy-Chevalier/dp/0525953000?tag=NYTBS-20',
#   'title': 'AT THE EDGE OF THE ORCHARD',
#   'author': 'Tracy Chevalier',
#   'publisher': 'Viking',
#   'description': 'Two generations of 19th-century American pioneer life unfold in Chevalier’s eighth novel.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 375,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 4.99,
#   'first_date_listed': '2016-04-03',
#   'last_date_listed': '2016-04-10',
#   'worst_rank': 19,
#   'best_rank': 14,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/At-Waters-Edge-A-Novel/dp/0385523238?tag=NYTBS-20',
#   'title': "AT THE WATER'S EDGE",
#   'author': 'Sara Gruen',
#   'publisher': 'Spiegel & Grau',
#   'description': 'In the course of a search for the Loch Ness monster, a Philadelphia socialite uncovers secrets about her husband.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 2690,
#   'weeks_on_list': 7,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2015-04-19',
#   'last_date_listed': '2015-06-21',
#   'worst_rank': 18,
#   'best_rank': 6,
#   'times_listed': 10,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Avenue-Mysteries-John-Irving/dp/1451664168?tag=NYTBS-20',
#   'title': 'AVENUE OF MYSTERIES',
#   'author': 'John Irving',
#   'publisher': 'Simon & Schuster',
#   'description': 'In Irving’s 14th novel, a Mexican writer on a journey to the Philippines recalls his escape from a humble childhood.',
#   'star_rating': 3.4,
#   'nb_Amazon_reviews': 597,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2015-11-22',
#   'last_date_listed': '2016-01-03',
#   'worst_rank': 20,
#   'best_rank': 5,
#   'times_listed': 3,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Bad-Blood-Virgil-Flowers-novel/dp/0399156909?tag=NYTBS-20',
#   'title': 'BAD BLOOD',
#   'author': 'John Sandford',
#   'publisher': 'Putnam',
#   'description': 'Virgil Flowers is summoned to investigate a monstrous multigenerational conspiracy.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 751,
#   'weeks_on_list': 4,
#   'NYT_Price': 27.95,
#   'Amazon_Price': 4.99,
#   'first_date_listed': '2010-10-10',
#   'last_date_listed': '2010-10-31',
#   'worst_rank': 13,
#   'best_rank': 4,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Bark-Stories-Lorrie-Moore/dp/0307594130?tag=NYTBS-20',
#   'title': 'BARK',
#   'author': 'Lorrie Moore',
#   'publisher': 'Knopf',
#   'description': 'Moore’s first story collection in 16 years.',
#   'star_rating': 3.6,
#   'nb_Amazon_reviews': 157,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 12.99,
#   'first_date_listed': '2014-03-16',
#   'last_date_listed': '2014-03-16',
#   'worst_rank': 13,
#   'best_rank': 13,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Basketball-Jones-E-Lynn-Harris/dp/0767926277?tag=NYTBS-20',
#   'title': 'BASKETBALL JONES',
#   'author': 'E Lynn Harris',
#   'publisher': 'Doubleday',
#   'description': 'An N.B.A. star hides his male lover.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 158,
#   'weeks_on_list': 2,
#   'NYT_Price': 22.95,
#   'Amazon_Price': 10.99,
#   'first_date_listed': '2009-02-15',
#   'last_date_listed': '2009-03-01',
#   'worst_rank': 19,
#   'best_rank': 11,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Beach-Town-Mary-Kay-Andrews/dp/1250065933?tag=NYTBS-20',
#   'title': 'BEACH TOWN',
#   'author': 'Mary Kay Andrews',
#   'publisher': "St. Martin's",
#   'description': 'Complications arise when a Hollywood location scout tries to arrange a shoot in a Florida Gulf Coast town.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 782,
#   'weeks_on_list': 3,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-06-07',
#   'last_date_listed': '2015-06-28',
#   'worst_rank': 17,
#   'best_rank': 6,
#   'times_listed': 4,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Beat-Reaper-Novel-Josh-Bazell/dp/0316032212?tag=NYTBS-20',
#   'title': 'BEAT THE REAPER',
#   'author': 'Josh Bazell',
#   'publisher': 'Little, Brown',
#   'description': 'A former hit man for the mob who has become a doctor is threatened when a gangster patient recognizes him.',
#   'star_rating': 4.0,
#   'nb_Amazon_reviews': 389,
#   'weeks_on_list': 2,
#   'NYT_Price': 24.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-02-01',
#   'last_date_listed': '2009-02-08',
#   'worst_rank': 14,
#   'best_rank': 13,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Beautiful-Day-Novel-Elin-Hilderbrand-ebook/dp/B00A2DKQ72?tag=NYTBS-20',
#   'title': 'BEAUTIFUL DAY',
#   'author': 'Elin Hilderbrand',
#   'publisher': 'Reagan Arthur/Little, Brown',
#   'description': 'Various sorts of disaster threaten a Nantucket wedding.\xa0',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 804,
#   'weeks_on_list': 3,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2013-07-14',
#   'last_date_listed': '2013-08-11',
#   'worst_rank': 19,
#   'best_rank': 7,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Beautiful-Ruins-Novel-Jess-Walter/dp/0061928178?tag=NYTBS-20',
#   'title': 'BEAUTIFUL RUINS',
#   'author': 'Jess Walter',
#   'publisher': 'Harper/HarperCollins',
#   'description': 'Ruins both emotional and architectural, in Italy, Hollywood and elsewhere, figure in this sweeping novel.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 2901,
#   'weeks_on_list': 4,
#   'NYT_Price': 25.99,
#   'Amazon_Price': 11.49,
#   'first_date_listed': '2012-07-15',
#   'last_date_listed': '2012-08-19',
#   'worst_rank': 19,
#   'best_rank': 11,
#   'times_listed': 6,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Beautiful-You-Novel-Chuck-Palahniuk/dp/0385538030?tag=NYTBS-20',
#   'title': 'BEAUTIFUL YOU',
#   'author': 'Chuck Palahniuk',
#   'publisher': 'Doubleday',
#   'description': 'A Manhattan lawyer inadvertently becomes a test subject for a line of sex toys.',
#   'star_rating': 3.0,
#   'nb_Amazon_reviews': 351,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 10.99,
#   'first_date_listed': '2014-11-09',
#   'last_date_listed': '2014-11-16',
#   'worst_rank': 16,
#   'best_rank': 5,
#   'times_listed': 2,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Before-Fall-Noah-Hawley-ebook/dp/B0151YQUTE?tag=NYTBS-20',
#   'title': 'BEFORE THE FALL',
#   'author': 'Noah Hawley',
#   'publisher': 'Grand Central',
#   'description': 'After a private jet crashes, a firestorm of media madness ensues.',
#   'star_rating': 4.0,
#   'nb_Amazon_reviews': 4075,
#   'weeks_on_list': 14,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2016-06-19',
#   'last_date_listed': '2016-09-18',
#   'worst_rank': 15,
#   'best_rank': 2,
#   'times_listed': 14,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Before-Go-Sleep-S-Watson/dp/0062060562?tag=NYTBS-20',
#   'title': 'BEFORE I GO TO SLEEP',
#   'author': 'S J Watson',
#   'publisher': 'Harper/HarperCollins',
#   'description': 'After a mysterious accident, an amnesiac cannot remember her past or form new memories.',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 3756,
#   'weeks_on_list': 2,
#   'NYT_Price': 25.99,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2011-07-03',
#   'last_date_listed': '2011-08-14',
#   'worst_rank': 20,
#   'best_rank': 7,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Behind-Closed-Doors-intriguing-psychological/dp/1250121000?tag=NYTBS-20',
#   'title': 'BEHIND CLOSED DOORS',
#   'author': 'B A Paris',
#   'publisher': 'St. Martin’s',
#   'description': 'What cracks exist in an "it couple\'s" relationship?',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 5050,
#   'weeks_on_list': 3,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2016-08-28',
#   'last_date_listed': '2016-09-25',
#   'worst_rank': 19,
#   'best_rank': 15,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Being-Elizabeth-Barbara-Taylor-Bradford/dp/0312354630?tag=NYTBS-20',
#   'title': 'BEING ELIZABETH',
#   'author': 'Barbara Taylor Bradford',
#   'publisher': 'St. Martin’s',
#   'description': 'A 25-year-old newly in control of her family’s corporate empire faces tough choices in business and in love.',
#   'star_rating': 3.6,
#   'nb_Amazon_reviews': 93,
#   'weeks_on_list': 1,
#   'NYT_Price': 27.95,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2008-09-07',
#   'last_date_listed': '2008-09-14',
#   'worst_rank': 18,
#   'best_rank': 12,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Bel-Air-Dead-Stone-Barrington-Novel-ebook/dp/B004LRPDP0?tag=NYTBS-20',
#   'title': 'BEL-AIR DEAD',
#   'author': 'Stuart Woods',
#   'publisher': 'Putnam',
#   'description': 'The New York lawyer Stone Barrington makes enemies when he represents a widow in the sale of a world-famous movie studio.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 211,
#   'weeks_on_list': 3,
#   'NYT_Price': 25.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-05-15',
#   'last_date_listed': '2011-06-05',
#   'worst_rank': 17,
#   'best_rank': 3,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Best-Friends-Forever-Jennifer-Weiner/dp/0743294297?tag=NYTBS-20',
#   'title': 'BEST FRIENDS FOREVER',
#   'author': 'Jennifer Weiner',
#   'publisher': 'Atria',
#   'description': 'Childhood friends, estranged in high school, reunite years later when the popular one needs the mousy one’s help.',
#   'star_rating': 3.4,
#   'nb_Amazon_reviews': 334,
#   'weeks_on_list': 7,
#   'NYT_Price': 26.99,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2009-08-02',
#   'last_date_listed': '2009-09-13',
#   'worst_rank': 15,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Best-Kept-Secret-Clifton-Chronicles/dp/1250040779?tag=NYTBS-20',
#   'title': 'BEST KEPT SECRET',
#   'author': 'Jeffrey Archer',
#   'publisher': "St. Martin's",
#   'description': 'In Volume 3 of the Clifton Chronicles, the focus shifts to a new generation — Sebastian, the son of Harry and Emma Clifton.\xa0',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 2431,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2013-05-19',
#   'last_date_listed': '2013-06-16',
#   'worst_rank': 15,
#   'best_rank': 4,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Betrayal-A-Novel-Danielle-Steel-ebook/dp/B005BUG6TI?tag=NYTBS-20',
#   'title': 'BETRAYAL',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte Press',
#   'description': 'A happy and successful Hollywood director discovers that someone is embezzling large sums of her money.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 632,
#   'weeks_on_list': 5,
#   'NYT_Price': 28.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2012-04-15',
#   'last_date_listed': '2012-05-27',
#   'worst_rank': 19,
#   'best_rank': 3,
#   'times_listed': 6,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Big-Girl-Novel-Danielle-Steel/dp/0440245214?tag=NYTBS-20',
#   'title': 'BIG GIRL',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte',
#   'description': 'A young woman with a weight problem worries about her sister’s engagement to a man very much like their narcissistic father.',
#   'star_rating': 3.5,
#   'nb_Amazon_reviews': 365,
#   'weeks_on_list': 4,
#   'NYT_Price': 28.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2010-03-14',
#   'last_date_listed': '2010-04-11',
#   'worst_rank': 17,
#   'best_rank': 5,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Big-Little-Lies-Liane-Moriarty-ebook/dp/B00HDMMISA?tag=NYTBS-20',
#   'title': 'BIG LITTLE LIES',
#   'author': 'Liane Moriarty',
#   'publisher': 'Amy Einhorn/Putnam',
#   'description': 'Who will end up dead, and how, when three mothers with children in the same school become friends?',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 16090,
#   'weeks_on_list': 15,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2014-08-17',
#   'last_date_listed': '2015-03-15',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 20,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Black-Hills-Nora-Roberts/dp/0399155872?tag=NYTBS-20',
#   'title': 'BLACK HILLS',
# ...
#   'worst_rank': 14,
#   'best_rank': 1,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/To-Try-Mens-Souls-Washington/dp/0312591063?tag=NYTBS-20',
#   'title': "TO TRY MEN'S SOULS",
#   'author': 'Newt Gingrich, William R Forstchen and Albert S Hanser',
#   'publisher': 'Thomas Dunne/St. Martin’s',
#   'description': 'The darkest days of the American Revolution.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 265,
#   'weeks_on_list': 1,
#   'NYT_Price': 26.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-11-08',
#   'last_date_listed': '2009-11-15',
#   'worst_rank': 16,
#   'best_rank': 13,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Today-Will-Different-Maria-Semple-ebook/dp/B01A5VQUKM?tag=NYTBS-20',
#   'title': 'TODAY WILL BE DIFFERENT',
#   'author': 'Maria Semple',
#   'publisher': 'Little, Brown',
#   'description': 'A calamitous day in the life of a cynical Seattle transplant from the author of “Where’d You Go, Bernadette.”',
#   'star_rating': 3.1,
#   'nb_Amazon_reviews': 730,
#   'weeks_on_list': 4,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2016-10-23',
#   'last_date_listed': '2016-11-20',
#   'worst_rank': 18,
#   'best_rank': 6,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Top-Secret-Twenty-One-Stephanie-Novel-ebook/dp/B00H1294XO?tag=NYTBS-20',
#   'title': 'TOP SECRET TWENTY-ONE',
#   'author': 'Janet Evanovich',
#   'publisher': 'Bantam',
#   'description': 'The New Jersey bounty hunter Stephanie Plum pursues a dealer who sells more than used cars.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 5354,
#   'weeks_on_list': 7,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2014-07-06',
#   'last_date_listed': '2014-08-17',
#   'worst_rank': 14,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Touch-Go-Lisa-Gardner/dp/0451465849?tag=NYTBS-20',
#   'title': 'TOUCH AND GO',
#   'author': 'Lisa Gardner',
#   'publisher': 'Dutton',
#   'description': 'An investigator probing the disappearance of a seemingly perfect Boston family must dig beneath the surface.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 1321,
#   'weeks_on_list': 4,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2013-02-24',
#   'last_date_listed': '2013-03-24',
#   'worst_rank': 20,
#   'best_rank': 4,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Towers-Midnight-Wheel-Time-Thirteen/dp/0765325942?tag=NYTBS-20',
#   'title': 'TOWERS OF MIDNIGHT',
#   'author': 'Robert Jordan and Brandon Sanderson',
#   'publisher': 'Tor',
#   'description': 'The sun has begun to set upon the Third Age, and Perrin Aybara is hunted by specters from his past: Whitecloaks, a slayer of wolves, and the responsibilities of leadership; Book 13 of the Wheel of Time fantasy series.',
#   'star_rating': 4.7,
#   'nb_Amazon_reviews': 1334,
#   'weeks_on_list': 7,
#   'NYT_Price': 29.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2010-11-21',
#   'last_date_listed': '2011-03-06',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 14,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Trail-Spellmans-Document-Lisa-Lutz/dp/1451608128?tag=NYTBS-20',
#   'title': 'TRAIL OF THE SPELLMANS: DOCUMENT #5',
#   'author': 'Lisa Lutz',
#   'publisher': 'Simon & Schuster',
#   'description': 'Further adventures, many comic, of the quirky family of detectives.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 150,
#   'weeks_on_list': 1,
#   'NYT_Price': 25.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2012-03-18',
#   'last_date_listed': '2012-03-18',
#   'worst_rank': 15,
#   'best_rank': 15,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/TransAtlantic-A-Novel-Colum-McCann/dp/1400069599?tag=NYTBS-20',
#   'title': 'TRANSATLANTIC',
#   'author': 'Colum McCann',
#   'publisher': 'Random House',
#   'description': 'The lives of real and fictional characters (Frederick Douglass, George Mitchell, an Irish maid) are woven into historical events in Dublin, Newfoundland and New York.\xa0',
#   'star_rating': 4.1,
#   'nb_Amazon_reviews': 726,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 10.99,
#   'first_date_listed': '2013-06-23',
#   'last_date_listed': '2013-07-14',
#   'worst_rank': 18,
#   'best_rank': 13,
#   'times_listed': 4,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Treason-Lisson-Grove-Charlotte-Thomas-ebook/dp/B004GTLS5M?tag=NYTBS-20',
#   'title': 'TREASON AT LISSON GROVE',
#   'author': 'Anne Perry',
#   'publisher': 'Ballantine',
#   'description': '',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 142,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2011-04-24',
#   'last_date_listed': '2011-04-24',
#   'worst_rank': 20,
#   'best_rank': 20,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Tribute-Nora-Roberts/dp/0515146366?tag=NYTBS-20',
#   'title': 'TRIBUTE',
#   'author': 'Nora Roberts',
#   'publisher': 'Putnam',
#   'description': 'A former child star returns to Virginia to rehabilitate the farm owned by her grandmother, an actress who died mysteriously.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 395,
#   'weeks_on_list': 6,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2008-07-27',
#   'last_date_listed': '2008-09-07',
#   'worst_rank': 19,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Trick-Light-Inspector-Gamache-Novels/dp/0312655452?tag=NYTBS-20',
#   'title': 'A TRICK OF THE LIGHT',
#   'author': 'Louise Penny',
#   'publisher': 'Minotaur',
#   'description': 'Called to a case, Chief Inspector Armand Gamache of homicide encounters a world where nothing is as it seems.',
#   'star_rating': 4.7,
#   'nb_Amazon_reviews': 1199,
#   'weeks_on_list': 2,
#   'NYT_Price': 25.99,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2011-09-18',
#   'last_date_listed': '2011-10-02',
#   'worst_rank': 20,
#   'best_rank': 4,
#   'times_listed': 3,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Tricky-Twenty-Two-Stephanie-Plum-Novel-ebook/dp/B00TND3N7C?tag=NYTBS-20',
#   'title': 'TRICKY TWENTY-TWO',
#   'author': 'Janet Evanovich',
#   'publisher': 'Bantam',
#   'description': 'The New Jersey bounty hunter Stephanie Plum pursues a fraternity member arrested for beating up a college dean and investigates a murder. \n\t2',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 4984,
#   'weeks_on_list': 7,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2015-12-06',
#   'last_date_listed': '2016-01-17',
#   'worst_rank': 12,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Trigger-Mortis-Original-Material-Fleming/dp/0062395106?tag=NYTBS-20',
#   'title': 'TRIGGER MORTIS',
#   'author': 'Anthony Horowitz',
#   'publisher': 'Harper',
#   'description': '',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 292,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-09-27',
#   'last_date_listed': '2015-09-27',
#   'worst_rank': 20,
#   'best_rank': 20,
#   'times_listed': 1,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Trigger-Warning-Short-Fictions-Disturbances/dp/0062330268?tag=NYTBS-20',
#   'title': 'TRIGGER WARNING',
#   'author': 'Neil Gaiman',
#   'publisher': 'Morrow/HarperCollins',
#   'description': 'Stories and poems about the power of imagination.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 544,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 10.49,
#   'first_date_listed': '2015-02-22',
#   'last_date_listed': '2015-03-29',
#   'worst_rank': 18,
#   'best_rank': 4,
#   'times_listed': 6,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Truth-Die-James-Patterson-ebook/dp/B00QQQL8VM?tag=NYTBS-20',
#   'title': 'TRUTH OR DIE',
#   'author': 'James Patterson and Howard Roughan',
#   'publisher': 'Little, Brown',
#   'description': 'An attorney discovers a shocking secret.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 946,
#   'weeks_on_list': 5,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2015-07-12',
#   'last_date_listed': '2015-08-16',
#   'worst_rank': 17,
#   'best_rank': 3,
#   'times_listed': 6,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Tsar-A-Thriller-Alex-Hawke/dp/1416550402?tag=NYTBS-20',
#   'title': 'TSAR',
#   'author': 'Ted Bell',
#   'publisher': 'Simon & Schuster',
#   'description': 'The Kremlin has a brutal killer working for it in America.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 234,
#   'weeks_on_list': 3,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 9.49,
#   'first_date_listed': '2008-10-12',
#   'last_date_listed': '2008-11-02',
#   'worst_rank': 18,
#   'best_rank': 5,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Turn-Coat-Dresden-Files-Book/dp/0451462564?tag=NYTBS-20',
#   'title': 'TURN COAT',
#   'author': 'Jim Butcher',
#   'publisher': 'Roc',
#   'description': 'Book 11 of the Dresden Files series about a wizard detective in Chicago.',
#   'star_rating': 4.8,
#   'nb_Amazon_reviews': 532,
#   'weeks_on_list': 3,
#   'NYT_Price': 25.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-04-26',
#   'last_date_listed': '2009-05-24',
#   'worst_rank': 20,
#   'best_rank': 1,
#   'times_listed': 5,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Twelve-Days-Christmas-Novel-ebook/dp/B01AERZQLQ?tag=NYTBS-20',
#   'title': 'TWELVE DAYS OF CHRISTMAS',
#   'author': 'Debbie Macomber',
#   'publisher': 'Ballantine',
#   'description': 'A woman starts a blog about her attempt to reach out to a grumpy neighbor at Christmastime, and finds herself falling for him.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 580,
#   'weeks_on_list': 1,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 5.99,
#   'first_date_listed': '2016-10-23',
#   'last_date_listed': '2016-11-27',
#   'worst_rank': 16,
#   'best_rank': 7,
#   'times_listed': 3,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Twelve-Digital-Edition-Vintage-Contemporaries-ebook/dp/B00A9ET5XU?tag=NYTBS-20',
#   'title': 'THE TWELVE TRIBES OF HATTIE',
#   'author': 'Ayana Mathis',
#   'publisher': 'Knopf',
#   'description': 'Fifty-some years in the life of an African-American family, starting with Hattie Shepherd, who leaves Georgia for Philadelphia in 1923.',
#   'star_rating': 3.9,
#   'nb_Amazon_reviews': 1551,
#   'weeks_on_list': 10,
#   'NYT_Price': 24.95,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2012-12-23',
#   'last_date_listed': '2013-03-10',
#   'worst_rank': 20,
#   'best_rank': 6,
#   'times_listed': 12,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Twenties-Girl-Novel-Sophie-Kinsella-ebook/dp/B002HFJ77S?tag=NYTBS-20',
#   'title': 'TWENTIES GIRL',
#   'author': 'Sophie Kinsella',
#   'publisher': 'Dial',
#   'description': 'A young woman is haunted by the spirit of her great-aunt, who wants her to find a missing necklace.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 708,
#   'weeks_on_list': 3,
#   'NYT_Price': 26.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2009-08-09',
#   'last_date_listed': '2009-08-30',
#   'worst_rank': 18,
#   'best_rank': 4,
#   'times_listed': 4,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Twenty-Wishes-Blossom-Street-Books/dp/0778326314?tag=NYTBS-20',
#   'title': 'TWENTY WISHES',
#   'author': 'Debbie Macomber',
#   'publisher': 'Mira',
#   'description': 'A widow who owns a bookstore on Blossom Street compiles a list of things she always wanted to do.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 455,
#   'weeks_on_list': 4,
#   'NYT_Price': 24.95,
#   'Amazon_Price': 5.99,
#   'first_date_listed': '2008-06-08',
#   'last_date_listed': '2008-06-08',
#   'worst_rank': 14,
#   'best_rank': 14,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Twilights-Dawn-Black-Jewels-Trilogy/dp/0451463781?tag=NYTBS-20',
#   'title': 'TWILIGHT’S DAWN',
#   'author': 'Anne Bishop',
#   'publisher': 'Roc',
#   'description': 'The author of the Black Jewels novels returns to the Blood realm with four novellas.',
#   'star_rating': 4.3,
#   'nb_Amazon_reviews': 194,
#   'weeks_on_list': 1,
#   'NYT_Price': 25.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2011-03-20',
#   'last_date_listed': '2011-03-20',
#   'worst_rank': 14,
#   'best_rank': 14,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Two-Nicholas-Sparks-ebook/dp/B01ER6Z7RI?tag=NYTBS-20',
#   'title': 'TWO BY TWO',
#   'author': 'Nicholas Sparks',
#   'publisher': 'Grand Central',
#   'description': 'A man who became a single father when his marriage and business collapsed learns to take a chance on a new love.',
#   'star_rating': 4.2,
#   'nb_Amazon_reviews': 4656,
#   'weeks_on_list': 21,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2016-10-23',
#   'last_date_listed': '2017-03-12',
#   'worst_rank': 13,
#   'best_rank': 1,
#   'times_listed': 21,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/U-Undertow-Kinsey-Millhone-Mystery/dp/039915597X?tag=NYTBS-20',
#   'title': 'U IS FOR UNDERTOW',
#   'author': 'Sue Grafton',
#   'publisher': 'Putnam',
#   'description': 'Kinsey Millhone investigates the case of a 4-year-old girl who disappeared 21 years earlier.',
#   'star_rating': 4.5,
#   'nb_Amazon_reviews': 924,
#   'weeks_on_list': 7,
#   'NYT_Price': 27.95,
#   'Amazon_Price': 9.99,
#   'first_date_listed': '2009-12-20',
#   'last_date_listed': '2010-01-31',
#   'worst_rank': 12,
#   'best_rank': 1,
#   'times_listed': 7,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Unaccustomed-Earth-Jhumpa-Lahiri/dp/0307265730?tag=NYTBS-20',
#   'title': 'BRIGHT SHINY MORNING',
#   'author': 'James Frey',
#   'publisher': 'Harper',
#   'description': 'A novel, set in Los Angeles, by the author of "A Million Little Pieces."',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 521,
#   'weeks_on_list': 2,
#   'NYT_Price': 26.95,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2008-06-08',
#   'last_date_listed': '2008-06-15',
#   'worst_rank': 18,
#   'best_rank': 12,
#   'times_listed': 2,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Unaccustomed-Vintage-Contemporaries-Jhumpa-Lahiri/dp/0307278255?tag=NYTBS-20',
#   'title': 'UNACCUSTOMED EARTH',
#   'author': 'Jhumpa Lahiri',
#   'publisher': 'Knopf',
#   'description': 'Stories of the anxiety and transformation experienced by Bengalis in America.',
#   'star_rating': 4.4,
#   'nb_Amazon_reviews': 521,
#   'weeks_on_list': 0,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 11.99,
#   'first_date_listed': '2008-06-08',
#   'last_date_listed': '2009-01-04',
#   'worst_rank': 20,
#   'best_rank': 17,
#   'times_listed': 3,
#   'better_price': 'NYT'},
#  {'Amazon_url': 'http://www.amazon.com/Undead-Unfinished-Queen-Betsy-Book/dp/0425234355?tag=NYTBS-20',
#   'title': 'UNDEAD AND UNFINISHED',
#   'author': 'MaryJanice Davidson',
#   'publisher': 'Berkley Sensation',
#   'description': 'Betsy Taylor, a suburban vampire queen, makes a deal with the Devil that involves traveling to hell with her kid sister.',
#   'star_rating': 2.8,
#   'nb_Amazon_reviews': 288,
#   'weeks_on_list': 1,
#   'NYT_Price': 24.95,
#   'Amazon_Price': 8.99,
#   'first_date_listed': '2010-07-25',
#   'last_date_listed': '2010-07-25',
#   'worst_rank': 15,
#   'best_rank': 15,
#   'times_listed': 1,
#   'better_price': 'Amazon'},
#  {'Amazon_url': 'http://www.amazon.com/Undercover-A-Novel-Danielle-Steel/dp/0345531043?tag=NYTBS-20',
#   'title': 'UNDERCOVER',
#   'author': 'Danielle Steel',
#   'publisher': 'Delacorte',
#   'description': 'A woman recovering from an act of violence in Buenos Aires crosses paths with a D.E.A. agent in Paris, and both are in danger.',
#   'star_rating': 4.6,
#   'nb_Amazon_reviews': 1153,
#   'weeks_on_list': 2,
#   'NYT_Price': 0.0,
#   'Amazon_Price': 7.99,
#   'first_date_listed': '2015-09-20',
#   'last_date_listed': '2015-10-18',
#   'worst_rank': 20,
#   'best_rank': 8,
#   'times_listed': 5,
#   'better_price': 'NYT'},
#  ...]

# %%
collection.insert_many(data)
