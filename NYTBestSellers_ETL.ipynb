# %% [markdown]
# # EXTRACT

# %% [markdown]
# ### STEP 1: Extract data from kaggle's file 'nyt2.json'
#
# Our first challenge started with the data file 'nyt2.json' we downloaded from kaggle. We expected a traditional json file (a list of dictionaries or a dictionary of dictionaries), but it is, instead, a compilation of json files, one per line. We wrote the code below to transform it into a true json file, which we named 'output.json'.

# %%
# Import dependencies needed

import json
import pandas as pd
from pprint import pprint

# %%
# Load 'nyt2.json' file into dataframe:

raw_nyt = pd.read_json('Resources/nyt2.json', lines=True, orient='columns')
raw_nyt.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b4aa4ead3089013507db18b'}
# 1  {'$oid': '5b4aa4ead3089013507db18c'}
# 2  {'$oid': '5b4aa4ead3089013507db18d'}
# 3  {'$oid': '5b4aa4ead3089013507db18e'}
# 4  {'$oid': '5b4aa4ead3089013507db18f'}
#
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 3  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
#
#                               bestsellers_date  \
# 0  {'$date': {'$numberLong': '1211587200000'}}
# 1  {'$date': {'$numberLong': '1211587200000'}}
# 2  {'$date': {'$numberLong': '1211587200000'}}
# 3  {'$date': {'$numberLong': '1211587200000'}}
# 4  {'$date': {'$numberLong': '1211587200000'}}
#
#                                          description  \
# 0  Odd Thomas, who can communicate with the dead,...
# 1  Aliens have taken control of the minds and bod...
# 2  A woman's happy marriage is shaken when she en...
# 3  A Massachusetts state investigator and his tea...
# 4  An aging porn queens aims to cap her career by...
#
#                         price                               published_date  \
# 0        {'$numberInt': '27'}  {'$date': {'$numberLong': '1212883200000'}}
# 1  {'$numberDouble': '25.99'}  {'$date': {'$numberLong': '1212883200000'}}
# 2  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 3  {'$numberDouble': '22.95'}  {'$date': {'$numberLong': '1212883200000'}}
# 4  {'$numberDouble': '24.95'}  {'$date': {'$numberLong': '1212883200000'}}
#
#        publisher                 rank       rank_last_week  \
# 0         Bantam  {'$numberInt': '1'}  {'$numberInt': '0'}
# 1  Little, Brown  {'$numberInt': '2'}  {'$numberInt': '1'}
# 2   St. Martin's  {'$numberInt': '3'}  {'$numberInt': '2'}
# 3         Putnam  {'$numberInt': '4'}  {'$numberInt': '0'}
# 4      Doubleday  {'$numberInt': '5'}  {'$numberInt': '0'}
#
#                       title        weeks_on_list
# 0                 ODD HOURS  {'$numberInt': '1'}
# 1                  THE HOST  {'$numberInt': '3'}
# 2  LOVE THE ONE YOU'RE WITH  {'$numberInt': '2'}
# 3                 THE FRONT  {'$numberInt': '1'}
# 4                     SNUFF  {'$numberInt': '1'}

# %%
# Save DataFrame 'raw_nyt' into a json file ('output.json') and load it as 'data' we can now work with:

raw_nyt.to_json(path_or_buf='output.json', orient = "records")
with open('output.json') as file:
    data = json.load(file)
#pprint(data)

# %%
# Set up lists to hold reponse info:

nyt_ids = []
urls = []
authors = []
bestsellers_dates = []
descriptions = []
prices = []
published_dates = []
publishers = []
ranks = []
ranks_last_week = []
titles = []
weeks_on_lists = []

# Populate the lists:

for item in data:
    nyt_ids.append(item['_id']['$oid'])
    urls.append(item['amazon_product_url'])
    authors.append(item['author'])
    bestsellers_dates.append(item['bestsellers_date']['$date']['$numberLong'])
    descriptions.append(item['description'])
    published_dates.append(item['published_date']['$date']['$numberLong'])
    publishers.append(item['publisher'])
    ranks.append(item['rank']['$numberInt'])
    ranks_last_week.append(item['rank_last_week']['$numberInt'])
    titles.append(item['title'])
    weeks_on_lists.append(item['weeks_on_list']['$numberInt'])
# Here we have to check for the correct keyname before we can extract the price string:
    price_key, = item['price'].keys()
    if price_key == '$numberInt' or price_key == '$numberDouble':
        prices.append(item['price'][price_key])# Populate the lists:

# %%
# Create a DataFrame from the lists

bestsellers_dict = {
    "nyt_id": nyt_ids,
    "title": titles,
    "author": authors,
    "url": urls,
    "publisher": publishers,
    "description": descriptions,
    "list_price": prices,
    "published_date": published_dates,
    "bestseller_date": bestsellers_dates,
    "rank": ranks,
    "rank_last_week": ranks_last_week,
    "weeks_on_list": weeks_on_lists
}
bestsellers_data = pd.DataFrame(bestsellers_dict)
bestsellers_data.head()
# Out:
#                      nyt_id                     title             author  \
# 0  5b4aa4ead3089013507db18b                 ODD HOURS      Dean R Koontz
# 1  5b4aa4ead3089013507db18c                  THE HOST    Stephenie Meyer
# 2  5b4aa4ead3089013507db18d  LOVE THE ONE YOU'RE WITH       Emily Giffin
# 3  5b4aa4ead3089013507db18e                 THE FRONT  Patricia Cornwell
# 4  5b4aa4ead3089013507db18f                     SNUFF    Chuck Palahniuk
#
#                                                  url      publisher  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...         Bantam
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...  Little, Brown
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...   St. Martin's
# 3  http://www.amazon.com/The-Front-Garano-Patrici...         Putnam
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...      Doubleday
#
#                                          description list_price  \
# 0  Odd Thomas, who can communicate with the dead,...         27
# 1  Aliens have taken control of the minds and bod...      25.99
# 2  A woman's happy marriage is shaken when she en...      24.95
# 3  A Massachusetts state investigator and his tea...      22.95
# 4  An aging porn queens aims to cap her career by...      24.95
#
#   published_date bestseller_date rank rank_last_week weeks_on_list
# 0  1212883200000   1211587200000    1              0             1
# 1  1212883200000   1211587200000    2              1             3
# 2  1212883200000   1211587200000    3              2             2
# 3  1212883200000   1211587200000    4              0             1
# 4  1212883200000   1211587200000    5              0             1

# %%
bestsellers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 12 columns):
# nyt_id             10195 non-null object
# title              10195 non-null object
# author             10195 non-null object
# url                10195 non-null object
# publisher          10195 non-null object
# description        10195 non-null object
# list_price         10195 non-null object
# published_date     10195 non-null object
# bestseller_date    10195 non-null object
# rank               10195 non-null object
# rank_last_week     10195 non-null object
# weeks_on_list      10195 non-null object
# dtypes: object(12)
# memory usage: 955.9+ KB

# %% [markdown]
# ### STEP 2: Scrape info from amazon.com
#
# In this step, we identify the list of unique Amazon URLs from our bestsellers_data DataFrame, and we visit each of those URLs to scrape the Amazon price offer, number of customer reviews, and average 5-star rating.
# We encountered our second challenge here, as we had to iterate multiple times through our list of Amazon URLs and repetitively request the info we were seeking. Eventually we were able to scrape info for 1211 URLs out of the 2329 identified in our kaggle dataset.

# %%
# Import dependencies needed

from bs4 import BeautifulSoup
import requests
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36"}

# %%
# Get list of unique amazon urls

amazon_urls = list(dict.fromkeys(urls))
len(amazon_urls)
# Out:
# 2329

# %% [raw]
# # Set-up lists to store scraped info and user-defined functions for the iterations
#
# reviews = []
# ratings = []
# offers = []
# img_urls = []
#
# def get_nb_reviews(x_url):
#     if x_url not in [url for (url, _) in reviews]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         review = soup.find_all('span', id="acrCustomerReviewText")[0].text
#         reviews.append((url, review))
#
# def get_rating(x_url):
#     if x_url not in [url for (url, _) in ratings]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         rating = soup.find('span', class_="a-icon-alt").text
#         ratings.append((url, rating))
#
# def get_offer(x_url):
#     if x_url not in [url for (url, _) in offers]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         offer = soup.find('span', class_="a-size-medium a-color-price offer-price a-text-normal").text
#         offers.append((url, offer))
#
# def get_img(x_url):
#     if x_url not in [url for (url, _) in img_urls]:
#         response = requests.get(x_url, headers=headers)
#         soup = BeautifulSoup(response.text, 'lxml')
#         img_url = soup.find('div', id='img-canvas').find('img')['data-a-dynamic-image']
#         img_urls.append((url, img_url))

# %% [raw]
# # Extract info from amazon using requests
#
# missing_urls = []
# for url in amazon_urls:
#     try:
#         get_offer(url)
#         get_img(url)
#         get_nb_reviews(url)
#         get_rating(url)
#         print(url)
#     except (AttributeError, RuntimeError, TypeError, NameError, IndexError):
#         print("error")
#         missing_urls.append(url)

# %% [markdown]
# # TRANSFORM

# %% [markdown]
# ### STEP 1: Transform data from 'bestsellers_data' DataFrame
#
# The original kaggle dataset contains over 2300 datapoints, yet we could not scrape all of the info sought in amazon for each of the unique urls contained in the dataset. [Explain why we think we could not scrape it all]. Each team member scraped on her end with different using requests, but iterating in different ways (see jupyter notebook X and Y). We then merged our scraped data together and ended up with a dataframe of with a number of NaN values on certain fields.
#
# All data extracted from the json file and read into our bestsellers_data DataFrame has a the type 'string'. We now need to transform some of into the correct data type. Specifically:
# - 'list_price' should have the float type
# - 'published_date' and 'bestseller_date' should be formatted as dates
# - 'rank', 'rank_last_week', and 'weeks_on_list' should have the integer type

# %%
# Import dependencies needed

import numpy as np
from datetime import datetime

# %%
# Load our file of scraped Amazon data ('join_data.csv') into dataframe

Amazon_data1 = pd.read_csv("Output/join_data.csv")
Amazon_data2 = pd.read_csv("Output/more_scraped_data.csv")
print(Amazon_data1.count())
print(Amazon_data2.count())
print(bestsellers_data.count())
# Out:
# Unnamed: 0    1211
# url           1211
# reviews       1211
# rating        1211
# price         1211
# dtype: int64
# Unnamed: 0      2046
# url             2046
# nb_reviews      1641
# nb_stars        1615
# amazon_price    1237
# img_url         1307
# dtype: int64
# nyt_id             10195
# title              10195
# author             10195
# url                10195
# publisher          10195
# description        10195
# list_price         10195
# published_date     10195
# bestseller_date    10195
# rank               10195
# rank_last_week     10195
# weeks_on_list      10195
# dtype: int64

# %%
# Group bestsellers_data by url

grouped = bestsellers_data.groupby('url')
bestsellers_grouped = grouped['url', 'title', 'author', 'publisher', 'description', 'list_price', 'weeks_on_list'].max()

# Calculate additional columns

bestsellers_grouped['first_date_listed'] = grouped[['published_date']].min()
bestsellers_grouped['last_date_listed'] = grouped[['published_date']].max()
bestsellers_grouped['worst_rank'] = grouped[['rank']].max()
bestsellers_grouped['best_rank'] = grouped[['rank']].min()
bestsellers_grouped['times_listed'] = grouped[['url']].count()
#bestsellers_grouped["better_price"] = bestsellers_df.apply(lambda row : 'Amazon' if row['NYT_Price'] > row['Amazon_Price'] else 'NYT', axis=1)
bestsellers_grouped.count()
# Out:
# url                  2329
# title                2329
# author               2329
# publisher            2329
# description          2329
# list_price           2329
# weeks_on_list        2329
# first_date_listed    2329
# last_date_listed     2329
# worst_rank           2329
# best_rank            2329
# times_listed         2329
# dtype: int64

# %%
# Merge dataframes

df = pd.merge(bestsellers_grouped, Amazon_data1, on='url',how='left')
df = pd.merge(df, Amazon_data2, on='url',how='left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 21 columns):
# url                  2329 non-null object
# title                2329 non-null object
# author               2329 non-null object
# publisher            2329 non-null object
# description          2329 non-null object
# list_price           2329 non-null object
# weeks_on_list        2329 non-null object
# first_date_listed    2329 non-null object
# last_date_listed     2329 non-null object
# worst_rank           2329 non-null object
# best_rank            2329 non-null object
# times_listed         2329 non-null int64
# Unnamed: 0_x         1211 non-null float64
# reviews              1211 non-null object
# rating               1211 non-null object
# price                1211 non-null object
# Unnamed: 0_y         2046 non-null float64
# nb_reviews           1641 non-null float64
# nb_stars             1615 non-null float64
# amazon_price         1237 non-null object
# img_url              1307 non-null object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 400.3+ KB
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2961: FutureWarning: 'url' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Drop columns 'Unnamed: 0'

df.drop('Unnamed: 0_x', axis=1, inplace=True)
df.drop('Unnamed: 0_y', axis=1, inplace=True)

# %%
# Convert all price columns to float:

df['list_price'] = df['list_price'].apply(lambda x : float(x))
df['price']=df['price'].replace('[\$,]', '', regex=True).astype(float)
df['amazon_price']=df['amazon_price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Convert all date columns from unix time stamp to date format:

df['first_date_listed'] = df['first_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))
df['last_date_listed'] = df['last_date_listed'].apply(lambda x : datetime.utcfromtimestamp(int(x[:10])).strftime('%Y-%m-%d'))

# %%
# Convert 'weeks_on_list' and 'reviews; to integer, 'rating' to float:

df['weeks_on_list'] = df['weeks_on_list'].apply(lambda x : int(x))

# %%
#df['reviews'] = df['reviews'].str.replace(',', '')
#df['reviews'] = df['reviews'].apply(lambda x : int(x.split()[0]))
#df['rating'] = df['rating'].apply(lambda x : x.split()[0])
df.head()
# Out:
#                                                  url  \
# 0  http://www.amazon.com/10th-Anniversary-Womens-...
# 1  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# 2  http://www.amazon.com/11th-Hour-Womens-Murder-...
# 3  http://www.amazon.com/1225-Christmas-Tree-Lane...
# 4  http://www.amazon.com/12th-Never-Womens-Murder...
#
#                       title                             author      publisher  \
# 0          10TH ANNIVERSARY  James Patterson and Maxine Paetro  Little, Brown
# 1                  11/22/63                       Stephen King       Scribner
# 2                 11TH HOUR  James Patterson and Maxine Paetro  Little, Brown
# 3  1225 CHRISTMAS TREE LANE                    Debbie Macomber           Mira
# 4             12TH OF NEVER  James Patterson and Maxine Paetro  Little, Brown
#
#                                          description  list_price  \
# 0  Detective Lindsay Boxer’s long-awaited wedding...       27.99
# 1  An English teacher travels back to 1958 by way...       35.00
# 2  When a millionaire is gunned down, Detective L...       27.99
# 3  Puppies that need good homes and an ex-husband...       16.95
# 4  One week after the birth of her baby, Detectiv...        0.00
#
#    weeks_on_list first_date_listed last_date_listed worst_rank best_rank  \
# 0              8        2011-05-22       2011-07-24          9        16
# 1              9        2011-11-27       2012-05-13          6         1
# 2              8        2012-05-27       2012-07-29          6         1
# 3              4        2011-10-16       2011-11-27          8        10
# 4              6        2013-05-19       2013-06-30          8         1
#
#    times_listed                  reviews              rating  price  \
# 0            10   1,365 customer reviews  4.6 out of 5 stars   9.99
# 1            23  26,427 customer reviews  4.5 out of 5 stars  10.99
# 2            10   1,858 customer reviews  4.6 out of 5 stars   9.99
# 3             7                      NaN                 NaN    NaN
# 4             7   3,789 customer reviews  4.5 out of 5 stars   9.99
#
#    nb_reviews  nb_stars  amazon_price  \
# 0      1365.0       4.6          8.87
# 1     26432.0       NaN           NaN
# 2         NaN       4.6         10.00
# 3       741.0       NaN          5.98
# 4      3790.0       4.5         12.00
#
#                                              img_url
# 0  {"https://images-na.ssl-images-amazon.com/imag...
# 1                                                NaN
# 2  {"https://images-na.ssl-images-amazon.com/imag...
# 3  {"https://images-na.ssl-images-amazon.com/imag...
# 4  {"https://images-na.ssl-images-amazon.com/imag...

# %%
# Rename some columns

df = df.rename(columns={"list_price":"NYT_Price", "price":"Amazon_Price", 'url':'Amazon_url', 'reviews': 'nb_Amazon_reviews', 'rating': 'star_rating'})

# %%
# Group data by bestseller

grouped = df.groupby('Amazon_url')
bestsellers_df = grouped['Amazon_url', 'title', 'author', 'publisher', 'description', 'star_rating', 'nb_Amazon_reviews', 'weeks_on_list', 'NYT_Price', 'Amazon_Price'].max()

# Calculate additional columns

bestsellers_df['first_date_listed'] = grouped[['published_date']].min()
bestsellers_df['last_date_listed'] = grouped[['published_date']].max()
bestsellers_df['worst_rank'] = grouped[['rank']].max()
bestsellers_df['best_rank'] = grouped[['rank']].min()
bestsellers_df['times_listed'] = grouped[['Amazon_url']].count()
bestsellers_df["better_price"] = bestsellers_df.apply(lambda row : 'Amazon' if row['NYT_Price'] > row['Amazon_Price'] else 'NYT', axis=1)
bestsellers_df.head()
# Out:
#                                                                                            Amazon_url  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  http://www.amazon.com/10th-Anniversary-Womens-...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  http://www.amazon.com/11-22-63-A-Novel/dp/1451...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  http://www.amazon.com/11th-Hour-Womens-Murder-...
# http://www.amazon.com/12th-Never-Womens-Murder-...  http://www.amazon.com/12th-Never-Womens-Murder...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  http://www.amazon.com/14th-Deadly-Womens-Murde...
#
#                                                                title  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  10TH ANNIVERSARY
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          11/22/63
# http://www.amazon.com/11th-Hour-Womens-Murder-C...         11TH HOUR
# http://www.amazon.com/12th-Never-Womens-Murder-...     12TH OF NEVER
# http://www.amazon.com/14th-Deadly-Womens-Murder...   14TH DEADLY SIN
#
#                                                                                author  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  James Patterson and Maxine Paetro
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...                       Stephen King
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  James Patterson and Maxine Paetro
# http://www.amazon.com/12th-Never-Womens-Murder-...  James Patterson and Maxine Paetro
# http://www.amazon.com/14th-Deadly-Womens-Murder...  James Patterson and Maxine Paetro
#
#                                                         publisher  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Little, Brown
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       Scribner
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  Little, Brown
# http://www.amazon.com/12th-Never-Womens-Murder-...  Little, Brown
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Little, Brown
#
#                                                                                           description  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...  Detective Lindsay Boxer’s long-awaited wedding...
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...  An English teacher travels back to 1958 by way...
# http://www.amazon.com/11th-Hour-Womens-Murder-C...  When a millionaire is gunned down, Detective L...
# http://www.amazon.com/12th-Never-Womens-Murder-...  One week after the birth of her baby, Detectiv...
# http://www.amazon.com/14th-Deadly-Womens-Murder...  Detective Lindsay Boxer and her friends must r...
#
#                                                     star_rating  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          4.6
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          4.5
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          4.6
# http://www.amazon.com/12th-Never-Womens-Murder-...          4.5
# http://www.amazon.com/14th-Deadly-Womens-Murder...          4.3
#
#                                                     nb_Amazon_reviews  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...               1365
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...              26427
# http://www.amazon.com/11th-Hour-Womens-Murder-C...               1858
# http://www.amazon.com/12th-Never-Womens-Murder-...               3789
# http://www.amazon.com/14th-Deadly-Womens-Murder...               4140
#
#                                                     weeks_on_list  NYT_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...              8      27.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...             21      35.00
# http://www.amazon.com/11th-Hour-Womens-Murder-C...              8      27.99
# http://www.amazon.com/12th-Never-Womens-Murder-...              6       0.00
# http://www.amazon.com/14th-Deadly-Womens-Murder...              7       0.00
#
#                                                     Amazon_Price  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          9.99
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...         10.99
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          9.99
# http://www.amazon.com/12th-Never-Womens-Murder-...          9.99
# http://www.amazon.com/14th-Deadly-Womens-Murder...          9.99
#
#                                                    first_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...        2011-05-22
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...        2011-11-27
# http://www.amazon.com/11th-Hour-Womens-Murder-C...        2012-05-27
# http://www.amazon.com/12th-Never-Womens-Murder-...        2013-05-19
# http://www.amazon.com/14th-Deadly-Womens-Murder...        2015-05-24
#
#                                                    last_date_listed  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...       2011-07-24
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...       2012-05-13
# http://www.amazon.com/11th-Hour-Womens-Murder-C...       2012-07-29
# http://www.amazon.com/12th-Never-Womens-Murder-...       2013-06-30
# http://www.amazon.com/14th-Deadly-Womens-Murder...       2015-07-12
#
#                                                     worst_rank  best_rank  \
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...          18          2
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...          20          1
# http://www.amazon.com/11th-Hour-Womens-Murder-C...          20          1
# http://www.amazon.com/12th-Never-Womens-Murder-...          19          1
# http://www.amazon.com/14th-Deadly-Womens-Murder...          20          1
#
#                                                     times_listed better_price
# Amazon_url
# http://www.amazon.com/10th-Anniversary-Womens-M...            10       Amazon
# http://www.amazon.com/11-22-63-A-Novel/dp/14516...            23       Amazon
# http://www.amazon.com/11th-Hour-Womens-Murder-C...            10       Amazon
# http://www.amazon.com/12th-Never-Womens-Murder-...             7          NYT
# http://www.amazon.com/14th-Deadly-Womens-Murder...             8          NYT

# %% [markdown]
# # LOAD into MongoDB

# %% [markdown]
# ### Why MongoDB?
#
# The original kaggle dataset contains over 2300 datapoints, yet we could not scrape all of the info sought in amazon for each of the unique urls contained in the dataset. [Explain why we think we could not scrape it all]. Each team member scraped on her end with different using requests, but iterating in different ways (see jupyter notebook X and Y). We then merged our scraped data together and ended up with a dataframe of with a number of NaN values on certain fields. Since we wanted to keep all info for future app developpement, and one field is a long string (book description), we thought MongoDB would offer the best flexibility to store our data.

# %%
# Import dependencies needed
import pymongo

# %%
# Initialize PyMongo to work with MongoDB

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Check if database exists already and drop it if so

dblist = client.list_database_names()
if "nyt_bestsellers" in dblist:
    client.drop_database("nyt_bestsellers")

# %%
# Define database and collection

db = client.nyt_bestsellers
collection = db.bestsellers

# %%
bestsellers_df = pd.read_csv("Output/output_table_final_version.csv")
bestsellers_df.head()
# Out:
#    Unnamed: 0                    nyt_id                     title  \
# 0           0  5b4aa4ead3089013507db18b                 ODD HOURS
# 1           1  5b4aa4ead3089013507db18c                  THE HOST
# 2           2  5b4aa4ead3089013507db18d  LOVE THE ONE YOU'RE WITH
# 3           3  5b4aa4ead3089013507db18e                 THE FRONT
# 4           4  5b4aa4ead3089013507db18f                     SNUFF
#
#                                           Amazon_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# 1  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 2  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 3  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 4  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
#
#        publisher                                        description  \
# 0         Bantam  Odd Thomas, who can communicate with the dead,...
# 1  Little, Brown  Aliens have taken control of the minds and bod...
# 2   St. Martin's  A woman's happy marriage is shaken when she en...
# 3         Putnam  A Massachusetts state investigator and his tea...
# 4      Doubleday  An aging porn queens aims to cap her career by...
#
#   published_date bestseller_date  rank  rank_last_week  weeks_on_list  \
# 0     2008-06-08      2008-05-24     1               0              1
# 1     2008-06-08      2008-05-24     2               1              3
# 2     2008-06-08      2008-05-24     3               2              2
# 3     2008-06-08      2008-05-24     4               0              1
# 4     2008-06-08      2008-05-24     5               0              1
#
#    NYT_Price  Amazon_Price  Amazon_reviews  Amazon_rating  Amazon_Discount%
# 0      27.00          7.99           920.0            4.4             29.59
# 1      25.99          7.99          6109.0            4.5             30.74
# 2      24.95          8.99           702.0            4.0             36.03
# 3      22.95          7.99           323.0            3.0             34.81
# 4      24.95          9.99           237.0            3.5             40.04

# %%
# Create a list of dictionaries that hold the mongoDB documents to be inserted

post = bestsellers_df.to_dict(orient='records')
print(f"Posting {len(post)} documents into collection of bestsellers inside nyt_bestsellers mongo database...")

# Insert the list of documents into the database

collection.insert_many(post)
# Out:
# Posting 2194 documents into collection of bestsellers inside nyt_bestsellers mongo database...

# %%
# Verify results

results = collection.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5c808d57bd7b6a18fc59d51d'), 'Unnamed: 0': 0, 'nyt_id': '5b4aa4ead3089013507db18b', 'title': 'ODD HOURS', 'Amazon_url': 'http://www.amazon.com/Odd-Hours-Dean-Koontz/dp/0553807056?tag=NYTBS-20', 'author': 'Dean R Koontz', 'publisher': 'Bantam', 'description': 'Odd Thomas, who can communicate with the dead, confronts evil forces in a California coastal town.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 920.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 29.59}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d51e'), 'Unnamed: 0': 1, 'nyt_id': '5b4aa4ead3089013507db18c', 'title': 'THE HOST', 'Amazon_url': 'http://www.amazon.com/The-Host-Novel-Stephenie-Meyer/dp/0316218502?tag=NYTBS-20', 'author': 'Stephenie Meyer', 'publisher': 'Little, Brown', 'description': 'Aliens have taken control of the minds and bodies of most humans, but one woman won’t surrender.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 2, 'rank_last_week': 1, 'weeks_on_list': 3, 'NYT_Price': 25.99, 'Amazon_Price': 7.99, 'Amazon_reviews': 6109.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 30.74}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d51f'), 'Unnamed: 0': 2, 'nyt_id': '5b4aa4ead3089013507db18d', 'title': "LOVE THE ONE YOU'RE WITH", 'Amazon_url': 'http://www.amazon.com/Love-Youre-With-Emily-Giffin/dp/0312348665?tag=NYTBS-20', 'author': 'Emily Giffin', 'publisher': "St. Martin's", 'description': "A woman's happy marriage is shaken when she encounters an old boyfriend.", 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 3, 'rank_last_week': 2, 'weeks_on_list': 2, 'NYT_Price': 24.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 702.0, 'Amazon_rating': 4.0, 'Amazon_Discount%': 36.03}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d520'), 'Unnamed: 0': 3, 'nyt_id': '5b4aa4ead3089013507db18e', 'title': 'THE FRONT', 'Amazon_url': 'http://www.amazon.com/The-Front-Garano-Patricia-Cornwell-ebook/dp/B0017T0C9M?tag=NYTBS-20', 'author': 'Patricia Cornwell', 'publisher': 'Putnam', 'description': 'A Massachusetts state investigator and his team from "At Risk" confront a rogue association of municipal police departments.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 22.95, 'Amazon_Price': 7.99, 'Amazon_reviews': 323.0, 'Amazon_rating': 3.0, 'Amazon_Discount%': 34.81}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d521'), 'Unnamed: 0': 4, 'nyt_id': '5b4aa4ead3089013507db18f', 'title': 'SNUFF', 'Amazon_url': 'http://www.amazon.com/Snuff-Chuck-Palahniuk/dp/0385517882?tag=NYTBS-20', 'author': 'Chuck Palahniuk', 'publisher': 'Doubleday', 'description': 'An aging porn queens aims to cap her career by having sex on film with 600 men in one day.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 5, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 237.0, 'Amazon_rating': 3.5, 'Amazon_Discount%': 40.04}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d522'), 'Unnamed: 0': 5, 'nyt_id': '5b4aa4ead3089013507db190', 'title': 'SUNDAYS AT TIFFANY’S', 'Amazon_url': 'http://www.amazon.com/Sundays-at-Tiffanys-James-Patterson/dp/0446199443?tag=NYTBS-20', 'author': 'James Patterson and Gabrielle Charbonnet', 'publisher': 'Little, Brown', 'description': 'A woman finds an unexpected love', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 6, 'rank_last_week': 3, 'weeks_on_list': 4, 'NYT_Price': 24.99, 'Amazon_Price': 6.99, 'Amazon_reviews': 478.0, 'Amazon_rating': 4.0, 'Amazon_Discount%': 27.97}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d523'), 'Unnamed: 0': 6, 'nyt_id': '5b4aa4ead3089013507db191', 'title': 'PHANTOM PREY', 'Amazon_url': 'http://www.amazon.com/Phantom-Prey-John-Sandford/dp/0425227987?tag=NYTBS-20', 'author': 'John Sandford', 'publisher': 'Putnam', 'description': 'The Minneapolis detective Lucas Davenport investigates a string of murders of young Goths.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 7, 'rank_last_week': 4, 'weeks_on_list': 3, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 435.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d524'), 'Unnamed: 0': 7, 'nyt_id': '5b4aa4ead3089013507db192', 'title': 'SWINE NOT?', 'Amazon_url': 'http://www.amazon.com/From-Worse-Southern-Vampire-Mysteries/dp/0441015891?tag=NYTBS-20', 'author': 'Jimmy Buffett', 'publisher': 'Little, Brown', 'description': 'A Southern family tries to hide its pet pig at a New York luxury hotel.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 8, 'rank_last_week': 6, 'weeks_on_list': 2, 'NYT_Price': 21.99, 'Amazon_Price': 7.99, 'Amazon_reviews': 685.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 36.33}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d525'), 'Unnamed: 0': 8, 'nyt_id': '5b4aa4ead3089013507db193', 'title': 'CARELESS IN RED', 'Amazon_url': 'http://www.amazon.com/Where-Are-You-Now-Novel/dp/1416566384?tag=NYTBS-20', 'author': 'Elizabeth George', 'publisher': 'Harper', 'description': "In Cornwall, trying to recover from his wife's death, Detective Thomas Lynley becomes involved in a murder investigation.", 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 9, 'rank_last_week': 8, 'weeks_on_list': 3, 'NYT_Price': 27.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 621.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 32.16}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d526'), 'Unnamed: 0': 9, 'nyt_id': '5b4aa4ead3089013507db194', 'title': 'THE WHOLE TRUTH', 'Amazon_url': 'http://www.amazon.com/The-Whole-Truth-David-Baldacci/dp/0446539686?tag=NYTBS-20', 'author': 'David Baldacci', 'publisher': 'Grand Central', 'description': 'An intelligence agent and a journalist team up against a warmongering defense contractor.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 10, 'rank_last_week': 7, 'weeks_on_list': 5, 'NYT_Price': 26.99, 'Amazon_Price': 9.99, 'Amazon_reviews': 1064.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 37.01}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d527'), 'Unnamed: 0': 10, 'nyt_id': '5b4aa4ead3089013507db195', 'title': 'INVINCIBLE', 'Amazon_url': 'http://www.amazon.com/Careless-Red-Novel-Elizabeth-George/dp/0061160873?tag=NYTBS-20', 'author': 'Troy Denning', 'publisher': 'Del Rey/Ballantine', 'description': "The New Jedi order battles Darth Caedus, Darth Vader's gradson; a 'Star Wars: Legacy of the Force' novel.", 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 11, 'rank_last_week': 5, 'weeks_on_list': 2, 'NYT_Price': 27.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 347.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': 37.0}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d528'), 'Unnamed: 0': 11, 'nyt_id': '5b4aa4ead3089013507db196', 'title': 'BRIGHT SHINY MORNING', 'Amazon_url': 'http://www.amazon.com/Unaccustomed-Earth-Jhumpa-Lahiri/dp/0307265730?tag=NYTBS-20', 'author': 'James Frey', 'publisher': 'Harper', 'description': 'A novel, set in Los Angeles, by the author of "A Million Little Pieces."', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 12, 'rank_last_week': 9, 'weeks_on_list': 2, 'NYT_Price': 26.95, 'Amazon_Price': 11.99, 'Amazon_reviews': 521.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 44.49}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d529'), 'Unnamed: 0': 12, 'nyt_id': '5b4aa4ead3089013507db197', 'title': 'THE ART OF RACING IN THE RAIN', 'Amazon_url': 'http://www.amazon.com/The-Racing-Rain-Garth-Stein-ebook/dp/B0017SWPXY?tag=NYTBS-20', 'author': 'Garth Stein', 'publisher': 'Harper', 'description': 'A Lab-terrier mix with great insight into the human condition helps his owner, a struggling race car driver.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 13, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 23.95, 'Amazon_Price': 11.99, 'Amazon_reviews': 8318.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': 50.06}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52a'), 'Unnamed: 0': 13, 'nyt_id': '5b4aa4ead3089013507db198', 'title': 'TWENTY WISHES', 'Amazon_url': 'http://www.amazon.com/Twenty-Wishes-Blossom-Street-Books/dp/0778326314?tag=NYTBS-20', 'author': 'Debbie Macomber', 'publisher': 'Mira', 'description': 'A widow who owns a bookstore on Blossom Street compiles a list of things she always wanted to do.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 14, 'rank_last_week': 10, 'weeks_on_list': 4, 'NYT_Price': 24.95, 'Amazon_Price': 5.99, 'Amazon_reviews': 455.0, 'Amazon_rating': 4.6, 'Amazon_Discount%': 24.01}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52b'), 'Unnamed: 0': 14, 'nyt_id': '5b4aa4ead3089013507db199', 'title': 'THE STEEL WAVE', 'Amazon_url': 'http://www.amazon.com/Hold-Tight-Harlan-Coben/dp/0525950605?tag=NYTBS-20', 'author': 'Jeff Shaara', 'publisher': 'Ballantine', 'description': 'A novel about the Allied invasion in France in World War II.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 15, 'rank_last_week': 11, 'weeks_on_list': 2, 'NYT_Price': 28.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 583.0, 'Amazon_rating': 4.3, 'Amazon_Discount%': 35.68}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52c'), 'Unnamed: 0': 15, 'nyt_id': '5b4aa4ead3089013507db19a', 'title': 'EXECUTIVE PRIVILEGE', 'Amazon_url': 'http://www.amazon.com/Executive-Privilege-Novel-Phillip-Margolin/dp/0061236217?tag=NYTBS-20', 'author': 'Phillip Margolin', 'publisher': 'HarperCollins Publishers', 'description': nan, 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 16, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 4.99, 'Amazon_reviews': 473.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52d'), 'Unnamed: 0': 16, 'nyt_id': '5b4aa4ead3089013507db19b', 'title': 'UNACCUSTOMED EARTH', 'Amazon_url': 'http://www.amazon.com/Unaccustomed-Vintage-Contemporaries-Jhumpa-Lahiri/dp/0307278255?tag=NYTBS-20', 'author': 'Jhumpa Lahiri', 'publisher': 'Knopf', 'description': 'Stories of the anxiety and transformation experienced by Bengalis in America.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 17, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'Amazon_reviews': 521.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52e'), 'Unnamed: 0': 17, 'nyt_id': '5b4aa4ead3089013507db19c', 'title': 'NETHERLAND', 'Amazon_url': 'http://www.amazon.com/Netherland-A-Novel-Joseph-ONeill/dp/0307377040?tag=NYTBS-20', 'author': "Joseph O'Neill", 'publisher': 'Knopf Publishing Group', 'description': 'A Dutchman deserted by his wife after 9/11 finds solace in New York’s immigrant cricket scene.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 18, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 11.99, 'Amazon_reviews': 242.0, 'Amazon_rating': 3.5, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d52f'), 'Unnamed: 0': 18, 'nyt_id': '5b4aa4ead3089013507db19d', 'title': 'THE APPEAL', 'Amazon_url': 'http://www.amazon.com/The-Appeal-John-Grisham/dp/0440243815?tag=NYTBS-20', 'author': 'John Grisham', 'publisher': 'Doubleday Publishing', 'description': 'Political and legal intrigue ensue when a Mississippi court rules against a company accused of dumping toxic waste.', 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 19, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 1257.0, 'Amazon_rating': 3.5, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d530'), 'Unnamed: 0': 19, 'nyt_id': '5b4aa4ead3089013507db19e', 'title': 'INDIANA JONES AND THE KINGDOM OF THE CRYSTAL SKULL', 'Amazon_url': 'http://www.amazon.com/Indiana-Jones-Kingdom-Crystal-Skull/dp/0345501284?tag=NYTBS-20', 'author': 'James Rollins', 'publisher': 'Random House Publishing Group', 'description': nan, 'published_date': '2008-06-08', 'bestseller_date': '2008-05-24', 'rank': 20, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 16.0, 'Amazon_reviews': 36.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d531'), 'Unnamed: 0': 20, 'nyt_id': '5b4aa4ead3089013507db19f', 'title': 'BLOOD NOIR', 'Amazon_url': 'http://www.amazon.com/Blood-Anita-Blake-Vampire-Hunter/dp/0515146374?tag=NYTBS-20', 'author': 'Laurell K Hamilton', 'publisher': 'Berkley', 'description': 'The vampire hunter Anita Blake is involved in a scandal that threatens the master vampire Jean-Claude’s power.', 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 518.0, 'Amazon_rating': 3.4, 'Amazon_Discount%': 34.64}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d532'), 'Unnamed: 0': 21, 'nyt_id': '5b4aa4ead3089013507db1a4', 'title': 'CHASING HARRY WINSTON', 'Amazon_url': 'http://www.amazon.com/Chasing-Harry-Winston-A-Novel/dp/0743290119?tag=NYTBS-20', 'author': 'Lauren Weisberger', 'publisher': 'Simon & Schuster', 'description': 'Three glamorous friends, New York women nearing 30, vow to change their lives.', 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 6, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 11.99, 'Amazon_reviews': 301.0, 'Amazon_rating': 3.1, 'Amazon_Discount%': 46.2}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d533'), 'Unnamed: 0': 22, 'nyt_id': '5b4aa4ead3089013507db1a6', 'title': 'DEVIL MAY CARE', 'Amazon_url': 'http://www.amazon.com/Devil-Care-James-Bond-Novel/dp/0385524285?tag=NYTBS-20', 'author': 'Sebastian Faulks', 'publisher': 'Doubleday', 'description': 'This continuation of the James Bond franchise finds Bond tracking a dangerous pharmaceutical executive amid cold war tensions with the help of a beautiful girl.', 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 8, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 7.99, 'Amazon_reviews': 169.0, 'Amazon_rating': 3.5, 'Amazon_Discount%': 32.02}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d534'), 'Unnamed: 0': 23, 'nyt_id': '5b4aa4ead3089013507db1a9', 'title': 'SHADOW OF POWER', 'Amazon_url': 'http://www.amazon.com/Shadow-Power-Paul-Madriani-Novel/dp/B001OW5OR2?tag=NYTBS-20', 'author': 'Steve Martini', 'publisher': 'Morrow', 'description': 'The lawyer Paul Madriani searches for a missing letter from Thomas Jefferson that might explain a scholar’s murder.', 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 11, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 7.49, 'Amazon_reviews': 153.0, 'Amazon_rating': 3.8, 'Amazon_Discount%': 27.79}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d535'), 'Unnamed: 0': 24, 'nyt_id': '5b4aa4ead3089013507db1af', 'title': 'BLUE SMOKE AND MURDER', 'Amazon_url': 'http://www.amazon.com/Blue-Smoke-Murder-Elizabeth-Lowell/dp/0060829869?tag=NYTBS-20', 'author': 'Elizabeth Lowell', 'publisher': 'HarperCollins Publishers', 'description': nan, 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 17, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 5.99, 'Amazon_reviews': 81.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d536'), 'Unnamed: 0': 25, 'nyt_id': '5b4aa4ead3089013507db1b1', 'title': 'THE ENCHANTRESS OF FLORENCE', 'Amazon_url': 'http://www.amazon.com/The-Enchantress-Florence-A-Novel/dp/0679640517?tag=NYTBS-20', 'author': 'Salman Rushdie', 'publisher': 'Random House Publishing Group', 'description': nan, 'published_date': '2008-06-15', 'bestseller_date': '2008-05-31', 'rank': 19, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 13.99, 'Amazon_reviews': 177.0, 'Amazon_rating': 3.7, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d537'), 'Unnamed: 0': 26, 'nyt_id': '5b4aa4ead3089013507db1b3', 'title': 'NOTHING TO LOSE', 'Amazon_url': 'http://www.amazon.com/Nothing-Lose-Jack-Reacher-No/dp/0440245583?tag=NYTBS-20', 'author': 'Lee Child', 'publisher': 'Delacorte', 'description': 'Jack Reacher exposes the secrets of a Colorado town.', 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 1982.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': 37.0}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d538'), 'Unnamed: 0': 27, 'nyt_id': '5b4aa4ead3089013507db1b5', 'title': 'PLAGUE SHIP', 'Amazon_url': 'http://www.amazon.com/Plague-Ship-The-Oregon-Files/dp/0425226697?tag=NYTBS-20', 'author': 'Clive Cussler with Jack Du Brul', 'publisher': 'Putnam', 'description': 'Juan Cabrillo and the crew of the Oregon must determine what happened on a cruise ship full of dead bodies.', 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 4.99, 'Amazon_reviews': 310.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 18.52}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d539'), 'Unnamed: 0': 28, 'nyt_id': '5b4aa4ead3089013507db1bb', 'title': 'DEATH AND HONOR', 'Amazon_url': 'http://www.amazon.com/Death-Honor-Bound-Book/dp/0515146382?tag=NYTBS-20', 'author': 'W E B Griffin and William E Butterworth IV', 'publisher': 'Putnam', 'description': 'A Marine pilot spies in  Argentina in 1943; the fourth book in the Honor Bound series.', 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 191.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53a'), 'Unnamed: 0': 29, 'nyt_id': '5b4aa4ead3089013507db1c2', 'title': 'THE SPIES OF WARSAW', 'Amazon_url': 'http://www.amazon.com/The-Spies-Warsaw-A-Novel/dp/0812977378?tag=NYTBS-20', 'author': 'Alan Furst', 'publisher': 'Random House', 'description': 'Intrigue in Poland just before World War II.', 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 16, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 12.99, 'Amazon_reviews': 262.0, 'Amazon_rating': 4.3, 'Amazon_Discount%': 51.96}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53b'), 'Unnamed: 0': 30, 'nyt_id': '5b4aa4ead3089013507db1c3', 'title': 'THE GARDEN OF LAST DAYS', 'Amazon_url': 'http://www.amazon.com/The-Garden-Last-Days-Novel/dp/0393041654?tag=NYTBS-20', 'author': 'Andre Dubus', 'publisher': 'Norton & Company, Incorporated, W. W.', 'description': nan, 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 17, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 168.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53c'), 'Unnamed: 0': 31, 'nyt_id': '5b4aa4ead3089013507db1c5', 'title': 'RESOLUTION', 'Amazon_url': 'http://www.amazon.com/Resolution-Robert-B-Parker/dp/0425227995?tag=NYTBS-20', 'author': 'Robert B Parker', 'publisher': 'Penguin Group (USA) Incorporated', 'description': nan, 'published_date': '2008-06-22', 'bestseller_date': '2008-06-07', 'rank': 19, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 225.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53d'), 'Unnamed: 0': 32, 'nyt_id': '5b4aa4ead3089013507db1c7', 'title': 'SAIL', 'Amazon_url': 'http://www.amazon.com/Sail-James-Patterson/dp/0446536105?tag=NYTBS-20', 'author': 'James Patterson and Howard Roughan', 'publisher': 'Little, Brown', 'description': 'A sailing vacation turns into a disaster when someone attempts to destroy a family.', 'published_date': '2008-06-29', 'bestseller_date': '2008-06-14', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.99, 'Amazon_Price': 7.99, 'Amazon_reviews': 468.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': 28.55}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53e'), 'Unnamed: 0': 33, 'nyt_id': '5b4aa4ead3089013507db1cd', 'title': 'THE BROKEN WINDOW', 'Amazon_url': 'http://www.amazon.com/The-Broken-Window-Lincoln-Rhyme/dp/1416549986?tag=NYTBS-20', 'author': 'Jeffery Deaver', 'publisher': 'Simon & Schuster', 'description': 'Detectives Lincoln Rhyme and Amelia Sachs come up against a criminal who uses identity theft to frame innocent people for murdering his victims.', 'published_date': '2008-06-29', 'bestseller_date': '2008-06-14', 'rank': 7, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 463.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d53f'), 'Unnamed: 0': 34, 'nyt_id': '5b4aa4ead3089013507db1cf', 'title': 'MARRIED LOVERS', 'Amazon_url': 'http://www.amazon.com/Married-Lovers-Jackie-Collins/dp/0312341814?tag=NYTBS-20', 'author': 'Jackie Collins', 'publisher': 'St. Martin’s', 'description': 'An affair between a beautiful personal trainer and a producer married to Hollywood royalty leads to \xadmurder.', 'published_date': '2008-06-29', 'bestseller_date': '2008-06-14', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 90.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d540'), 'Unnamed: 0': 35, 'nyt_id': '5b4aa4ead3089013507db1d4', 'title': 'THE STORY OF EDGAR SAWTELLE', 'Amazon_url': 'http://www.amazon.com/Story-Edgar-Sawtelle-David-Wroblewski/dp/B005DIGU4O?tag=NYTBS-20', 'author': 'David Wroblewski', 'publisher': 'Ecco', 'description': 'A young mute who can communicate with dogs his family raises takes refuge with three of them in the Wisconsin woods after his uncle murders his father.', 'published_date': '2008-06-29', 'bestseller_date': '2008-06-14', 'rank': 14, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 2573.0, 'Amazon_rating': 3.8, 'Amazon_Discount%': 34.64}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d541'), 'Unnamed: 0': 36, 'nyt_id': '5b4aa4ead3089013507db1d9', 'title': 'THE BRIEF WONDROUS LIFE OF OSCAR WAO', 'Amazon_url': 'http://www.amazon.com/The-Brief-Wondrous-Life-Oscar/dp/1594483299?tag=NYTBS-20', 'author': 'Junot Díaz', 'publisher': 'Riverhead', 'description': 'A nerdy Dominican-American struggles to escape a family curse.', 'published_date': '2008-06-29', 'bestseller_date': '2008-06-14', 'rank': 19, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'Amazon_reviews': 1556.0, 'Amazon_rating': 4.0, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d542'), 'Unnamed: 0': 37, 'nyt_id': '5b4aa4ead3089013507db1db', 'title': 'FEARLESS FOURTEEN', 'Amazon_url': 'http://www.amazon.com/Fearless-Fourteen-Janet-Evanovich/dp/0312349513?tag=NYTBS-20', 'author': 'Janet Evanovich', 'publisher': 'St. Martin’s', 'description': 'Stephanie Plum and her boyfriend Joe Morelli become involved when his cousin’s bank robbery goes bad.', 'published_date': '2008-07-06', 'bestseller_date': '2008-06-21', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 1041.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 32.16}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d543'), 'Unnamed: 0': 38, 'nyt_id': '5b4aa4ead3089013507db1e4', 'title': 'NO CHOICE BUT SEDUCTION', 'Amazon_url': 'http://www.amazon.com/No-Choice-But-Seduction-Malory/dp/1416537333?tag=NYTBS-20', 'author': 'Johanna Lindsey', 'publisher': 'Pocket Books', 'description': 'Sir Anthony Malory’s daughter is kidnapped, with repercussions for Katey and Boyd Anderson.', 'published_date': '2008-07-06', 'bestseller_date': '2008-06-21', 'rank': 10, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 362.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': 31.96}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d544'), 'Unnamed: 0': 39, 'nyt_id': '5b4aa4ead3089013507db1e5', 'title': 'THE BEACH HOUSE', 'Amazon_url': 'http://www.amazon.com/The-Beach-House-A-Novel/dp/0452295386?tag=NYTBS-20', 'author': 'Jane Green', 'publisher': 'Viking, $24.95', 'description': 'A woman’s life changes when she rents out rooms in her Nantucket house.', 'published_date': '2008-07-06', 'bestseller_date': '2008-06-21', 'rank': 11, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 8.99, 'Amazon_reviews': 521.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d545'), 'Unnamed: 0': 40, 'nyt_id': '5b4aa4ead3089013507db1f1', 'title': 'TAILSPIN', 'Amazon_url': 'http://www.amazon.com/TailSpin-FBI-Thriller-Catherine-Coulter/dp/051514648X?tag=NYTBS-20', 'author': 'Catherine Coulter', 'publisher': 'Putnam', 'description': 'Dillon Savich and Lacey Sherlock — F.B.I. agents as well as husband and wife — come to the aid of a colleague protecting a Washington psychiatrist who has been disclosing secrets about his powerful patients.', 'published_date': '2008-07-13', 'bestseller_date': '2008-06-28', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 256.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 34.64}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d546'), 'Unnamed: 0': 41, 'nyt_id': '5b4aa4ead3089013507db1f2', 'title': 'ROGUE', 'Amazon_url': 'http://www.amazon.com/Rogue-Danielle-Steel/dp/0440243297?tag=NYTBS-20', 'author': 'Danielle Steel', 'publisher': 'Delacorte', 'description': 'A divorced doctor on the verge of marriage to a kind new man faces a quandary when her exasperating ex-husband, a dot-com millionaire, wants her to work with him on a humanitarian project.', 'published_date': '2008-07-13', 'bestseller_date': '2008-06-28', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 192.0, 'Amazon_rating': 4.3, 'Amazon_Discount%': 29.59}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d547'), 'Unnamed: 0': 42, 'nyt_id': '5b4aa4ead3089013507db1f5', 'title': 'THE LAST ORACLE', 'Amazon_url': 'http://www.amazon.com/The-Last-Oracle-Sigma-Force/dp/0061230952?tag=NYTBS-20', 'author': 'James Rollins', 'publisher': 'Morrow', 'description': 'Sigma Force operatives battle a group of rogue scientists.', 'published_date': '2008-07-13', 'bestseller_date': '2008-06-28', 'rank': 7, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 412.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d548'), 'Unnamed: 0': 43, 'nyt_id': '5b4aa4ead3089013507db1fd', 'title': 'AMERICA AMERICA', 'Amazon_url': 'http://www.amazon.com/America-A-Novel-Ethan-Canin/dp/0679456805?tag=NYTBS-20', 'author': 'Ethan Canin', 'publisher': 'Random House', 'description': 'A boy becomes entangled with a powerful family in upstate New York in the early 1970s.', 'published_date': '2008-07-13', 'bestseller_date': '2008-06-28', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.0, 'Amazon_Price': 11.99, 'Amazon_reviews': 97.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': 44.41}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d549'), 'Unnamed: 0': 44, 'nyt_id': '5b4aa4ead3089013507db202', 'title': 'QUEEN OF BABBLE GETS HITCHED', 'Amazon_url': 'http://www.amazon.com/Queen-Babble-Gets-Hitched-Cabot/dp/006085202X?tag=NYTBS-20', 'author': 'Meg Cabot', 'publisher': 'HarperCollins Publishers', 'description': nan, 'published_date': '2008-07-13', 'bestseller_date': '2008-06-28', 'rank': 20, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 9.49, 'Amazon_reviews': 78.0, 'Amazon_rating': 3.5, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54a'), 'Unnamed: 0': 45, 'nyt_id': '5b4aa4ead3089013507db203', 'title': 'THE LAST PATRIOT', 'Amazon_url': 'http://www.amazon.com/The-Last-Patriot-A-Thriller/dp/1416543848?tag=NYTBS-20', 'author': 'Brad Thor', 'publisher': 'Atria', 'description': 'Scot Harvath, a Homeland Security superagent, searches for an ancient secret that could defeat Islamic militants.', 'published_date': '2008-07-20', 'bestseller_date': '2008-07-05', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.0, 'Amazon_Price': 8.99, 'Amazon_reviews': 631.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 34.58}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54b'), 'Unnamed: 0': 46, 'nyt_id': '5b4aa4ead3089013507db209', 'title': 'CHASING DARKNESS', 'Amazon_url': 'http://www.amazon.com/Chasing-Darkness-Elvis-Novel-Novels/dp/0743281640?tag=NYTBS-20', 'author': 'Robert Crais', 'publisher': 'Simon & Schuster', 'description': 'he Los Angeles private eye Elvis Cole responsible for the release of a serial killer?', 'published_date': '2008-07-20', 'bestseller_date': '2008-07-05', 'rank': 7, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 583.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 34.64}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54c'), 'Unnamed: 0': 47, 'nyt_id': '5b4aa4ead3089013507db20b', 'title': 'DEATH ANGEL', 'Amazon_url': 'http://www.amazon.com/Death-Angel-Novel-Linda-Howard/dp/0345486552?tag=NYTBS-20', 'author': 'Linda Howard', 'publisher': 'Ballantine', 'description': 'A crime lord’s former mistress cooperates with the F.B.I.', 'published_date': '2008-07-20', 'bestseller_date': '2008-07-05', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 260.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 30.73}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54d'), 'Unnamed: 0': 48, 'nyt_id': '5b4aa4ead3089013507db215', 'title': 'A SUMMER AFFAIR', 'Amazon_url': 'http://www.amazon.com/A-Summer-Affair-Novel/dp/B003P2VBNU?tag=NYTBS-20', 'author': 'Elin Hilderbrand', 'publisher': 'Little Brown & Company', 'description': 'A successful married artist is attracted to a billionaire on Nantucket.', 'published_date': '2008-07-20', 'bestseller_date': '2008-07-05', 'rank': 19, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 241.0, 'Amazon_rating': 3.7, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54e'), 'Unnamed: 0': 49, 'nyt_id': '5b4aa4ead3089013507db217', 'title': 'TRIBUTE', 'Amazon_url': 'http://www.amazon.com/Tribute-Nora-Roberts/dp/0515146366?tag=NYTBS-20', 'author': 'Nora Roberts', 'publisher': 'Putnam', 'description': 'A former child star returns to Virginia to rehabilitate the farm owned by her grandmother, an actress who died mysteriously.', 'published_date': '2008-07-27', 'bestseller_date': '2008-07-12', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 7.99, 'Amazon_reviews': 395.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 29.65}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d54f'), 'Unnamed: 0': 50, 'nyt_id': '5b4aa4ead3089013507db21b', 'title': 'SWAN PEAK', 'Amazon_url': 'http://www.amazon.com/Swan-Peak-Dave-Robicheaux-No/dp/1416548548?tag=NYTBS-20', 'author': 'James Lee Burke', 'publisher': 'Simon & Schuster', 'description': 'The Louisiana detective Dave Robicheaux can’t escape trouble on his Montana vacation.', 'published_date': '2008-07-27', 'bestseller_date': '2008-07-12', 'rank': 5, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 253.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': 38.5}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d550'), 'Unnamed: 0': 51, 'nyt_id': '5b4aa4ead3089013507db225', 'title': 'SILENT THUNDER', 'Amazon_url': 'http://www.amazon.com/Silent-Thunder-Iris-Johansen/dp/0312368003?tag=NYTBS-20', 'author': 'Iris Johansen and Roy Johansen', 'publisher': 'St. Martin’s', 'description': 'A decommissioned Soviet submarine holds a deadly secret.', 'published_date': '2008-07-27', 'bestseller_date': '2008-07-12', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 7.99, 'Amazon_reviews': 80.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': 32.02}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d551'), 'Unnamed: 0': 52, 'nyt_id': '5b4aa4ead3089013507db22d', 'title': 'RULES OF DECEPTION', 'Amazon_url': 'http://www.amazon.com/Rules-Deception-Christopher-Reich/dp/0307387828?tag=NYTBS-20', 'author': 'Christopher Reich', 'publisher': 'Doubleday', 'description': 'The death of a surgeon’s wife draws him into a world of espionage and terrorism.', 'published_date': '2008-08-03', 'bestseller_date': '2008-07-19', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.95, 'Amazon_Price': 4.99, 'Amazon_reviews': 196.0, 'Amazon_rating': 4.0, 'Amazon_Discount%': 17.85}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d552'), 'Unnamed: 0': 53, 'nyt_id': '5b4aa4ead3089013507db232', 'title': 'JUST TOO GOOD TO BE TRUE', 'Amazon_url': 'http://www.amazon.com/Just-Too-Good-Be-True/dp/0385492723?tag=NYTBS-20', 'author': 'E Lynn Harris', 'publisher': 'Double\xadday', 'description': 'Secrets threaten the relationship between a mother, a successful Atlanta entrepreneur, and her son, a college football player who is bound for the N.F.L.', 'published_date': '2008-08-03', 'bestseller_date': '2008-07-19', 'rank': 8, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 11.99, 'Amazon_reviews': 137.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': 48.06}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d553'), 'Unnamed: 0': 54, 'nyt_id': '5b4aa4ead3089013507db236', 'title': 'SAY GOODBYE', 'Amazon_url': 'http://www.amazon.com/Say-Goodbye-FBI-Profiler-Novel/dp/0553588095?tag=NYTBS-20', 'author': 'Lisa Gardner', 'publisher': 'Bantam', 'description': 'An F.B.I. agent tracks a serial killer who uses spiders as a weapon.', 'published_date': '2008-08-03', 'bestseller_date': '2008-07-19', 'rank': 12, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 368.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 31.96}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d554'), 'Unnamed: 0': 55, 'nyt_id': '5b4aa4ead3089013507db239', 'title': 'KILLER VIEW', 'Amazon_url': 'http://www.amazon.com/Killer-View-Fleming-Ridley-Pearson/dp/0515146498?tag=NYTBS-20', 'author': 'Ridley Pearson', 'publisher': 'Putnam', 'description': 'A sheriff in Sun Valley, Idaho, investigates a series of crimes against a backdrop of conflict between wealthy vacationers and locals.', 'published_date': '2008-08-03', 'bestseller_date': '2008-07-19', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 50.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': 40.04}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d555'), 'Unnamed: 0': 56, 'nyt_id': '5b4aa4ead3089013507db23c', 'title': 'A THOUSAND SPLENDID SUNS', 'Amazon_url': 'http://www.amazon.com/Thousand-Splendid-Suns-Khaled-Hosseini/dp/159448385X?tag=NYTBS-20', 'author': 'Khaled Hosseini', 'publisher': 'Riverhead', 'description': 'A friendship between two Afghan women — born a generation apart and with very different ideas about love and family — against the backdrop of 30 years of war.', 'published_date': '2008-08-03', 'bestseller_date': '2008-07-19', 'rank': 18, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 1.99, 'Amazon_reviews': 4704.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d556'), 'Unnamed: 0': 57, 'nyt_id': '5b4aa4ead3089013507db23f', 'title': 'THE SECRET SERVANT', 'Amazon_url': 'http://www.amazon.com/Secret-Servant-Gabriel-Allon-Novels/dp/0451224507?tag=NYTBS-20', 'author': 'Daniel Silva', 'publisher': 'Putnam', 'description': 'Gabriel Allon, an art restorer and an occasional spy for the Israeli secret service, uncovers a Russian arms sales plot.', 'published_date': '2008-08-10', 'bestseller_date': '2008-07-26', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 828.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': 37.07}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d557'), 'Unnamed: 0': 58, 'nyt_id': '5b4aa4ead3089013507db245', 'title': 'INTO THE FIRE', 'Amazon_url': 'http://www.amazon.com/Into-Fire-Troubleshooters-Book-13/dp/0345501535?tag=NYTBS-20', 'author': 'Suzanne Brockmann', 'publisher': 'Ballantine', 'description': 'A former employee of an elite security company comes out of hiding to confront a murderous neo-Nazi group.', 'published_date': '2008-08-10', 'bestseller_date': '2008-07-26', 'rank': 7, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 127.0, 'Amazon_rating': 4.3, 'Amazon_Discount%': 31.96}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d558'), 'Unnamed: 0': 59, 'nyt_id': '5b4aa4ead3089013507db246', 'title': 'DAMAGE CONTROL', 'Amazon_url': 'http://www.amazon.com/Damage-Control-Joanna-Brady-Mysteries/dp/0060746769?tag=NYTBS-20', 'author': 'J A Jance', 'publisher': 'Morrow', 'description': 'An elderly couple’s suicide-by-accident in the mountains is not what it appears; the 13th Joanna Brady mystery.', 'published_date': '2008-08-10', 'bestseller_date': '2008-07-26', 'rank': 8, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 241.0, 'Amazon_rating': 4.6, 'Amazon_Discount%': 38.5}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d559'), 'Unnamed: 0': 60, 'nyt_id': '5b4aa4ead3089013507db250', 'title': 'BY SCHISM RENT ASUNDER', 'Amazon_url': 'http://www.amazon.com/Schism-Rent-Asunder-David-Weber/dp/0765315017?tag=NYTBS-20', 'author': 'David Weber', 'publisher': 'Tor', 'description': nan, 'published_date': '2008-08-10', 'bestseller_date': '2008-07-26', 'rank': 18, 'rank_last_week': 0, 'weeks_on_list': 0, 'NYT_Price': 0.0, 'Amazon_Price': 8.99, 'Amazon_reviews': 203.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55a'), 'Unnamed: 0': 61, 'nyt_id': '5b4aa4ead3089013507db254', 'title': 'THE BOURNE SANCTION', 'Amazon_url': 'http://www.amazon.com/Bourne-Sanction-Eric-Van-Lustbader/dp/B002GPYJ8Q?tag=NYTBS-20', 'author': 'Eric Van Lustbader', 'publisher': 'Grand Central', 'description': 'Robert Ludlum’s character Jason Bourne pursues the leader of a Muslim terrorist group.', 'published_date': '2008-08-17', 'bestseller_date': '2008-08-02', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.99, 'Amazon_Price': 2.09, 'Amazon_reviews': 176.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': 8.04}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55b'), 'Unnamed: 0': 62, 'nyt_id': '5b4aa4ead3089013507db257', 'title': 'THE GUERNSEY LITERARY AND POTATO PEEL PIE SOCIETY', 'Amazon_url': 'http://www.amazon.com/Guernsey-Literary-Potato-Peel-Society/dp/0385340990?tag=NYTBS-20', 'author': 'Mary Ann Shaffer and Annie Barrows', 'publisher': 'Dial', 'description': 'After World War II, a journalist travels to the island of Guernsey to meet residents who resisted the Nazi occupation.', 'published_date': '2008-08-17', 'bestseller_date': '2008-08-02', 'rank': 5, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 22.0, 'Amazon_Price': 12.99, 'Amazon_reviews': 4907.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': 59.05}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55c'), 'Unnamed: 0': 63, 'nyt_id': '5b4aa4ead3089013507db259', 'title': 'THE LACE READER', 'Amazon_url': 'http://www.amazon.com/The-Lace-Reader-A-Novel/dp/0061624772?tag=NYTBS-20', 'author': 'Brunonia Barry', 'publisher': 'Morrow', 'description': 'Secrets of a family of Salem women who foresee the future.', 'published_date': '2008-08-17', 'bestseller_date': '2008-08-02', 'rank': 7, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 633.0, 'Amazon_rating': 4.0, 'Amazon_Discount%': 40.04}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55d'), 'Unnamed: 0': 64, 'nyt_id': '5b4aa4ead3089013507db25f', 'title': 'THE CLONE WARS', 'Amazon_url': 'http://www.amazon.com/The-Clone-Wars-Star/dp/034550898X?tag=NYTBS-20', 'author': 'Karen Traviss', 'publisher': 'Del Rey', 'description': 'In the years before “Revenge of the Sith,” the Republic does battle with an army of cloned soldiers; a “Star Wars” novel.', 'published_date': '2008-08-17', 'bestseller_date': '2008-08-02', 'rank': 13, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 20.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 75.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 49.95}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55e'), 'Unnamed: 0': 65, 'nyt_id': '5b4aa4ead3089013507db261', 'title': 'FRACTURED', 'Amazon_url': 'http://www.amazon.com/Fractured-Karin-Slaughter/dp/0385341954?tag=NYTBS-20', 'author': 'Karin Slaughter', 'publisher': 'Delacorte', 'description': 'An Atlanta detective pursue’s a teenage girl’s killer.', 'published_date': '2008-08-17', 'bestseller_date': '2008-08-02', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 454.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 39.96}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d55f'), 'Unnamed: 0': 66, 'nyt_id': '5b4aa4ead3089013507db267', 'title': 'ACHERON', 'Amazon_url': 'http://www.amazon.com/Acheron-Dark-Hunter-Book-Sherrilyn-Kenyon/dp/0312949413?tag=NYTBS-20', 'author': 'Sherrilyn Kenyon', 'publisher': 'St. Martin’s', 'description': 'Book 12 of the Dark-Hunter paranormal series.', 'published_date': '2008-08-24', 'bestseller_date': '2008-08-09', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 1163.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': 36.03}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d560'), 'Unnamed: 0': 67, 'nyt_id': '5b4aa4ead3089013507db26f', 'title': 'FOREIGN BODY', 'Amazon_url': 'http://www.amazon.com/Foreign-Body-Robin-Cook/dp/0425228959?tag=NYTBS-20', 'author': 'Robin Cook', 'publisher': 'Putnam', 'description': 'A medical student investigates a rising number of deaths among medical tourists at foreign hospitals.', 'published_date': '2008-08-24', 'bestseller_date': '2008-08-09', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 116.0, 'Amazon_rating': 3.1, 'Amazon_Discount%': 34.64}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d561'), 'Unnamed: 0': 68, 'nyt_id': '5b4aa4ead3089013507db272', 'title': 'THE ASSASSIN', 'Amazon_url': 'http://www.amazon.com/The-Assassin-Novel-Stephen-Coonts/dp/031299446X?tag=NYTBS-20', 'author': 'Stephen Coonts', 'publisher': 'St. Martin’s', 'description': 'A top Qaeda terrorist pursues the Western leaders who are trying to defeat him.', 'published_date': '2008-08-24', 'bestseller_date': '2008-08-09', 'rank': 12, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 119.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d562'), 'Unnamed: 0': 69, 'nyt_id': '5b4aa4ead3089013507db274', 'title': 'THE GARGOYLE', 'Amazon_url': 'http://www.amazon.com/The-Gargoyle-Andrew-Davidson/dp/0385524943?tag=NYTBS-20', 'author': 'Andrew Davidson', 'publisher': 'Doubleday', 'description': 'A hideously burned man is cared for by a sculptress who claims they were lovers seven centuries ago.', 'published_date': '2008-08-24', 'bestseller_date': '2008-08-09', 'rank': 14, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 591.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 38.5}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d563'), 'Unnamed: 0': 70, 'nyt_id': '5b4aa4ead3089013507db27b', 'title': 'SMOKE SCREEN', 'Amazon_url': 'http://www.amazon.com/Smoke-Screen-Novel-Sandra-Brown/dp/1416563075?tag=NYTBS-20', 'author': 'Sandra Brown', 'publisher': 'Simon & Schuster', 'description': 'Scandalous deaths thwart the investigation of a fatal fire at police headquarters in Charleston, S.C.', 'published_date': '2008-08-31', 'bestseller_date': '2008-08-16', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.95, 'Amazon_Price': 8.99, 'Amazon_reviews': 312.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': 33.36}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d564'), 'Unnamed: 0': 71, 'nyt_id': '5b4aa4ead3089013507db282', 'title': 'THE MERCEDES COFFIN', 'Amazon_url': 'http://www.amazon.com/The-Mercedes-Coffin-Decker-Lazarus/dp/0061227374?tag=NYTBS-20', 'author': 'Faye Kellerman', 'publisher': 'Morrow', 'description': 'Decker and Lazarus investigate cases of murder victims found in Mercedes-Benz trunks.', 'published_date': '2008-08-31', 'bestseller_date': '2008-08-16', 'rank': 8, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 25.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 143.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': 38.5}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d565'), 'Unnamed: 0': 72, 'nyt_id': '5b4aa4ead3089013507db283', 'title': 'OFF SEASON', 'Amazon_url': 'http://www.amazon.com/Off-Season-Anne-Rivers-Siddons-ebook/dp/B0015DTUYI?tag=NYTBS-20', 'author': 'Anne Rivers Siddons', 'publisher': 'Grand Central', 'description': 'A widow returns to her hometown in Maine to regather the strands of her life.', 'published_date': '2008-08-31', 'bestseller_date': '2008-08-16', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 24.95, 'Amazon_Price': 9.99, 'Amazon_reviews': 239.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': 40.04}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d566'), 'Unnamed: 0': 73, 'nyt_id': '5b4aa4ead3089013507db286', 'title': 'THE 19TH WIFE', 'Amazon_url': 'http://www.amazon.com/The-19th-Wife-A-Novel/dp/1400063973?tag=NYTBS-20', 'author': 'David Ebershoff', 'publisher': 'Random House', 'description': 'A tale of Mormon outcasts past and present: a wife of Brigham Young and a son of a murdered polygamist.', 'published_date': '2008-08-31', 'bestseller_date': '2008-08-16', 'rank': 12, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.0, 'Amazon_Price': 9.99, 'Amazon_reviews': 785.0, 'Amazon_rating': 3.9, 'Amazon_Discount%': 38.42}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d567'), 'Unnamed: 0': 74, 'nyt_id': '5b4aa4ead3089013507db28f', 'title': 'THE FORCE UNLEASHED', 'Amazon_url': 'http://www.amazon.com/The-Force-Unleashed-Star-Wars/dp/0345499026?tag=NYTBS-20', 'author': 'Sean Williams', 'publisher': 'Del Rey', 'description': 'An apprentice to Darth Vader is dispatched to kill the last of his master’s enemies; a “Star Wars” novel.', 'published_date': '2008-09-07', 'bestseller_date': '2008-08-23', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 26.0, 'Amazon_Price': 7.99, 'Amazon_reviews': 926.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': 30.73}
# {'_id': ObjectId('5c808d57bd7b6a18fc59d568'), 'Unnamed: 0': 75, 'nyt_id': '5b4aa4ead3089013507db29a', 'title': 'BEING ELIZABETH', 'Amazon_url': 'http://www.amazon.com/Being-Elizabeth-Barbara-Taylor-Bradford/dp/0312354630?tag=NYTBS-20', 'author': 'Barbara Taylor Bradford', 'publisher': 'St. Martin’s', 'description': 'A 25-year-old newly in control of her family’s corporate empire faces tough choices in business and in love.', 'published_date': '2008-09-07', 'bestseller_date': '2008-08-23', 'rank': 12, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 27.95, 'Amazon_Price': 7.99, 'Amazon_reviews': 93.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': 28.59}
# ...
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd96'), 'Unnamed: 0': 2169, 'nyt_id': '5b4aa4ead3089013507dd8e9', 'title': 'BY INVITATION ONLY', 'Amazon_url': 'https://www.amazon.com/Invitation-Only-Dorothea-Benton-Frank-ebook/dp/B071S5VRQV?tag=NYTBS-20', 'author': 'Dorothea Benton Frank', 'publisher': 'Morrow', 'description': 'Two families are brought together when the daughter of a Chicago power broker and the son of a Southern peach farmer decide to wed.', 'published_date': '2018-06-03', 'bestseller_date': '2018-05-19', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 406.0, 'Amazon_rating': nan, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd97'), 'Unnamed: 0': 2170, 'nyt_id': '5b4aa4ead3089013507dd8f3', 'title': 'HOW TO WALK AWAY', 'Amazon_url': 'https://www.amazon.com/How-Walk-Away-Katherine-Center/dp/1250149061?tag=NYTBS-20', 'author': 'Katherine Center', 'publisher': "St. Martin's", 'description': 'Maggie Jacobsen’s life is turned upside down when she is paralyzed and winds up in a hospital.', 'published_date': '2018-06-03', 'bestseller_date': '2018-05-19', 'rank': 14, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 13.85, 'Amazon_reviews': 539.0, 'Amazon_rating': nan, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd98'), 'Unnamed: 0': 2171, 'nyt_id': '5b4aa4ead3089013507dd8f5', 'title': 'THE OUTSIDER', 'Amazon_url': 'https://www.amazon.com/Outsider-Novel-Stephen-King/dp/1501180983?tag=NYTBS-20', 'author': 'Stephen King', 'publisher': 'Scribner', 'description': 'A detective investigates a seemingly wholesome member of the community when an 11-year-old boy’s body is found in a town park.', 'published_date': '2018-06-10', 'bestseller_date': '2018-05-26', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 3724.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd99'), 'Unnamed: 0': 2172, 'nyt_id': '5b4aa4ead3089013507dd903', 'title': 'THE FAVORITE SISTER', 'Amazon_url': 'https://www.amazon.com/Favorite-Sister-Jessica-Knoll/dp/1501153196?tag=NYTBS-20', 'author': 'Jessica Knoll', 'publisher': 'Simon & Schuster', 'description': 'The more popular of a pair of sisters cast on a reality show turns up dead.', 'published_date': '2018-06-10', 'bestseller_date': '2018-05-26', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 301.0, 'Amazon_rating': 3.0, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9a'), 'Unnamed: 0': 2173, 'nyt_id': '5b4aa4ead3089013507dd905', 'title': 'SHELTER IN PLACE', 'Amazon_url': 'https://www.amazon.com/Shelter-Place-Nora-Roberts-ebook/dp/B076BGDMK9?tag=NYTBS-20', 'author': 'Nora Roberts', 'publisher': "St. Martin's", 'description': 'Survivors of a mass shooting outside a mall in Portland, Me., develop different coping mechanisms and face a new menace.', 'published_date': '2018-06-17', 'bestseller_date': '2018-06-02', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 1580.0, 'Amazon_rating': 4.7, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9b'), 'Unnamed: 0': 2174, 'nyt_id': '5b4aa4ead3089013507dd906', 'title': 'THE GRAY GHOST', 'Amazon_url': 'https://www.amazon.com/Gray-Ghost-Remi-Fargo-Adventure-ebook/dp/B075HY5MJK?tag=NYTBS-20', 'author': 'Clive Cussler and Robin Burcell', 'publisher': 'Putnam', 'description': 'Sam and Remi Fargo search for a Rolls-Royce prototype that has vanished for a second time.', 'published_date': '2018-06-17', 'bestseller_date': '2018-06-02', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 434.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9c'), 'Unnamed: 0': 2175, 'nyt_id': '5b4aa4ead3089013507dd907', 'title': 'THE DEATH OF MRS. WESTAWAY', 'Amazon_url': 'https://www.amazon.com/Death-Mrs-Westaway-Ruth-Ware/dp/1501156217?tag=NYTBS-20', 'author': 'Ruth Ware', 'publisher': 'Gallery/Scout', 'description': 'A tarot card reader mistakenly receives an inheritance letter and attends the funeral of the deceased.', 'published_date': '2018-06-17', 'bestseller_date': '2018-06-02', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 16.76, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9d'), 'Unnamed: 0': 2176, 'nyt_id': '5b4aa4ead3089013507dd908', 'title': 'TO THE MOON AND BACK', 'Amazon_url': 'https://www.amazon.com/Moon-Back-Novel-Baxter-Family/dp/1451687656?tag=NYTBS-20', 'author': 'Karen Kingsbury', 'publisher': 'Howard', 'description': 'A man whose mother died in the Oklahoma City bombing seeks to reconnect with a woman also affected by the tragedy.', 'published_date': '2018-06-17', 'bestseller_date': '2018-06-02', 'rank': 5, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9e'), 'Unnamed: 0': 2177, 'nyt_id': '5b4aa4ead3089013507dd913', 'title': 'THE PRESIDENT IS MISSING', 'Amazon_url': 'https://www.amazon.com/President-Missing-Novel-James-Patterson/dp/0316412694?tag=NYTBS-20', 'author': 'Bill Clinton and James Patterson', 'publisher': 'Little, Brown and Knopf', 'description': 'President Jonathan Duncan, a Gulf War veteran and widower, takes on adversaries at home and abroad.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 5978.0, 'Amazon_rating': 4.3, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dd9f'), 'Unnamed: 0': 2178, 'nyt_id': '5b4aa4ead3089013507dd917', 'title': 'BRIEF CASES', 'Amazon_url': 'https://www.amazon.com/Brief-Cases-Dresden-Files-Butcher-ebook/dp/B077WYGXPP?tag=NYTBS-20', 'author': 'Jim Butcher', 'publisher': 'Ace', 'description': 'A dozen stories about Harry Dresden, Chicago’s only professional wizard.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 5, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 548.0, 'Amazon_rating': nan, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda0'), 'Unnamed: 0': 2179, 'nyt_id': '5b4aa4ead3089013507dd91a', 'title': 'WHEN LIFE GIVES YOU LULULEMONS', 'Amazon_url': 'https://www.amazon.com/When-Life-Gives-You-Lululemons-ebook/dp/B078MC8G1X?tag=NYTBS-20', 'author': 'Lauren Weisberger', 'publisher': 'Simon & Schuster', 'description': 'Emily Charlton plans a comeback from the suburbs. From the author of "The Devil Wears Prada."', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 8, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'Amazon_reviews': 518.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda1'), 'Unnamed: 0': 2180, 'nyt_id': '5b4aa4ead3089013507dd91b', 'title': 'US AGAINST YOU', 'Amazon_url': 'https://www.amazon.com/Us-Against-You-Novel-Beartown/dp/1501160796?tag=NYTBS-20', 'author': 'Fredrik Backman', 'publisher': 'Atria', 'description': 'Beartown’s hockey team gets a new coach and their rivalry with a neighboring team escalates.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda2'), 'Unnamed: 0': 2181, 'nyt_id': '5b4aa4ead3089013507dd91c', 'title': 'TURBULENCE', 'Amazon_url': 'https://www.amazon.com/Turbulence-Stone-Barrington-Novel-Stuart-ebook/dp/B078G37F9W?tag=NYTBS-20', 'author': 'Stuart Woods', 'publisher': 'Putnam', 'description': 'The 46th book in the Stone Barrington series.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 10, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': nan, 'Amazon_rating': 4.0, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda3'), 'Unnamed: 0': 2182, 'nyt_id': '5b4aa4ead3089013507dd91d', 'title': 'SOMETHING IN THE WATER', 'Amazon_url': 'https://www.amazon.com/Something-Water-Novel-Catherine-Steadman-ebook/dp/B075HYDH8B?tag=NYTBS-20', 'author': 'Catherine Steadman', 'publisher': 'Ballantine', 'description': 'A documentary filmmaker and an investment banker must decide whether they should protect a secret.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 11, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 12.99, 'Amazon_reviews': 1046.0, 'Amazon_rating': 3.8, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda4'), 'Unnamed: 0': 2183, 'nyt_id': '5b4aa4ead3089013507dd91f', 'title': 'THERE THERE', 'Amazon_url': 'https://www.amazon.com/There-novel-Tommy-Orange/dp/0525520376?tag=NYTBS-20', 'author': 'Tommy Orange', 'publisher': 'Knopf', 'description': 'A multigenerational story exploring the plight of the urban Native American.', 'published_date': '2018-06-24', 'bestseller_date': '2018-06-09', 'rank': 13, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 13.99, 'Amazon_reviews': 480.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda5'), 'Unnamed: 0': 2184, 'nyt_id': '5b4aa4ead3089013507dd924', 'title': 'TOM CLANCY LINE OF SIGHT', 'Amazon_url': 'https://www.amazon.com/Clancy-Line-Sight-Jack-Novel-ebook/dp/B075HYJF6X?tag=NYTBS-20', 'author': 'Mike Maden', 'publisher': 'Putnam', 'description': 'Jack Ryan Jr. risks his life to protect a woman in a country on the brink of civil war.', 'published_date': '2018-07-01', 'bestseller_date': '2018-06-16', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 456.0, 'Amazon_rating': 3.7, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda6'), 'Unnamed: 0': 2185, 'nyt_id': '5b4aa4ead3089013507dd925', 'title': 'THE PHARAOH KEY', 'Amazon_url': 'https://www.amazon.com/Pharaoh-Key-Gideon-Crew/dp/1455525820?tag=NYTBS-20', 'author': 'Douglas Preston and Lincoln Child', 'publisher': 'Grand Central', 'description': 'Gideon Crew and Manuel Garza go on a mission to solve the mystery of a centuries-old stone tablet.', 'published_date': '2018-07-01', 'bestseller_date': '2018-06-16', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 8.99, 'Amazon_reviews': 386.0, 'Amazon_rating': 3.8, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda7'), 'Unnamed: 0': 2186, 'nyt_id': '5b4aa4ead3089013507dd92a', 'title': 'BEFORE THE STORM', 'Amazon_url': 'https://www.amazon.com/Before-Storm-Warcraft-Christie-Golden/dp/0399594094?tag=NYTBS-20', 'author': 'Christie Golden', 'publisher': 'Del Rey', 'description': 'An impending war may destroy Azeroth. Based on the online role-playing game World of Warcraft.', 'published_date': '2018-07-01', 'bestseller_date': '2018-06-16', 'rank': 9, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 327.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda8'), 'Unnamed: 0': 2187, 'nyt_id': '5b4aa4ead3089013507dd92e', 'title': 'A PLACE FOR US', 'Amazon_url': 'https://www.amazon.com/Place-Us-Fatima-Farheen-Mirza/dp/1524763551?tag=NYTBS-20', 'author': 'Fatima Farheen Mirza', 'publisher': 'SJP for Hogarth', 'description': 'The bonds and betrayals of an Indian Muslim family are exposed when they gather for a wedding in California.', 'published_date': '2018-07-01', 'bestseller_date': '2018-06-16', 'rank': 13, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 18.36, 'Amazon_reviews': nan, 'Amazon_rating': nan, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59dda9'), 'Unnamed: 0': 2188, 'nyt_id': '5b4aa4ead3089013507dd932', 'title': 'THE PERFECT COUPLE', 'Amazon_url': 'https://www.amazon.com/Perfect-Couple-Elin-Hilderbrand/dp/0316375268?tag=NYTBS-20', 'author': 'Elin Hilderbrand', 'publisher': 'Little, Brown', 'description': 'A body is found in Nantucket Harbor hours before a picture-perfect wedding.', 'published_date': '2018-07-08', 'bestseller_date': '2018-06-23', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 15.4, 'Amazon_reviews': 897.0, 'Amazon_rating': 4.2, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59ddaa'), 'Unnamed: 0': 2189, 'nyt_id': '5b4aa4ead3089013507dd93c', 'title': 'THE SKAAR INVASION', 'Amazon_url': 'https://www.amazon.com/Skaar-Invasion-Fall-Shannara/dp/0553391518?tag=NYTBS-20', 'author': 'Terry Brooks', 'publisher': 'Del Rey', 'description': 'The second book in the Fall of Shannara series.', 'published_date': '2018-07-08', 'bestseller_date': '2018-06-23', 'rank': 12, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': nan, 'Amazon_reviews': 156.0, 'Amazon_rating': nan, 'Amazon_Discount%': nan}
# {'_id': ObjectId('5c808d57bd7b6a18fc59ddab'), 'Unnamed: 0': 2190, 'nyt_id': '5b4aa4ead3089013507dd93d', 'title': 'BRING ME BACK', 'Amazon_url': 'https://www.amazon.com/Bring-Me-Back-B-Paris/dp/1250151333?tag=NYTBS-20', 'author': 'BA Paris', 'publisher': "St. Martin's", 'description': "A decade after she vanished, a woman's potential reappearance may interfere with her ex-boyfriend's engagement to her sister.", 'published_date': '2018-07-08', 'bestseller_date': '2018-06-23', 'rank': 13, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.84, 'Amazon_reviews': 661.0, 'Amazon_rating': 3.6, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59ddac'), 'Unnamed: 0': 2191, 'nyt_id': '5b4aa4ead3089013507dd941', 'title': 'ALL WE EVER WANTED', 'Amazon_url': 'https://www.amazon.com/All-We-Ever-Wanted-Novel-ebook/dp/B07639D2G9?tag=NYTBS-20', 'author': 'Emily Giffin', 'publisher': 'Ballantine', 'description': 'A scandal sends members of two Nashville families into chaos.', 'published_date': '2018-07-15', 'bestseller_date': '2018-06-30', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 1055.0, 'Amazon_rating': 4.1, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59ddad'), 'Unnamed: 0': 2192, 'nyt_id': '5b4aa4ead3089013507dd950', 'title': 'SPYMASTER', 'Amazon_url': 'https://www.amazon.com/Spymaster-Thriller-Scot-Harvath-Book-ebook/dp/B075RMMZ6K?tag=NYTBS-20', 'author': 'Brad Thor', 'publisher': 'Emily Bestler/Atria', 'description': 'The 18th book in the Scot Harvath series. As a war looms, a counterterrorism operative takes on a new role his own way.', 'published_date': '2018-07-22', 'bestseller_date': '2018-07-07', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 14.99, 'Amazon_reviews': 719.0, 'Amazon_rating': 4.5, 'Amazon_Discount%': inf}
# {'_id': ObjectId('5c808d57bd7b6a18fc59ddae'), 'Unnamed: 0': 2193, 'nyt_id': '5b4aa4ead3089013507dd95d', 'title': 'THE LAST TIME I LIED', 'Amazon_url': 'https://www.amazon.com/Last-Time-Lied-Novel/dp/1524743070?tag=NYTBS-20', 'author': 'Riley Sager', 'publisher': 'Dutton', 'description': 'A painter is in danger when she returns to the summer camp where some of her childhood friends disappeared.', 'published_date': '2018-07-22', 'bestseller_date': '2018-07-07', 'rank': 15, 'rank_last_week': 0, 'weeks_on_list': 1, 'NYT_Price': 0.0, 'Amazon_Price': 15.11, 'Amazon_reviews': 386.0, 'Amazon_rating': 4.4, 'Amazon_Discount%': inf}

# %% [markdown]
# ### STEP 2: Render data using Flask
#
# In this step we build an app to render our data.

# %%
# Import and set-up Flask

from flask import Flask, jsonify
app = Flask(__name__)

# Define Flask routes

@app.route("/")
def welcome():
    return (
        f"Welcome to Best of the NYT BestSellers!<br/>"
        f"Available Routes:<br/>"
        f"/api/v1.0/justice-league"
    )


if __name__ == "__main__":
    app.run(debug=True)
